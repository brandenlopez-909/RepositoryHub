# %% [markdown]
# # 1.
#
# Search the web for "spoof newspaper headlines", to find such gems as: British Left Waffles on Falkland Islands, and Juvenile Court to Try Shooting Defendant. Manually tag these headlines to see if knowledge of the part-of-speech tags removes the ambiguity.
#
# British Left Waffles on Falkland Islands
# - British: Noun- "the british people"
# - Left: Verb
# - Waffes: Noun
# - ON:  preposition
# - Falkland Islands; noun.
#
# By manually taggin the headline we see that the british people left a food item on an island. If we do not tag the sentence we can think that " British Left Waffle" is a noun. That is  British Left Waffle could be a political party, on the islands.
#
# Juvenile Court to Try Shooting Defendant:
#
# - Juvenile: Noun - a young person
#
# - Court: Noun- A place
# - to: preposition- approaching or reaching
# - Try: adverb
# - Shoooing: Verb - the action or practice of shooting with a gun or the action of filming or photographing a scene, film, etc.
#
# - Defendant: noun
#
# When taking the POS tags in context it still seems ambigous. we know that a a person is being acted upon.

# %% [markdown]
# # 2.
#
# Working with someone else, take turns to pick a word that can be either a noun or a verb (e.g. contest); the opponent has to predict which one is likely to be the most frequent in the Brown corpus; check the opponent's prediction, and tally the score over several turns.
#
# No one is present, I always work in the library.

# %% [markdown]
# # 3.
#  Tokenize and tag the following sentence: They wind back the clock, while we chase after the wind. What different pronunciations and parts of speech are involved?

# %%
import nltk
s = "They wind back the clock, while we chase after the win"
tokens = nltk.word_tokenize(s)
tokens
# Out:
# ['They',
#  'wind',
#  'back',
#  'the',
#  'clock',
#  ',',
#  'while',
#  'we',
#  'chase',
#  'after',
#  'the',
#  'win']

# %%
#Make sure you use, tagset='universal' or you will not understand the output
nltk.pos_tag(tokens, tagset='universal')
# Out:
# [('They', 'PRON'),
#  ('wind', 'VERB'),
#  ('back', 'ADV'),
#  ('the', 'DET'),
#  ('clock', 'NOUN'),
#  (',', '.'),
#  ('while', 'ADP'),
#  ('we', 'PRON'),
#  ('chase', 'VERB'),
#  ('after', 'ADP'),
#  ('the', 'DET'),
#  ('win', 'NOUN')]

# %% [markdown]
# - Pronoun(PRON): a word that can function by itself as a noun phrase and that refers either to the participants in the discourse (e.g., I, you ) or to someone or something mentioned elsewhere in the discourse (e.g., she, it, this ).
#
# - VERB: An action.
#
# - Adverb(ADV): a word or phrase that modifies or qualifies an adjective, verb, or other adverb or a word group, expressing a relation of place, time, circumstance, manner, cause, degree, etc. (e.g., gently, quite, then, there ).
#
# - Determiner(DET):  a modifying word that determines the kind of reference a noun or noun group has, for example a, the, every.
#
# - Noun: Person, place, or thing.
#
# - Adposition(ADP): An adposition is a cover term for prepositions and postpositions.
#
# There is a wide range of tags used in the single sentence.

# %% [markdown]
# # 4.
# Review the mappings in 3.1. Discuss any other examples of mappings you can think of. What type of information do they map from and to?
#
# 3.1
#
# |Linguistic Object	|Maps From|	Maps To|
# |--------------------|---------|--------|
# |Document Index	|Word	|List of pages (where word is found) |
# |Thesaurus|	Word sense|	List of synonyms|
# |Dictionary|	Headword|	Entry (part-of-speech, sense definitions, etymology)|
# |Comparative Wordlist|	Gloss term|	Cognates (list of words, one per language)|
# |Morph Analyzer|	Surface form|	Morphological analysis (list of component morphemes)|
#
# Mapping can be found everywhere. Grocery stores use barcodes to map to product information. URLS map to a specific website. etc.

# %% [markdown]
# # 5.
#
# Using the Python interpreter in interactive mode, experiment with the dictionary examples in this chapter. Create a dictionary d, and add some entries. What happens if you try to access a non-existent entry, e.g. d['xyz']?

# %%
d = dict()
d['xyz'] = 1
d
#It simply adds it to an empty dictonary
# Out:
# {'xyz': 1}

# %%
d['a'] = "b"
#If we do not use a defaultdict, we can pass whatever value we want.

# %%
#d["x"]
#An error occurs if we try to access a non-existent entry

# %% [markdown]
# # 6.
# Try deleting an element from a dictionary d, using the syntax del d['abc']. Check that the item was deleted.

# %%
help(dict)
# Out:
# Help on class dict in module builtins:
#
# class dict(object)
#  |  dict() -> new empty dictionary
#  |  dict(mapping) -> new dictionary initialized from a mapping object's
#  |      (key, value) pairs
#  |  dict(iterable) -> new dictionary initialized as if via:
#  |      d = {}
#  |      for k, v in iterable:
#  |          d[k] = v
#  |  dict(**kwargs) -> new dictionary initialized with the name=value pairs
#  |      in the keyword argument list.  For example:  dict(one=1, two=2)
#  |
#  |  Methods defined here:
#  |
#  |  __contains__(self, key, /)
#  |      True if the dictionary has the specified key, else False.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __setitem__(self, key, value, /)
#  |      Set self[key] to value.
#  |
#  |  __sizeof__(...)
#  |      D.__sizeof__() -> size of D in memory, in bytes
#  |
#  |  clear(...)
#  |      D.clear() -> None.  Remove all items from D.
#  |
#  |  copy(...)
#  |      D.copy() -> a shallow copy of D
#  |
#  |  get(self, key, default=None, /)
#  |      Return the value for key if key is in the dictionary, else default.
#  |
#  |  items(...)
#  |      D.items() -> a set-like object providing a view on D's items
#  |
#  |  keys(...)
#  |      D.keys() -> a set-like object providing a view on D's keys
#  |
#  |  pop(...)
#  |      D.pop(k[,d]) -> v, remove specified key and return the corresponding value.
#  |      If key is not found, d is returned if given, otherwise KeyError is raised
#  |
#  |  popitem(...)
#  |      D.popitem() -> (k, v), remove and return some (key, value) pair as a
#  |      2-tuple; but raise KeyError if D is empty.
#  |
#  |  setdefault(self, key, default=None, /)
#  |      Insert key with a value of default if key is not in the dictionary.
#  |
#  |      Return the value for key if key is in the dictionary, else default.
#  |
#  |  update(...)
#  |      D.update([E, ]**F) -> None.  Update D from dict/iterable E and F.
#  |      If E is present and has a .keys() method, then does:  for k in E: D[k] = E[k]
#  |      If E is present and lacks a .keys() method, then does:  for k, v in E: D[k] = v
#  |      In either case, this is followed by: for k in F:  D[k] = F[k]
#  |
#  |  values(...)
#  |      D.values() -> an object providing a view on D's values
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  fromkeys(iterable, value=None, /) from builtins.type
#  |      Create a new dictionary with keys from iterable and values set to value.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None

# %%
#Firt we ad it 
d["abc"] = 10

# %%
d
# Out:
# {'xyz': 1, 'a': 'b', 'abc': 10}

# %%
del d["abc"]

# %%
d
#wow!
# Out:
# {'xyz': 1, 'a': 'b'}

# %% [markdown]
# # 7.
# Create two dictionaries, d1 and d2, and add some entries to each. Now issue the command d1.update(d2). What did this do? What might it be useful for?

# %%
d1 = dict(abc = 5, xyz = 10);
d2 = dict(me = 24, you = 21);
d1.update(d2)
d1
#Useful for adding dictonaries together or adding new entries.
# Out:
# {'abc': 5, 'xyz': 10, 'me': 24, 'you': 21}

# %% [markdown]
# # 8.
#
# Create a dictionary e, to represent a single lexical entry for some word of your choice. Define keys like headword, part-of-speech, sense, and example, and assign them suitable values.

# %%
e = dict(Branden = "noun", noun = "person, place, or thing", example= "My name is Branden")
e
# Out:
# {'Branden': 'noun',
#  'noun': 'person, place, or thing',
#  'example': 'My name is Branden'}

# %% [markdown]
# # 9.
# Satisfy yourself that there are restrictions on the distribution of go and went, in the sense that they cannot be freely interchanged in the kinds of contexts illustrated in (3d) in 7.
#
# - 3d.		We went on the excursion.
# - 7. Determine category of the word.
#
# There are restrictions to "go" and "went". "Go" can be future tense, it indicates something will happen in the future, or it can be present tense. "Went" is past tense, it indicates something happened in the past. If we change 3d with "go", we change the meaning of the sentence
#
# - We go on the exursion. Not only does it sound grammatically incorrect, but it changes the meaning from something they have done in the past, to something they will be/ are doing.

# %% [markdown]
# # 10
# Train a unigram tagger and run it on some new text. Observe that some words are not assigned a tag. Why not?

# %%
help(nltk.UnigramTagger)
# Out:
# Help on class UnigramTagger in module nltk.tag.sequential:
#
# class UnigramTagger(NgramTagger)
#  |  UnigramTagger(train=None, model=None, backoff=None, cutoff=0, verbose=False)
#  |
#  |  Unigram Tagger
#  |
#  |  The UnigramTagger finds the most likely tag for each word in a training
#  |  corpus, and then uses that information to assign tags to new tokens.
#  |
#  |      >>> from nltk.corpus import brown
#  |      >>> from nltk.tag import UnigramTagger
#  |      >>> test_sent = brown.sents(categories='news')[0]
#  |      >>> unigram_tagger = UnigramTagger(brown.tagged_sents(categories='news')[:500])
#  |      >>> for tok, tag in unigram_tagger.tag(test_sent):
#  |      ...     print("(%s, %s), " % (tok, tag))
#  |      (The, AT), (Fulton, NP-TL), (County, NN-TL), (Grand, JJ-TL),
#  |      (Jury, NN-TL), (said, VBD), (Friday, NR), (an, AT),
#  |      (investigation, NN), (of, IN), (Atlanta's, NP$), (recent, JJ),
#  |      (primary, NN), (election, NN), (produced, VBD), (``, ``),
#  |      (no, AT), (evidence, NN), ('', ''), (that, CS), (any, DTI),
#  |      (irregularities, NNS), (took, VBD), (place, NN), (., .),
#  |
#  |  :param train: The corpus of training data, a list of tagged sentences
#  |  :type train: list(list(tuple(str, str)))
#  |  :param model: The tagger model
#  |  :type model: dict
#  |  :param backoff: Another tagger which this tagger will consult when it is
#  |      unable to tag a word
#  |  :type backoff: TaggerI
#  |  :param cutoff: The number of instances of training data the tagger must see
#  |      in order not to use the backoff tagger
#  |  :type cutoff: int
#  |
#  |  Method resolution order:
#  |      UnigramTagger
#  |      NgramTagger
#  |      ContextTagger
#  |      SequentialBackoffTagger
#  |      nltk.tag.api.TaggerI
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, train=None, model=None, backoff=None, cutoff=0, verbose=False)
#  |      :param context_to_tag: A dictionary mapping contexts to tags.
#  |      :param backoff: The backoff tagger that should be used for this tagger.
#  |
#  |  context(self, tokens, index, history)
#  |      :return: the context that should be used to look up the tag
#  |          for the specified token; or None if the specified token
#  |          should not be handled by this tagger.
#  |      :rtype: (hashable)
#  |
#  |  encode_json_obj(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  decode_json_obj(obj) from abc.ABCMeta
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __abstractmethods__ = frozenset()
#  |
#  |  json_tag = 'nltk.tag.sequential.UnigramTagger'
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from ContextTagger:
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  __unicode__ = __str__(self, /)
#  |
#  |  choose_tag(self, tokens, index, history)
#  |      Decide which tag should be used for the specified token, and
#  |      return that tag.  If this tagger is unable to determine a tag
#  |      for the specified token, return None -- do not consult
#  |      the backoff tagger.  This method should be overridden by
#  |      subclasses of SequentialBackoffTagger.
#  |
#  |      :rtype: str
#  |      :type tokens: list
#  |      :param tokens: The list of words that are being tagged.
#  |      :type index: int
#  |      :param index: The index of the word whose tag should be
#  |          returned.
#  |      :type history: list(str)
#  |      :param history: A list of the tags for all words before *index*.
#  |
#  |  size(self)
#  |      :return: The number of entries in the table used by this
#  |          tagger to map from contexts to tags.
#  |
#  |  unicode_repr = __repr__(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from SequentialBackoffTagger:
#  |
#  |  tag(self, tokens)
#  |      Determine the most appropriate tag sequence for the given
#  |      token sequence, and return a corresponding list of tagged
#  |      tokens.  A tagged token is encoded as a tuple ``(token, tag)``.
#  |
#  |      :rtype: list(tuple(str, str))
#  |
#  |  tag_one(self, tokens, index, history)
#  |      Determine an appropriate tag for the specified token, and
#  |      return that tag.  If this tagger is unable to determine a tag
#  |      for the specified token, then its backoff tagger is consulted.
#  |
#  |      :rtype: str
#  |      :type tokens: list
#  |      :param tokens: The list of words that are being tagged.
#  |      :type index: int
#  |      :param index: The index of the word whose tag should be
#  |          returned.
#  |      :type history: list(str)
#  |      :param history: A list of the tags for all words before *index*.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from SequentialBackoffTagger:
#  |
#  |  backoff
#  |      The backoff tagger for this tagger.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from nltk.tag.api.TaggerI:
#  |
#  |  evaluate(self, gold)
#  |      Score the accuracy of the tagger against the gold standard.
#  |      Strip the tags from the gold standard text, retag it using
#  |      the tagger, then compute the accuracy score.
#  |
#  |      :type gold: list(list(tuple(str, str)))
#  |      :param gold: The list of tagged sentences to score the tagger on.
#  |      :rtype: float
#  |
#  |  tag_sents(self, sentences)
#  |      Apply ``self.tag()`` to each element of *sentences*.  I.e.:
#  |
#  |          return [self.tag(sent) for sent in sentences]
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from nltk.tag.api.TaggerI:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
from nltk.corpus import brown

# %%
brown.categories()
# Out:
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %%
from nltk.corpus import brown
brown_tagged_sents = brown.tagged_sents(categories='adventure')
brown_sents = brown.sents(categories='adventure')
unigram_tagger = nltk.UnigramTagger(brown_tagged_sents)
unigram_tagger.tag(brown_sents[1])
# Out:
# [('He', 'PPS'),
#  ('was', 'BEDZ'),
#  ('well', 'RB'),
#  ('rid', 'JJ'),
#  ('of', 'IN'),
#  ('her', 'PP$'),
#  ('.', '.')]

# %%
unigram_tagger.evaluate(brown_tagged_sents)
# Out:
# 0.9403247670964207

# %% [markdown]
# I had some issues finding an actual sentence that had None as the POS. I tried higher-order functions with itemgetter() to find the pos tags and add them to a set. Not only did it fail to include items in the first sentence, it never found a None.

# %%
from operator import itemgetter
#set( item for item in map(itemgetter(1),unigram_tagger.tag(brown_sent) ) for brown_sent in brown_sents)
#This is clearly wrong.

# %%
#set(map(itemgetter(1),unigram_tagger.tag(brown_sents[1]) ) )

# %% [markdown]
# Despite this, from the book:  It cannot tag the following word (i.e., million) even if it was seen during training, simply because it never saw it during training with a None tag on the previous word.

# %% [markdown]
# # 11.
#
# Learn about the affix tagger (type help(nltk.AffixTagger)). Train an affix tagger and run it on some new text. Experiment with different settings for the affix length and the minimum word length. Discuss your findings.

# %%
help(nltk.AffixTagger)
# Out:
# Help on class AffixTagger in module nltk.tag.sequential:
#
# class AffixTagger(ContextTagger)
#  |  AffixTagger(train=None, model=None, affix_length=-3, min_stem_length=2, backoff=None, cutoff=0, verbose=False)
#  |
#  |  A tagger that chooses a token's tag based on a leading or trailing
#  |  substring of its word string.  (It is important to note that these
#  |  substrings are not necessarily "true" morphological affixes).  In
#  |  particular, a fixed-length substring of the word is looked up in a
#  |  table, and the corresponding tag is returned.  Affix taggers are
#  |  typically constructed by training them on a tagged corpus.
#  |
#  |  Construct a new affix tagger.
#  |
#  |  :param affix_length: The length of the affixes that should be
#  |      considered during training and tagging.  Use negative
#  |      numbers for suffixes.
#  |  :param min_stem_length: Any words whose length is less than
#  |      min_stem_length+abs(affix_length) will be assigned a
#  |      tag of None by this tagger.
#  |
#  |  Method resolution order:
#  |      AffixTagger
#  |      ContextTagger
#  |      SequentialBackoffTagger
#  |      nltk.tag.api.TaggerI
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, train=None, model=None, affix_length=-3, min_stem_length=2, backoff=None, cutoff=0, verbose=False)
#  |      :param context_to_tag: A dictionary mapping contexts to tags.
#  |      :param backoff: The backoff tagger that should be used for this tagger.
#  |
#  |  context(self, tokens, index, history)
#  |      :return: the context that should be used to look up the tag
#  |          for the specified token; or None if the specified token
#  |          should not be handled by this tagger.
#  |      :rtype: (hashable)
#  |
#  |  encode_json_obj(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  decode_json_obj(obj) from abc.ABCMeta
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __abstractmethods__ = frozenset()
#  |
#  |  json_tag = 'nltk.tag.sequential.AffixTagger'
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from ContextTagger:
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  __unicode__ = __str__(self, /)
#  |
#  |  choose_tag(self, tokens, index, history)
#  |      Decide which tag should be used for the specified token, and
#  |      return that tag.  If this tagger is unable to determine a tag
#  |      for the specified token, return None -- do not consult
#  |      the backoff tagger.  This method should be overridden by
#  |      subclasses of SequentialBackoffTagger.
#  |
#  |      :rtype: str
#  |      :type tokens: list
#  |      :param tokens: The list of words that are being tagged.
#  |      :type index: int
#  |      :param index: The index of the word whose tag should be
#  |          returned.
#  |      :type history: list(str)
#  |      :param history: A list of the tags for all words before *index*.
#  |
#  |  size(self)
#  |      :return: The number of entries in the table used by this
#  |          tagger to map from contexts to tags.
#  |
#  |  unicode_repr = __repr__(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from SequentialBackoffTagger:
#  |
#  |  tag(self, tokens)
#  |      Determine the most appropriate tag sequence for the given
#  |      token sequence, and return a corresponding list of tagged
#  |      tokens.  A tagged token is encoded as a tuple ``(token, tag)``.
#  |
#  |      :rtype: list(tuple(str, str))
#  |
#  |  tag_one(self, tokens, index, history)
#  |      Determine an appropriate tag for the specified token, and
#  |      return that tag.  If this tagger is unable to determine a tag
#  |      for the specified token, then its backoff tagger is consulted.
#  |
#  |      :rtype: str
#  |      :type tokens: list
#  |      :param tokens: The list of words that are being tagged.
#  |      :type index: int
#  |      :param index: The index of the word whose tag should be
#  |          returned.
#  |      :type history: list(str)
#  |      :param history: A list of the tags for all words before *index*.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from SequentialBackoffTagger:
#  |
#  |  backoff
#  |      The backoff tagger for this tagger.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from nltk.tag.api.TaggerI:
#  |
#  |  evaluate(self, gold)
#  |      Score the accuracy of the tagger against the gold standard.
#  |      Strip the tags from the gold standard text, retag it using
#  |      the tagger, then compute the accuracy score.
#  |
#  |      :type gold: list(list(tuple(str, str)))
#  |      :param gold: The list of tagged sentences to score the tagger on.
#  |      :rtype: float
#  |
#  |  tag_sents(self, sentences)
#  |      Apply ``self.tag()`` to each element of *sentences*.  I.e.:
#  |
#  |          return [self.tag(sent) for sent in sentences]
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from nltk.tag.api.TaggerI:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
from nltk.corpus import brown
brown_tagged_sents = brown.tagged_sents(categories='adventure')
brown_sents = brown.sents(categories='adventure')
affixTagger = nltk.AffixTagger(brown_tagged_sents, affix_length=-3, min_stem_length=2)
affixTagger.tag(brown_sents[2021])
# Out:
# [('He', None),
#  ('stepped', 'VBD'),
#  ('inside', 'IN'),
#  ("Jess's", 'NP$'),
#  ('guard', 'IN'),
#  ('and', None),
#  ('landed', 'VBD'),
#  ('two', None),
#  ('blows', 'NNS'),
#  ('to', None),
#  ('the', None),
#  ('big', None),
#  ("man's", 'NP$'),
#  ('belly', 'RB'),
#  (',', None),
#  ('putting', 'VBG'),
#  ('everything', 'VBG'),
#  ('he', None),
#  ('had', None),
#  ('behind', 'IN'),
#  ('them', None),
#  ('.', None)]

# %%
affixTagger.evaluate(brown_tagged_sents)
# Out:
# 0.2180640881428283

# %%
affixTagger = nltk.AffixTagger(brown_tagged_sents, affix_length=-2, min_stem_length=2)
affixTagger.evaluate(brown_tagged_sents)
# Out:
# 0.2590781921490583

# %%
affixTagger = nltk.AffixTagger(brown_tagged_sents, affix_length=-4, min_stem_length=2)
affixTagger.evaluate(brown_tagged_sents)
# Out:
# 0.1723053849038101

# %%
affixTagger = nltk.AffixTagger(brown_tagged_sents, affix_length=-1, min_stem_length=2)
affixTagger.evaluate(brown_tagged_sents)
# Out:
# 0.2407343312855124

# %% [markdown]
# Affixes include prefixes and suffixes.
#
# On the brown sentences it performed better on affix length of -2, while the standard is -3.
#
# Thinking about it I use affixes of length 2 more often than not. A few include ed, es, im.
#
# While the only affixes I could think of are suffixes such as: ing and ies.

# %% [markdown]
# # 12.
# Train a bigram tagger with no backoff tagger, and run it on some of the training data. Next, run it on some new data. What happens to the performance of the tagger? Why?

# %%
len(brown_sents)
# Out:
# 4637

# %%
brown_tagged_sents = brown.tagged_sents(categories='adventure')
brown_sents = brown.sents(categories='adventure')
brown_train = brown_tagged_sents[:int(len(brown_sents)*.9)]
brown_test =brown_tagged_sents[int(len(brown_sents)*.9):]
unigram_tagger = nltk.UnigramTagger(brown_train)

# %%
unigram_tagger.evaluate(brown_train)
# Out:
# 0.9399707887049659

# %%
unigram_tagger.evaluate(brown_test)
# Out:
# 0.810929810929811

# %% [markdown]
# The performance decreases significantly. As we know models fit the data they know and perform worse on unseen data. Backoff tagers allow us to tag that unseen data in a way the inital model cannot. Since we are missing the backoff, we are missing that performance boost.

# %% [markdown]
# # 13
#
# We can use a dictionary to specify the values to be substituted into a formatting string. [Read Python's library documentation for formatting strings](https://docs.python.org/3/library/string.html) and use this method to display today's date in two different formats.

# %%
date = dict(day = "24", month = "5", year = "2021")
print("{}/{}/{}".format(date["day"] , date["month"], date["year"]) )
print("{}-{}-{}".format(date["day"] , date["month"], date["year"]) )
#I think this is what they wanted.
# Out:
# 24/5/2021
# 24-5-2021

# %% [markdown]
# # 14.
# Use sorted() and set() to get a sorted list of tags used in the Brown corpus, removing duplicates.

# %%
brown.tagged_words(categories = "news")
# Out:
# [('The', 'AT'), ('Fulton', 'NP-TL'), ...]

# %%
set(tag for (word,tag) in brown.tagged_words(categories = "news") if tag[:2].isalpha())
# Out:
# {'ABL',
#  'ABN',
#  'ABN-HL',
#  'ABX',
#  'AP',
#  'AP$',
#  'AP-HL',
#  'AP-TL',
#  'AT',
#  'AT-HL',
#  'AT-TL',
#  'BE',
#  'BE-HL',
#  'BED',
#  'BED*',
#  'BEDZ',
#  'BEDZ*',
#  'BEDZ-HL',
#  'BEG',
#  'BEM',
#  'BEN',
#  'BER',
#  'BER*',
#  'BER-HL',
#  'BER-TL',
#  'BEZ',
#  'BEZ*',
#  'BEZ-HL',
#  'CC',
#  'CC-HL',
#  'CC-TL',
#  'CD',
#  'CD$',
#  'CD-HL',
#  'CD-TL',
#  'CS',
#  'CS-HL',
#  'DO',
#  'DO*',
#  'DO-HL',
#  'DOD',
#  'DOD*',
#  'DOZ',
#  'DOZ*',
#  'DT',
#  'DT$',
#  'DT+BEZ',
#  'DT-HL',
#  'DTI',
#  'DTI-HL',
#  'DTS',
#  'DTX',
#  'EX',
#  'EX+BEZ',
#  'FW-*',
#  'FW-AT',
#  'FW-AT-HL',
#  'FW-AT-TL',
#  'FW-CC',
#  'FW-CD',
#  'FW-DT',
#  'FW-IN',
#  'FW-IN+AT-TL',
#  'FW-IN+NN',
#  'FW-IN+NN-TL',
#  'FW-IN-TL',
#  'FW-JJ',
#  'FW-JJ-TL',
#  'FW-NN',
#  'FW-NN-TL',
#  'FW-NNS',
#  'FW-PP$-NC',
#  'FW-VB',
#  'FW-VB-NC',
#  'FW-WDT',
#  'HV',
#  'HVD',
#  'HVD*',
#  'HVD-HL',
#  'HVG',
#  'HVN',
#  'HVZ',
#  'HVZ*',
#  'IN',
#  'IN-HL',
#  'IN-TL',
#  'JJ',
#  'JJ-HL',
#  'JJ-NC',
#  'JJ-TL',
#  'JJR',
#  'JJR-HL',
#  'JJR-NC',
#  'JJR-TL',
#  'JJS',
#  'JJS-TL',
#  'JJT',
#  'JJT-HL',
#  'MD',
#  'MD*',
#  'MD*-HL',
#  'MD+HV',
#  'MD-HL',
#  'MD-TL',
#  'NN',
#  'NN$',
#  'NN$-HL',
#  'NN$-TL',
#  'NN-HL',
#  'NN-NC',
#  'NN-TL',
#  'NN-TL-HL',
#  'NNS',
#  'NNS$',
#  'NNS$-HL',
#  'NNS$-TL',
#  'NNS-HL',
#  'NNS-TL',
#  'NNS-TL-HL',
#  'NP',
#  'NP$',
#  'NP$-TL',
#  'NP+BEZ',
#  'NP-HL',
#  'NP-TL',
#  'NP-TL-HL',
#  'NPS',
#  'NPS$',
#  'NPS$-TL',
#  'NPS-HL',
#  'NPS-TL',
#  'NR',
#  'NR$',
#  'NR$-TL',
#  'NR-HL',
#  'NR-TL',
#  'OD',
#  'OD-HL',
#  'OD-TL',
#  'PN',
#  'PN$',
#  'PN+HVZ',
#  'PN-HL',
#  'PP$',
#  'PP$$',
#  'PP$-TL',
#  'PPL',
#  'PPLS',
#  'PPO',
#  'PPS',
#  'PPS+BEZ',
#  'PPS+BEZ-HL',
#  'PPS+HVZ',
#  'PPS+MD',
#  'PPSS',
#  'PPSS+BEM',
#  'PPSS+BER',
#  'PPSS+HV',
#  'PPSS+HVD',
#  'PPSS+MD',
#  'PPSS-HL',
#  'QL',
#  'QL-TL',
#  'QLP',
#  'RB',
#  'RB$',
#  'RB+BEZ',
#  'RB-HL',
#  'RB-TL',
#  'RBR',
#  'RBT',
#  'RP',
#  'RP-HL',
#  'TO',
#  'TO-HL',
#  'TO-TL',
#  'UH',
#  'UH-TL',
#  'VB',
#  'VB+PPO',
#  'VB-HL',
#  'VB-TL',
#  'VBD',
#  'VBD-HL',
#  'VBD-TL',
#  'VBG',
#  'VBG-HL',
#  'VBG-TL',
#  'VBN',
#  'VBN-HL',
#  'VBN-TL',
#  'VBN-TL-HL',
#  'VBZ',
#  'VBZ-HL',
#  'WDT',
#  'WDT+BEZ',
#  'WP$',
#  'WPO',
#  'WPS',
#  'WPS+BEZ',
#  'WQL',
#  'WRB'}

# %%
from operator import itemgetter

# %%
sorted( set(tag for (word,tag) in brown.tagged_words(categories = "news") if tag[:2].isalpha() ) )
# Out:
# ['ABL',
#  'ABN',
#  'ABN-HL',
#  'ABX',
#  'AP',
#  'AP$',
#  'AP-HL',
#  'AP-TL',
#  'AT',
#  'AT-HL',
#  'AT-TL',
#  'BE',
#  'BE-HL',
#  'BED',
#  'BED*',
#  'BEDZ',
#  'BEDZ*',
#  'BEDZ-HL',
#  'BEG',
#  'BEM',
#  'BEN',
#  'BER',
#  'BER*',
#  'BER-HL',
#  'BER-TL',
#  'BEZ',
#  'BEZ*',
#  'BEZ-HL',
#  'CC',
#  'CC-HL',
#  'CC-TL',
#  'CD',
#  'CD$',
#  'CD-HL',
#  'CD-TL',
#  'CS',
#  'CS-HL',
#  'DO',
#  'DO*',
#  'DO-HL',
#  'DOD',
#  'DOD*',
#  'DOZ',
#  'DOZ*',
#  'DT',
#  'DT$',
#  'DT+BEZ',
#  'DT-HL',
#  'DTI',
#  'DTI-HL',
#  'DTS',
#  'DTX',
#  'EX',
#  'EX+BEZ',
#  'FW-*',
#  'FW-AT',
#  'FW-AT-HL',
#  'FW-AT-TL',
#  'FW-CC',
#  'FW-CD',
#  'FW-DT',
#  'FW-IN',
#  'FW-IN+AT-TL',
#  'FW-IN+NN',
#  'FW-IN+NN-TL',
#  'FW-IN-TL',
#  'FW-JJ',
#  'FW-JJ-TL',
#  'FW-NN',
#  'FW-NN-TL',
#  'FW-NNS',
#  'FW-PP$-NC',
#  'FW-VB',
#  'FW-VB-NC',
#  'FW-WDT',
#  'HV',
#  'HVD',
#  'HVD*',
#  'HVD-HL',
#  'HVG',
#  'HVN',
#  'HVZ',
#  'HVZ*',
#  'IN',
#  'IN-HL',
#  'IN-TL',
#  'JJ',
#  'JJ-HL',
#  'JJ-NC',
#  'JJ-TL',
#  'JJR',
#  'JJR-HL',
#  'JJR-NC',
#  'JJR-TL',
#  'JJS',
#  'JJS-TL',
#  'JJT',
#  'JJT-HL',
#  'MD',
#  'MD*',
#  'MD*-HL',
#  'MD+HV',
#  'MD-HL',
#  'MD-TL',
#  'NN',
#  'NN$',
#  'NN$-HL',
#  'NN$-TL',
#  'NN-HL',
#  'NN-NC',
#  'NN-TL',
#  'NN-TL-HL',
#  'NNS',
#  'NNS$',
#  'NNS$-HL',
#  'NNS$-TL',
#  'NNS-HL',
#  'NNS-TL',
#  'NNS-TL-HL',
#  'NP',
#  'NP$',
#  'NP$-TL',
#  'NP+BEZ',
#  'NP-HL',
#  'NP-TL',
#  'NP-TL-HL',
#  'NPS',
#  'NPS$',
#  'NPS$-TL',
#  'NPS-HL',
#  'NPS-TL',
#  'NR',
#  'NR$',
#  'NR$-TL',
#  'NR-HL',
#  'NR-TL',
#  'OD',
#  'OD-HL',
#  'OD-TL',
#  'PN',
#  'PN$',
#  'PN+HVZ',
#  'PN-HL',
#  'PP$',
#  'PP$$',
#  'PP$-TL',
#  'PPL',
#  'PPLS',
#  'PPO',
#  'PPS',
#  'PPS+BEZ',
#  'PPS+BEZ-HL',
#  'PPS+HVZ',
#  'PPS+MD',
#  'PPSS',
#  'PPSS+BEM',
#  'PPSS+BER',
#  'PPSS+HV',
#  'PPSS+HVD',
#  'PPSS+MD',
#  'PPSS-HL',
#  'QL',
#  'QL-TL',
#  'QLP',
#  'RB',
#  'RB$',
#  'RB+BEZ',
#  'RB-HL',
#  'RB-TL',
#  'RBR',
#  'RBT',
#  'RP',
#  'RP-HL',
#  'TO',
#  'TO-HL',
#  'TO-TL',
#  'UH',
#  'UH-TL',
#  'VB',
#  'VB+PPO',
#  'VB-HL',
#  'VB-TL',
#  'VBD',
#  'VBD-HL',
#  'VBD-TL',
#  'VBG',
#  'VBG-HL',
#  'VBG-TL',
#  'VBN',
#  'VBN-HL',
#  'VBN-TL',
#  'VBN-TL-HL',
#  'VBZ',
#  'VBZ-HL',
#  'WDT',
#  'WDT+BEZ',
#  'WP$',
#  'WPO',
#  'WPS',
#  'WPS+BEZ',
#  'WQL',
#  'WRB']

# %% [markdown]
# # 15
# Write programs to process the Brown Corpus and find answers to the following questions:
#
# - Which nouns are more common in their plural form, rather than their singular form? (Only consider regular plurals, formed with the -s suffix.)
# - Which word has the greatest number of distinct tags. What are they, and what do they represent?
# - List tags in order of decreasing frequency. What do the 20 most frequent tags represent?
# - Which tags are nouns most commonly found after? What do these tags represent?

# %%
#Use the conditional frequency for this problem. 
tagged_words = brown.tagged_words(categories = "news")
cdf = nltk.ConditionalFreqDist((tag, word) for (word, tag) in tagged_words)
cdf["NNS"]
# Out:
# FreqDist({'years': 101, 'members': 69, 'people': 52, 'sales': 51, 'men': 46, 'children': 45, 'months': 42, 'days': 37, 'schools': 36, 'laws': 30, ...})

# %%
NNS = [ (word[:-1],freq) for (word, freq) in cdf["NNS"].items() if "s" in word[-2:] ]
NNS
# Out:
# [('irregularitie', 3),
#  ('presentment', 1),
#  ('thank', 5),
#  ('report', 9),
#  ('voter', 12),
#  ('law', 30),
#  ('legislator', 8),
#  ('topic', 2),
#  ('department', 2),
#  ('practice', 6),
#  ('government', 5),
#  ('office', 4),
#  ('policie', 8),
#  ('step', 8),
#  ('fund', 27),
#  ('service', 18),
#  ('home', 9),
#  ('item', 4),
#  ('countie', 13),
#  ('juror', 4),
#  ('taxpayer', 5),
#  ('appraiser', 1),
#  ('guardian', 2),
#  ('administrator', 1),
#  ('fee', 12),
#  ('procedure', 5),
#  ('recommendation', 6),
#  ('jurie', 1),
#  ('citizen', 6),
#  ('action', 6),
#  ('ward', 1),
#  ('cost', 17),
#  ('servant', 5),
#  ('criticism', 2),
#  ('influence', 1),
#  ('concessionaire', 1),
#  ('price', 19),
#  ('matter', 3),
#  ('deputie', 2),
#  ('official', 12),
#  ('employe', 9),
#  ('farm', 3),
#  ('Attorney', 2),
#  ('response', 1),
#  ('petition', 5),
#  ('precinct', 4),
#  ('signature', 5),
#  ('dissent', 1),
#  ('course', 5),
#  ('name', 6),
#  ('candidate', 10),
#  ('relation', 15),
#  ('year', 101),
#  ('area', 12),
#  ('adjustment', 2),
#  ('chamber', 2),
#  ('bond', 28),
#  ('court', 6),
#  ('sale', 51),
#  ('contract', 3),
#  ('highway', 3),
#  ('one', 8),
#  ('authoritie', 7),
#  ('road', 9),
#  ('plan', 15),
#  ('allowance', 3),
#  ('detail', 3),
#  ('raise', 3),
#  ('session', 6),
#  ('member', 69),
#  ('vote', 6),
#  ('poll', 3),
#  ('call', 7),
#  ('threat', 1),
#  ('day', 37),
#  ('protest', 1),
#  ('banker', 8),
#  ('rule', 10),
#  ('question', 8),
#  ('witnesse', 7),
#  ('dollar', 15),
#  ('mean', 13),
#  ('book', 12),
#  ('account', 2),
#  ('stock', 9),
#  ('person', 24),
#  ('bank', 4),
#  ('firm', 15),
#  ('companie', 18),
#  ('corporation', 2),
#  ('obligation', 4),
#  ('depositor', 1),
#  ('customer', 7),
#  ('million', 9),
#  ('pocket', 2),
#  ('Senator', 1),
#  ('school', 36),
#  ('student', 21),
#  ('saving', 3),
#  ('scholastic', 1),
#  ('parimutuel', 1),
#  ('folk', 2),
#  ('letter', 12),
#  ('ponie', 1),
#  ('citie', 6),
#  ('bill', 16),
#  ('committee', 4),
#  ('act', 7),
#  ('district', 4),
#  ('senator', 4),
#  ('gift', 3),
#  ('donation', 2),
#  ('retailer', 2),
#  ('taxe', 10),
#  ('broker', 2),
#  ('site', 3),
#  ('reservoir', 1),
#  ('vacancie', 1),
#  ('election', 3),
#  ('representative', 5),
#  ('two-third', 3),
#  ('majoritie', 1),
#  ('Opponent', 1),
#  ('proposal', 9),
#  ('need', 8),
#  ('place', 4),
#  ('Statement', 1),
#  ('defender', 1),
#  ('method', 10),
#  ('hour', 22),
#  ('teacher', 7),
#  ('subject', 3),
#  ('co-signer', 1),
#  ('regent', 1),
#  ('Principal', 1),
#  ('cause', 3),
#  ('recipient', 2),
#  ('problem', 19),
#  ('case', 17),
#  ('skill', 3),
#  ('breakup', 1),
#  ('relative', 2),
#  ('parent', 4),
#  ('project', 5),
#  ('defendant', 9),
#  ('statement', 9),
#  ('observer', 2),
#  ('attorney', 5),
#  ('other', 14),
#  ('draft', 2),
#  ('portion', 1),
#  ('aid', 1),
#  ('adviser', 7),
#  ('decision', 6),
#  ('demand', 5),
#  ('right', 3),
#  ('proceeding', 2),
#  ('hearing', 3),
#  ('subpena', 1),
#  ('individual', 5),
#  ('judge', 5),
#  ('processe', 3),
#  ('worker', 15),
#  ('program', 12),
#  ('request', 4),
#  ('grant', 13),
#  ('scholarship', 4),
#  ('boost', 1),
#  ('Official', 2),
#  ('benefit', 4),
#  ('figure', 1),
#  ('part', 6),
#  ('system', 8),
#  ('stay', 1),
#  ('state', 22),
#  ('requirement', 4),
#  ('hospital', 3),
#  ('contribution', 8),
#  ('facilitie', 10),
#  ('element', 3),
#  ('line', 17),
#  ('Legislator', 2),
#  ('aye', 1),
#  ('noe', 1),
#  ('appointment', 2),
#  ('selection', 1),
#  ('discussion', 3),
#  ('meeting', 5),
#  ('change', 10),
#  ('minister', 2),
#  ('power', 1),
#  ('difficultie', 3),
#  ('tragedie', 1),
#  ('allie', 4),
#  ('circumstance', 5),
#  ('trouble', 5),
#  ('week', 25),
#  ('critic', 1),
#  ('position', 6),
#  ('surprise', 2),
#  ('car', 18),
#  ('manifestation', 1),
#  ('arm', 8),
#  ('speeche', 1),
#  ('point', 10),
#  ('setback', 1),
#  ('correspondent', 2),
#  ('spot', 2),
#  ('event', 4),
#  ('month', 42),
#  ('submarine', 5),
#  ('water', 4),
#  ('societie', 2),
#  ('direction', 1),
#  ('countrie', 28),
#  ('force', 16),
#  ('attack', 4),
#  ('modification', 1),
#  ('error', 8),
#  ('reform', 4),
#  ('confrontation', 1),
#  ('blunder', 1),
#  ('educator', 1),
#  ('group', 12),
#  ('effort', 22),
#  ('condition', 7),
#  ('victorie', 4),
#  ('opinion', 3),
#  ('professor', 1),
#  ('channel', 1),
#  ('Policie', 1),
#  ('negotiation', 11),
#  ('nation', 12),
#  ('losse', 4),
#  ('neighbor', 6),
#  ('idea', 5),
#  ('communitie', 4),
#  ('arrest', 2),
#  ('offender', 1),
#  ('resident', 6),
#  ('radio', 1),
#  ('siren', 1),
#  ('truck', 6),
#  ('ground', 3),
#  ('interval', 3),
#  ('thing', 10),
#  ('classe', 3),
#  ('revision', 1),
#  ('view', 5),
#  ('officer', 18),
#  ('statute', 1),
#  ('instance', 2),
#  ('time', 18),
#  ('type', 4),
#  ('food', 2),
#  ('store', 4),
#  ('supermarket', 2),
#  ('shop', 1),
#  ('thousand', 7),
#  ('license', 2),
#  ('outlet', 1),
#  ('Liberal', 1),
#  ('conservative', 2),
#  ('partie', 14),
#  ('utilitie', 2),
#  ('resource', 6),
#  ('increase', 4),
#  ('manufacturer', 10),
#  ('canvasser', 2),
#  ('justice', 1),
#  ('post', 5),
#  ('pretense', 1),
#  ('signer', 1),
#  ('motorist', 3),
#  ('offense', 3),
#  ('fine', 1),
#  ('boo', 2),
#  ('remain', 2),
#  ('issue', 9),
#  ('use', 1),
#  ('minute', 25),
#  ('barb', 1),
#  ('crise', 1),
#  ('way', 10),
#  ('vehicle', 1),
#  ('intention', 6),
#  ('opponent', 1),
#  ('leader', 22),
#  ('manager', 8),
#  ('ballot', 1),
#  ('machine', 7),
#  ('result', 3),
#  ('fire', 2),
#  ('technique', 2),
#  ('plow', 1),
#  ('unit', 8),
#  ('warden', 2),
#  ('slogan', 1),
#  ('sign', 3),
#  ('hoodlum', 2),
#  ('1940', 1),
#  ('tract', 1),
#  ('municipalitie', 1),
#  ('colleague', 1),
#  ('term', 7),
#  ('elephant', 2),
#  ('tusk', 1),
#  ('retirement', 1),
#  ('1920', 1),
#  ('mate', 6),
#  ('choice', 1),
#  ('talk', 7),
#  ('interview', 3),
#  ('reporter', 4),
#  ('politician', 4),
#  ('reason', 12),
#  ('scandal', 1),
#  ('work', 4),
#  ('investigation', 1),
#  ('newspaper', 2),
#  ('forecast', 2),
#  ('mortgage', 2),
#  ('down-payment', 1),
#  ('familie', 8),
#  ('slum', 1),
#  ('college', 9),
#  ('dormitorie', 2),
#  ('loan', 6),
#  ('language', 3),
#  ('agencie', 8),
#  ('universitie', 4),
#  ('Interview', 1),
#  ('goal', 4),
#  ('estimate', 3),
#  ('technician', 4),
#  ('expert', 3),
#  ('job', 10),
#  ('inhabitant', 2),
#  ('affair', 8),
#  ('neutralist', 1),
#  ('half-brother', 1),
#  ('delegation', 1),
#  ('diplomat', 1),
#  ('consultation', 1),
#  ('tactic', 1),
#  ('principle', 2),
#  ('factor', 5),
#  ('Thousand', 1),
#  ('seat', 4),
#  ('hundred', 5),
#  ('ceremonie', 5),
#  ('building', 5),
#  ('shrine', 1),
#  ('monument', 1),
#  ('chapter', 1),
#  ('suffragette', 1),
#  ('soldier', 2),
#  ('record', 8),
#  ('track', 1),
#  ('spectator', 5),
#  ('statue', 1),
#  ('branche', 3),
#  ('academie', 1),
#  ('representation', 1),
#  ('territorie', 1),
#  ('development', 2),
#  ('foe', 2),
#  ('friend', 11),
#  ('edge', 1),
#  ('job-seeker', 1),
#  ('commitment', 3),
#  ('lawmaker', 2),
#  ('odd', 2),
#  ('eye', 5),
#  ('crossroad', 1),
#  ('camp', 2),
#  ('loyalist', 1),
#  ('independent', 1),
#  ('rank', 2),
#  ('Report', 1),
#  ('stresse', 1),
#  ('finance', 2),
#  ('revenue', 13),
#  ('inconsistencie', 1),
#  ('hand', 12),
#  ('politico', 1),
#  ('purpose', 3),
#  ('expense', 7),
#  ('alternative', 1),
#  ('trim', 1),
#  ('allegation', 1),
#  ('follower', 2),
#  ('affiliation', 2),
#  ('bid', 3),
#  ('Estimate', 1),
#  ('contractor', 2),
#  ('shortcut', 1),
#  ('disclosure', 2),
#  ('voucher', 1),
#  ('charge', 9),
#  ('director', 5),
#  ('violation', 2),
#  ('joint', 2),
#  ('repair', 1),
#  ('rate', 9),
#  ('hotel', 6),
#  ('room', 5),
#  ('permit', 1),
#  ('house', 6),
#  ('dwelling', 2),
#  ('accomodation', 1),
#  ('dog', 3),
#  ('male', 1),
#  ('female', 1),
#  ('owner', 10),
#  ('catcher', 1),
#  ('bite', 1),
#  ('Petition', 1),
#  ('agreement', 5),
#  ('redeveloper', 1),
#  ('hazard', 2),
#  ('pedestrian', 2),
#  ('apartment', 6),
#  ('park', 3),
#  ('churche', 13),
#  ('cluster', 2),
#  ('builder', 7),
#  ('sector', 1),
#  ('walkway', 1),
#  ('bridge', 2),
#  ('fighter', 3),
#  ('teamster', 4),
#  ('fracture', 1),
#  ('ankle', 2),
#  ('son', 4),
#  ('guard', 2),
#  ('pledge', 1),
#  ('path', 2),
#  ('door', 5),
#  ('people', 1),
#  ('good', 5),
#  ('product', 16),
#  ('lot', 3),
#  ('mother', 2),
#  ('blueprint', 1),
#  ('specification', 1),
#  ('speaker', 2),
#  ('Poll', 1),
#  ('belief', 3),
#  ('delegate', 7),
#  ('trend', 2),
#  ('truth', 1),
#  ('live', 3),
#  ('scripture', 1),
#  ('miracle', 1),
#  ('mission', 1),
#  ('Survey', 1),
#  ('babie', 2),
#  ('center', 5),
#  ('pastor', 1),
#  ('volunteer', 5),
#  ('graduate', 2),
#  ('apprentice', 1),
#  ('motion', 4),
#  ('Denial', 1),
#  ('trial', 1),
#  ('conspirator', 2),
#  ('mail', 3),
#  ('club', 3),
#  ('Indication', 1),
#  ('frame', 2),
#  ('hit', 11),
#  ('batter', 1),
#  ('run', 30),
#  ('start', 6),
#  ('blow', 1),
#  ('offering', 1),
#  ('pitcher', 3),
#  ('double', 4),
#  ('chore', 4),
#  ('safetie', 1),
#  ('ball', 6),
#  ('pinch-hitter', 1),
#  ('pitche', 1),
#  ('tallie', 2),
#  ('runner', 1),
#  ('homer', 3),
#  ('player', 12),
#  ('pound', 4),
#  ('hitter', 1),
#  ('specialist', 1),
#  ('champion', 6),
#  ('crowd', 3),
#  ('game', 22),
#  ('coache', 4),
#  ('teammate', 2),
#  ('hurler', 1),
#  ('colt', 1),
#  ('stage', 3),
#  ('furlong', 1),
#  ('celebrant', 1),
#  ('steward', 2),
#  ('horse', 1),
#  ('race', 1),
#  ('yard', 22),
#  ('third', 1),
#  ('tenth', 1),
#  ('play', 3),
#  ('pad', 1),
#  ('trie', 4),
#  ('conversion', 2),
#  ('boy', 9),
#  ('completion', 3),
#  ('attempt', 3),
#  ('kid', 5),
#  ('performance', 3),
#  ('stop', 2),
#  ('thrust', 1),
#  ('reserve', 2),
#  ('sweat-suit', 1),
#  ('reckoning', 1),
#  ('collector', 1),
#  ('quarterback', 1),
#  ('linebacker', 1),
#  ('movie', 4),
#  ('passe', 4),
#  ('touchdown', 1),
#  ('strike', 2),
#  ('ball-carrier', 1),
#  ('statistic', 2),
#  ('tosse', 1),
#  ('average', 3),
#  ('check', 2),
#  ('baseball', 1),
#  ('league', 3),
#  ('test', 3),
#  ('viewer', 2),
#  ('inning', 3),
#  ('base', 7),
#  ('flie', 1),
#  ('light', 2),
#  ('fan', 3),
#  ('reflexe', 2),
#  ('at-bat', 1),
#  ('chance', 3),
#  ('masse', 3),
#  ('heroic', 1),
#  ('tongue', 2),
#  ('feat', 1),
#  ('achievement', 1),
#  ('heart', 1),
#  ('guy', 1),
#  ('rookie', 2),
#  ('laurel', 1),
#  ('lefthander', 1),
#  ('slugger', 2),
#  ('merit', 2),
#  ('season', 3),
#  ('ruler', 1),
#  ('afternoon', 1),
#  ('injurie', 3),
#  ('champ', 1),
#  ('bleacher', 2),
#  ('end', 2),
#  ('aerial', 1),
#  ('cufflink', 1),
#  ('award', 4),
#  ('sport', 6),
#  ('writer', 4),
#  ('personalitie', 2),
#  ('barrier', 2),
#  ('disappointment', 1),
#  ('major', 3),
#  ('matche', 2),
#  ('tournament', 3),
#  ('incompetent', 1),
#  ('frustration', 2),
#  ('pixie', 1),
#  ('zombie', 1),
#  ('banshee', 1),
#  ('bound', 2),
#  ('shot', 4),
#  ('stroke', 8),
#  ('duffer', 2),
#  ('hacker', 1),
#  ('echoe', 1),
#  ('nerve', 2),
#  ('string', 4),
#  ('competitor', 2),
#  ('rain', 1),
#  ('father', 1),
#  ('amendment', 1),
#  ('team', 5),
#  ('date', 3),
#  ('bat', 2),
#  ('plunker', 1),
#  ('triumph', 2),
#  ('Speaker', 1),
#  ('word', 9),
#  ('honor', 5),
#  ('fault', 1),
#  ('defeat', 1),
#  ('trip', 3),
#  ('cow', 1),
#  ('talent', 2),
#  ('career', 3),
#  ('expectation', 1),
#  ('height', 2),
#  ("rbi'", 1),
#  ('peak', 1),
#  ('professional', 1),
#  ('sight', 1),
#  ('holiday', 2),
#  ('uncle', 1),
#  ('aunt', 1),
#  ('huzzah', 1),
#  ('ear', 1),
#  ('embassie', 1),
#  ('bushe', 2),
#  ('activitie', 9),
#  ('dancer', 3),
#  ('dervishe', 1),
#  ('invitation', 2),
#  ('singer', 1),
#  ('song', 1),
#  ('costume', 5),
#  ('tree', 2),
#  ('street', 7),
#  ('train', 1),
#  ('shelter', 1),
#  ('pub', 1),
#  ('night', 1),
#  ('ethic', 1),
#  ('moral', 1),
#  ('appearance', 3),
#  ('gal', 1),
#  ('phonie', 1),
#  ('phone', 1),
#  ('contrib', 1),
#  ('exhibitor', 1),
#  ('screening', 1),
#  ('touche', 1),
#  ('charitie', 2),
#  ('holder', 2),
#  ('clashe', 1),
#  ('bomb', 1),
#  ('peasant', 1),
#  ('struggle', 1),
#  ('role', 2),
#  ('medic', 1),
#  ('doing', 1),
#  ('lesson', 1),
#  ('suggestion', 3),
#  ('boxe', 3),
#  ('Member', 5),
#  ('guest', 14),
#  ('suite', 1),
#  ('Grandparent', 2),
#  ('Cocktail', 2),
#  ('Guest', 3),
#  ('junior', 2),
#  ('decoration', 2),
#  ('qualitie', 2),
#  ('task', 2),
#  ('alcoholic', 2),
#  ('parolee', 2),
#  ('schedule', 3),
#  ('ticket', 5),
#  ('concert', 6),
#  ('cookie', 3),
#  ('sweet', 1),
#  ('motel-keeper', 1),
#  ('suitcase', 1),
#  ('mile', 10),
#  ('motel', 4),
#  ('station', 2),
#  ('wagon', 1),
#  ('restaurant', 1),
#  ('stand', 2),
#  ('accommodation', 2),
#  ('taste', 1),
#  ('peculiaritie', 1),
#  ('pool', 3),
#  ('adult', 3),
#  ('Motorist', 1),
#  ('tourist', 1),
#  ('chair', 4),
#  ('towel', 1),
#  ('ant', 2),
#  ('Parent', 2),
#  ('attendant', 1),
#  ('applique', 1),
#  ('gardenia', 1),
#  ('bridesmaid', 1),
#  ('newlywed', 1),
#  ('orchid', 1),
#  ('studie', 2),
#  ('prospect', 7),
#  ('hat', 3),
#  ('festivitie', 4),
#  ('oyster', 2),
#  ('specialtie', 1),
#  ('effect', 1),
#  ('flower', 3),
#  ('reproduction', 2),
#  ('shelve', 1),
#  ('headquarter', 8),
#  ('suburb', 1),
#  ('bundle', 3),
#  ('dinner', 1),
#  ('fund-raiser', 1),
#  ('husband', 1),
#  ('hostesse', 1),
#  ('arrangement', 4),
#  ('dutie', 2),
#  ('aide', 3),
#  ('controller', 1),
#  ('Model', 1),
#  ('decade', 2),
#  ('temperature', 1),
#  ('poster', 2),
#  ('painting', 5),
#  ('sponsor', 1),
#  ('artist', 5),
#  ('Proceed', 1),
#  ('level', 5),
#  ('host', 1),
#  ('ladie', 3),
#  ('ballgown', 1),
#  ('dance', 1),
#  ('panel', 5),
#  ('tier', 1),
#  ('slipper', 1),
#  ('maid', 1),
#  ('ashe', 1),
#  ('rose', 1),
#  ('thread', 1),
#  ('sequin', 1),
#  ('bead', 1),
#  ('cut', 4),
#  ('lay-off', 3),
#  ('employee', 11),
#  ('supervisor', 1),
#  ('union', 13),
#  ('wage', 11),
#  ('burn', 5),
#  ('remark', 2),
#  ('discrepancie', 1),
#  ('bodie', 4),
#  ('suit', 4),
#  ('misunderstanding', 1),
#  ('board', 3),
#  ('Doctor', 1),
#  ('deficiencie', 1),
#  ('crew', 1),
#  ('storm', 1),
#  ('improvement', 4),
#  ('operation', 10),
#  ('laborer', 2),
#  ('tire', 3),
#  ('chain', 1),
#  ('merchant', 1),
#  ('observation', 1),
#  ('supplie', 6),
#  ('blade', 1),
#  ('victim', 3),
#  ('detective', 6),
#  ('shooting', 1),
#  ('brother', 3),
#  ('spirit', 1),
#  ('seeker', 1),
#  ('component', 1),
#  ('structure', 2),
#  ('Other', 4),
#  ('stair', 1),
#  ('balconie', 1),
#  ('secret', 13),
#  ('agent', 3),
#  ('design', 9),
#  ('sub', 1),
#  ('strongroom', 1),
#  ('dot', 1),
#  ('mark', 1),
#  ('1950', 2),
#  ('1960', 1),
#  ('drawing', 1),
#  ('lawyer', 3),
#  ('client', 2),
#  ('reactor', 1),
#  ('turbine', 1),
#  ('destroyer', 2),
#  ('ship', 2),
#  ('torpedoe', 1),
#  ('Design', 1),
#  ('signal', 1),
#  ('wavelength', 1),
#  ('code', 1),
#  ('lighter', 1),
#  ('narcotic', 6),
#  ('indictment', 2),
#  ('addict', 1),
#  ('peddler', 1),
#  ('rivalrie', 2),
#  ('criminal', 1),
#  ('jealousie', 1),
#  ('grievance', 1),
#  ('mention', 1),
#  ('compensation', 1),
#  ('comment', 2),
#  ('youth', 4),
#  ('homeowner', 1),
#  ('casket', 1),
#  ('fume', 1),
#  ('girl', 6),
#  ('arrear', 1),
#  ('meal', 3),
#  ('surpluse', 1),
#  ('proceed', 2),
#  ('troop', 10),
#  ('move', 4),
#  ('assault', 2),
#  ('source', 1),
#  ('claim', 2),
#  ('squad', 1),
#  ('tribunal', 1),
#  ('collaborator', 1),
#  ('execution', 2),
#  ('rebel', 3),
#  ('rifle', 2),
#  ('jail', 1),
#  ('priest', 1),
#  ('prisoner', 1),
#  ('by-law', 2),
#  ('institution', 10),
#  ('standard', 4),
#  ('privilege', 3),
#  ('provision', 1),
#  ('obstacle', 2),
#  ('endowment', 2),
#  ('document', 1),
#  ('application', 4),
#  ('occupant', 1),
#  ('laceration', 1),
#  ('bruise', 1),
#  ('stand-in', 3),
#  ('theater', 6),
#  ('operator', 2),
#  ('profit', 2),
#  ('Survivor', 5),
#  ('sister', 3),
#  ('daughter', 5),
#  ('scratche', 3),
#  ('uniform', 1),
#  ('count', 2),
#  ('doctor', 1),
#  ('entrie', 1),
#  ('transfer', 1),
#  ('employment', 1),
#  ('pension', 2),
#  ('acre', 8),
#  ('plane', 2),
#  ('crop', 3),
#  ('human', 2),
#  ('Student', 2),
#  ('computer', 1),
#  ('camera', 1),
#  ('engineer', 2),
#  ('crashe', 1),
#  ('Trooper', 1),
#  ('flame', 1),
#  ('commissioner', 3),
#  ('wheel', 1),
#  ('argument', 1),
#  ('weaknesse', 1),
#  ('communication', 1),
#  ('robberie', 1),
#  ('paper', 1),
#  ('Employe', 2),
#  ('function', 1),
#  ('entertainer', 1),
#  ('Service', 1),
#  ('spice', 1),
#  ('stockholder', 1),
#  ('teenager', 3),
#  ('youngster', 3),
#  ('businesse', 2),
#  ('Participant', 1),
#  ('advisor', 2),
#  ('Advisor', 1),
#  ('show', 3),
#  ('skie', 2),
#  ('fairgoer', 1),
#  ('Finalist', 1),
#  ('ribbon', 3),
#  ('blue', 4),
#  ('egg', 1),
#  ('championship', 1),
#  ('appeal', 6),
#  ('assessor', 1),
#  ('assessment', 1),
#  ('Appeal', 1),
#  ('propertie', 1),
#  ('pain', 2),
#  ('Thieve', 1),
#  ('fur', 1),
#  ('jewel', 1),
#  ('coin', 2),
#  ('intruder', 1),
#  ('ring', 2),
#  ('earring', 2),
#  ('thieve', 1),
#  ('Drawer', 1),
#  ('cabinet', 1),
#  ('bedroom', 1),
#  ('plant', 5),
#  ('collection', 4),
#  ('rib', 1),
#  ('damage', 1),
#  ('lieutenant', 2),
#  ('Person', 1),
#  ('Score', 1),
#  ('contributor', 1),
#  ('pennie', 1),
#  ('nickel', 1),
#  ('dime', 2),
#  ('quarter', 2),
#  ('alteration', 1),
#  ('bed', 3),
#  ('incident', 1),
#  ('connection', 3),
#  ('control', 1),
#  ('mistake', 2),
#  ('experiment', 1),
#  ('farmer', 5),
#  ('bird', 4),
#  ('enemie', 1),
#  ('insect', 1),
#  ('rodent', 1),
#  ('grape', 2),
#  ('blueberrie', 1),
#  ('restriction', 3),
#  ('wetland', 1),
#  ('pesticide', 1),
#  ('tideland', 1),
#  ('animal', 1),
#  ('pilot', 3),
#  ('rocket-bomb', 1),
#  ('surface', 1),
#  ('wing', 1),
#  ('aileron', 1),
#  ('Moment', 1),
#  ('flight', 1),
#  ('missile', 3),
#  ('Pilot', 1),
#  ('glider', 1),
#  ('Nation', 1),
#  ('weapon', 6),
#  ('Government', 1),
#  ('buddie', 1),
#  ('chief', 1),
#  ('prosecutor', 2),
#  ('gangster', 1),
#  ('payment', 8),
#  ('janitor', 2),
#  ('factorie', 2),
#  ('amount', 2),
#  ('lien', 1),
#  ('share', 19),
#  ('Investor', 3),
#  ('inquirie', 3),
#  ('Letter', 1),
#  ('ream', 1),
#  ('underwriter', 2),
#  ('kind', 1),
#  ('earning', 7),
#  ('investor', 7),
#  ('run-up', 1),
#  ('price-earning', 2),
#  ('Food', 1),
#  ('ratio', 1),
#  ('executive', 1),
#  ('abilitie', 1),
#  ('merger', 2),
#  ('buyer', 2),
#  ('ton', 1),
#  ('gin', 1),
#  ("1900'", 1),
#  ('drier', 3),
#  ('cleaner', 2),
#  ('Headquarter', 3),
#  ('Factorie', 1),
#  ('heater', 1),
#  ('extractor', 1),
#  ('separator', 1),
#  ('saw', 2),
#  ('bearing', 1),
#  ('doldrum', 1),
#  ('Registration', 1),
#  ('dealer', 10),
#  ('maker', 1),
#  ...]

# %%
sorted(NNS, key = itemgetter(1) , reverse = True)
# Out:
# [('year', 101),
#  ('member', 69),
#  ('sale', 51),
#  ('month', 42),
#  ('day', 37),
#  ('school', 36),
#  ('law', 30),
#  ('run', 30),
#  ('bond', 28),
#  ('countrie', 28),
#  ('fund', 27),
#  ('week', 25),
#  ('minute', 25),
#  ('person', 24),
#  ('hour', 22),
#  ('state', 22),
#  ('effort', 22),
#  ('leader', 22),
#  ('game', 22),
#  ('yard', 22),
#  ('librarie', 22),
#  ('student', 21),
#  ('price', 19),
#  ('problem', 19),
#  ('share', 19),
#  ('service', 18),
#  ('companie', 18),
#  ('car', 18),
#  ('officer', 18),
#  ('time', 18),
#  ('cost', 17),
#  ('case', 17),
#  ('line', 17),
#  ('bill', 16),
#  ('force', 16),
#  ('product', 16),
#  ('relation', 15),
#  ('plan', 15),
#  ('dollar', 15),
#  ('firm', 15),
#  ('worker', 15),
#  ('other', 14),
#  ('partie', 14),
#  ('guest', 14),
#  ('countie', 13),
#  ('mean', 13),
#  ('grant', 13),
#  ('revenue', 13),
#  ('churche', 13),
#  ('union', 13),
#  ('secret', 13),
#  ('voter', 12),
#  ('fee', 12),
#  ('official', 12),
#  ('area', 12),
#  ('book', 12),
#  ('letter', 12),
#  ('program', 12),
#  ('group', 12),
#  ('nation', 12),
#  ('reason', 12),
#  ('hand', 12),
#  ('player', 12),
#  ('negotiation', 11),
#  ('friend', 11),
#  ('hit', 11),
#  ('employee', 11),
#  ('wage', 11),
#  ('candidate', 10),
#  ('rule', 10),
#  ('taxe', 10),
#  ('method', 10),
#  ('facilitie', 10),
#  ('change', 10),
#  ('point', 10),
#  ('thing', 10),
#  ('manufacturer', 10),
#  ('way', 10),
#  ('job', 10),
#  ('owner', 10),
#  ('mile', 10),
#  ('operation', 10),
#  ('troop', 10),
#  ('institution', 10),
#  ('dealer', 10),
#  ('turnpike', 10),
#  ('report', 9),
#  ('home', 9),
#  ('employe', 9),
#  ('road', 9),
#  ('stock', 9),
#  ('million', 9),
#  ('proposal', 9),
#  ('defendant', 9),
#  ('statement', 9),
#  ('issue', 9),
#  ('college', 9),
#  ('charge', 9),
#  ('rate', 9),
#  ('boy', 9),
#  ('word', 9),
#  ('activitie', 9),
#  ('design', 9),
#  ('legislator', 8),
#  ('policie', 8),
#  ('step', 8),
#  ('one', 8),
#  ('banker', 8),
#  ('question', 8),
#  ('need', 8),
#  ('system', 8),
#  ('contribution', 8),
#  ('arm', 8),
#  ('error', 8),
#  ('manager', 8),
#  ('unit', 8),
#  ('familie', 8),
#  ('agencie', 8),
#  ('affair', 8),
#  ('record', 8),
#  ('stroke', 8),
#  ('headquarter', 8),
#  ('acre', 8),
#  ('payment', 8),
#  ('authoritie', 7),
#  ('call', 7),
#  ('witnesse', 7),
#  ('customer', 7),
#  ('act', 7),
#  ('teacher', 7),
#  ('adviser', 7),
#  ('condition', 7),
#  ('thousand', 7),
#  ('machine', 7),
#  ('term', 7),
#  ('talk', 7),
#  ('expense', 7),
#  ('builder', 7),
#  ('delegate', 7),
#  ('base', 7),
#  ('street', 7),
#  ('prospect', 7),
#  ('earning', 7),
#  ('investor', 7),
#  ('order', 7),
#  ('piece', 7),
#  ('practice', 6),
#  ('recommendation', 6),
#  ('citizen', 6),
#  ('action', 6),
#  ('name', 6),
#  ('court', 6),
#  ('session', 6),
#  ('vote', 6),
#  ('citie', 6),
#  ('decision', 6),
#  ('part', 6),
#  ('position', 6),
#  ('neighbor', 6),
#  ('resident', 6),
#  ('truck', 6),
#  ('resource', 6),
#  ('intention', 6),
#  ('mate', 6),
#  ('loan', 6),
#  ('hotel', 6),
#  ('house', 6),
#  ('apartment', 6),
#  ('start', 6),
#  ('ball', 6),
#  ('champion', 6),
#  ('sport', 6),
#  ('concert', 6),
#  ('supplie', 6),
#  ('detective', 6),
#  ('narcotic', 6),
#  ('girl', 6),
#  ('theater', 6),
#  ('appeal', 6),
#  ('weapon', 6),
#  ('gain', 6),
#  ('debenture', 6),
#  ('export', 6),
#  ('thank', 5),
#  ('government', 5),
#  ('taxpayer', 5),
#  ('procedure', 5),
#  ('servant', 5),
#  ('petition', 5),
#  ('signature', 5),
#  ('course', 5),
#  ('representative', 5),
#  ('project', 5),
#  ('attorney', 5),
#  ('demand', 5),
#  ('individual', 5),
#  ('judge', 5),
#  ('meeting', 5),
#  ('circumstance', 5),
#  ('trouble', 5),
#  ('submarine', 5),
#  ('idea', 5),
#  ('view', 5),
#  ('post', 5),
#  ('factor', 5),
#  ('hundred', 5),
#  ('ceremonie', 5),
#  ('building', 5),
#  ('spectator', 5),
#  ('eye', 5),
#  ('director', 5),
#  ('room', 5),
#  ('agreement', 5),
#  ('door', 5),
#  ('good', 5),
#  ('center', 5),
#  ('volunteer', 5),
#  ('kid', 5),
#  ('team', 5),
#  ('honor', 5),
#  ('costume', 5),
#  ('Member', 5),
#  ('ticket', 5),
#  ('painting', 5),
#  ('artist', 5),
#  ('level', 5),
#  ('panel', 5),
#  ('burn', 5),
#  ('Survivor', 5),
#  ('daughter', 5),
#  ('plant', 5),
#  ('farmer', 5),
#  ('puppet', 5),
#  ('conference', 5),
#  ('liberal', 5),
#  ('hole', 5),
#  ('textile', 5),
#  ('office', 4),
#  ('item', 4),
#  ('juror', 4),
#  ('precinct', 4),
#  ('bank', 4),
#  ('obligation', 4),
#  ('committee', 4),
#  ('district', 4),
#  ('senator', 4),
#  ('place', 4),
#  ('parent', 4),
#  ('request', 4),
#  ('scholarship', 4),
#  ('benefit', 4),
#  ('requirement', 4),
#  ('allie', 4),
#  ('event', 4),
#  ('water', 4),
#  ('attack', 4),
#  ('reform', 4),
#  ('victorie', 4),
#  ('losse', 4),
#  ('communitie', 4),
#  ('type', 4),
#  ('store', 4),
#  ('increase', 4),
#  ('reporter', 4),
#  ('politician', 4),
#  ('work', 4),
#  ('universitie', 4),
#  ('goal', 4),
#  ('technician', 4),
#  ('seat', 4),
#  ('teamster', 4),
#  ('son', 4),
#  ('motion', 4),
#  ('double', 4),
#  ('chore', 4),
#  ('pound', 4),
#  ('coache', 4),
#  ('trie', 4),
#  ('movie', 4),
#  ('passe', 4),
#  ('award', 4),
#  ('writer', 4),
#  ('shot', 4),
#  ('string', 4),
#  ('motel', 4),
#  ('chair', 4),
#  ('festivitie', 4),
#  ('arrangement', 4),
#  ('cut', 4),
#  ('bodie', 4),
#  ('suit', 4),
#  ('improvement', 4),
#  ('Other', 4),
#  ('youth', 4),
#  ('move', 4),
#  ('standard', 4),
#  ('application', 4),
#  ('blue', 4),
#  ('collection', 4),
#  ('bird', 4),
#  ('wood', 4),
#  ('fabric', 4),
#  ('aspect', 4),
#  ('marriage', 4),
#  ('drum', 4),
#  ('toy', 4),
#  ('hope', 4),
#  ('employer', 4),
#  ('cent', 4),
#  ('tribe', 4),
#  ('librarian', 4),
#  ('irregularitie', 3),
#  ('matter', 3),
#  ('farm', 3),
#  ('contract', 3),
#  ('highway', 3),
#  ('allowance', 3),
#  ('detail', 3),
#  ('raise', 3),
#  ('poll', 3),
#  ('saving', 3),
#  ('gift', 3),
#  ('site', 3),
#  ('election', 3),
#  ('two-third', 3),
#  ('subject', 3),
#  ('cause', 3),
#  ('skill', 3),
#  ('right', 3),
#  ('hearing', 3),
#  ('processe', 3),
#  ('hospital', 3),
#  ('element', 3),
#  ('discussion', 3),
#  ('difficultie', 3),
#  ('opinion', 3),
#  ('ground', 3),
#  ('interval', 3),
#  ('classe', 3),
#  ('motorist', 3),
#  ('offense', 3),
#  ('result', 3),
#  ('sign', 3),
#  ('interview', 3),
#  ('language', 3),
#  ('estimate', 3),
#  ('expert', 3),
#  ('branche', 3),
#  ('commitment', 3),
#  ('purpose', 3),
#  ('bid', 3),
#  ('dog', 3),
#  ('park', 3),
#  ('fighter', 3),
#  ('lot', 3),
#  ('belief', 3),
#  ('live', 3),
#  ('mail', 3),
#  ('club', 3),
#  ('pitcher', 3),
#  ('homer', 3),
#  ('crowd', 3),
#  ('stage', 3),
#  ('play', 3),
#  ('completion', 3),
#  ('attempt', 3),
#  ('performance', 3),
#  ('average', 3),
#  ('league', 3),
#  ('test', 3),
#  ('inning', 3),
#  ('fan', 3),
#  ('chance', 3),
#  ('masse', 3),
#  ('season', 3),
#  ('injurie', 3),
#  ('major', 3),
#  ('tournament', 3),
#  ('date', 3),
#  ('trip', 3),
#  ('career', 3),
#  ('dancer', 3),
#  ('appearance', 3),
#  ('suggestion', 3),
#  ('boxe', 3),
#  ('Guest', 3),
#  ('schedule', 3),
#  ('cookie', 3),
#  ('pool', 3),
#  ('adult', 3),
#  ('hat', 3),
#  ('flower', 3),
#  ('bundle', 3),
#  ('aide', 3),
#  ('ladie', 3),
#  ('lay-off', 3),
#  ('board', 3),
#  ('tire', 3),
#  ('victim', 3),
#  ('brother', 3),
#  ('agent', 3),
#  ('lawyer', 3),
#  ('meal', 3),
#  ('rebel', 3),
#  ('privilege', 3),
#  ('stand-in', 3),
#  ('sister', 3),
#  ('scratche', 3),
#  ('crop', 3),
#  ('commissioner', 3),
#  ('teenager', 3),
#  ('youngster', 3),
#  ('show', 3),
#  ('ribbon', 3),
#  ('bed', 3),
#  ('connection', 3),
#  ('restriction', 3),
#  ('pilot', 3),
#  ('missile', 3),
#  ('Investor', 3),
#  ('inquirie', 3),
#  ('drier', 3),
#  ('Headquarter', 3),
#  ('picker', 3),
#  ('Farmer', 3),
#  ('tractor', 3),
#  ('implement', 3),
#  ('material', 3),
#  ('clothe', 3),
#  ('picture', 3),
#  ('trustee', 3),
#  ('patron', 3),
#  ('art', 3),
#  ('reservation', 3),
#  ('passenger', 3),
#  ('leg', 3),
#  ('number', 3),
#  ('film', 3),
#  ('musician', 3),
#  ('sculpture', 3),
#  ('title', 3),
#  ('giant', 3),
#  ('organization', 3),
#  ('monopolie', 3),
#  ('front', 3),
#  ('staff', 3),
#  ('round', 3),
#  ('golfer', 3),
#  ('par', 3),
#  ('province', 3),
#  ('hostage', 3),
#  ('import', 3),
#  ('quota', 3),
#  ('miner', 3),
#  ('mine', 3),
#  ('volume', 3),
#  ('topic', 2),
#  ('department', 2),
#  ('guardian', 2),
#  ('criticism', 2),
#  ('deputie', 2),
#  ('Attorney', 2),
#  ('adjustment', 2),
#  ('chamber', 2),
#  ('account', 2),
#  ('corporation', 2),
#  ('pocket', 2),
#  ('folk', 2),
#  ('donation', 2),
#  ('retailer', 2),
#  ('broker', 2),
#  ('recipient', 2),
#  ('relative', 2),
#  ('observer', 2),
#  ('draft', 2),
#  ('proceeding', 2),
#  ('Official', 2),
#  ('Legislator', 2),
#  ('appointment', 2),
#  ('minister', 2),
#  ('surprise', 2),
#  ('correspondent', 2),
#  ('spot', 2),
#  ('societie', 2),
#  ('arrest', 2),
#  ('instance', 2),
#  ('food', 2),
#  ('supermarket', 2),
#  ('license', 2),
#  ('conservative', 2),
#  ('utilitie', 2),
#  ('canvasser', 2),
#  ('boo', 2),
#  ('remain', 2),
#  ('fire', 2),
#  ('technique', 2),
#  ('warden', 2),
#  ('hoodlum', 2),
#  ('elephant', 2),
#  ('newspaper', 2),
#  ('forecast', 2),
#  ('mortgage', 2),
#  ('dormitorie', 2),
#  ('inhabitant', 2),
#  ('principle', 2),
#  ('soldier', 2),
#  ('development', 2),
#  ('foe', 2),
#  ('lawmaker', 2),
#  ('odd', 2),
#  ('camp', 2),
#  ('rank', 2),
#  ('finance', 2),
#  ('follower', 2),
#  ('affiliation', 2),
#  ('contractor', 2),
#  ('disclosure', 2),
#  ('violation', 2),
#  ('joint', 2),
#  ('dwelling', 2),
#  ('hazard', 2),
#  ('pedestrian', 2),
#  ('cluster', 2),
#  ('bridge', 2),
#  ('ankle', 2),
#  ('guard', 2),
#  ('path', 2),
#  ('mother', 2),
#  ('speaker', 2),
#  ('trend', 2),
#  ('babie', 2),
#  ('graduate', 2),
#  ('conspirator', 2),
#  ('frame', 2),
#  ('tallie', 2),
#  ('teammate', 2),
#  ('steward', 2),
#  ('conversion', 2),
#  ('stop', 2),
#  ('reserve', 2),
#  ('strike', 2),
#  ('statistic', 2),
#  ('check', 2),
#  ('viewer', 2),
#  ('light', 2),
#  ('reflexe', 2),
#  ('tongue', 2),
#  ('rookie', 2),
#  ('slugger', 2),
#  ('merit', 2),
#  ('bleacher', 2),
#  ('end', 2),
#  ('personalitie', 2),
#  ('barrier', 2),
#  ('matche', 2),
#  ('frustration', 2),
#  ('bound', 2),
#  ('duffer', 2),
#  ('nerve', 2),
#  ('competitor', 2),
#  ('bat', 2),
#  ('triumph', 2),
#  ('talent', 2),
#  ('height', 2),
#  ('holiday', 2),
#  ('bushe', 2),
#  ('invitation', 2),
#  ('tree', 2),
#  ('charitie', 2),
#  ('holder', 2),
#  ('role', 2),
#  ('Grandparent', 2),
#  ('Cocktail', 2),
#  ('junior', 2),
#  ('decoration', 2),
#  ('qualitie', 2),
#  ('task', 2),
#  ('alcoholic', 2),
#  ('parolee', 2),
#  ('station', 2),
#  ('stand', 2),
#  ('accommodation', 2),
#  ('ant', 2),
#  ('Parent', 2),
#  ('studie', 2),
#  ('oyster', 2),
#  ('reproduction', 2),
#  ('dutie', 2),
#  ('decade', 2),
#  ('poster', 2),
#  ('remark', 2),
#  ('laborer', 2),
#  ('structure', 2),
#  ('1950', 2),
#  ('client', 2),
#  ('destroyer', 2),
#  ('ship', 2),
#  ('indictment', 2),
#  ('rivalrie', 2),
#  ('comment', 2),
#  ('proceed', 2),
#  ('assault', 2),
#  ('claim', 2),
#  ('execution', 2),
#  ('rifle', 2),
#  ('by-law', 2),
#  ('obstacle', 2),
#  ('endowment', 2),
#  ('operator', 2),
#  ('profit', 2),
#  ('count', 2),
#  ('pension', 2),
#  ('plane', 2),
#  ('human', 2),
#  ('Student', 2),
#  ('engineer', 2),
#  ('Employe', 2),
#  ('businesse', 2),
#  ('advisor', 2),
#  ('skie', 2),
#  ('pain', 2),
#  ('coin', 2),
#  ('ring', 2),
#  ('earring', 2),
#  ('lieutenant', 2),
#  ('dime', 2),
#  ('quarter', 2),
#  ('mistake', 2),
#  ('grape', 2),
#  ('prosecutor', 2),
#  ('janitor', 2),
#  ('factorie', 2),
#  ('amount', 2),
#  ('underwriter', 2),
#  ('price-earning', 2),
#  ('merger', 2),
#  ('buyer', 2),
#  ('cleaner', 2),
#  ('saw', 2),
#  ('model', 2),
#  ('danger', 2),
#  ('situation', 2),
#  ('securitie', 2),
#  ('dividend', 2),
#  ('shareholder', 2),
#  ('railroad', 2),
#  ('exception', 2),
#  ('appliance', 2),
#  ('shipment', 2),
#  ('deduction', 2),
#  ('Request', 2),
#  ('green', 2),
#  ('supporter', 2),
#  ('snack', 2),
#  ('table', 2),
#  ('potatoe', 2),
#  ('breast', 2),
#  ('wall', 2),
#  ('dresser', 2),
#  ('tone', 2),
#  ('shade', 2),
#  ('couple', 2),
#  ('final', 2),
#  ('addresse', 2),
#  ('Newcomer', 2),
#  ('face', 2),
#  ('inche', 2),
#  ('decorator', 2),
#  ('antique', 2),
#  ('feature', 2),
#  ('ballet', 2),
#  ('relationship', 2),
#  ('workshop', 2),
#  ('assemblie', 2),
#  ('vow', 2),
#  ('assignment', 2),
#  ('age', 2),
#  ('credit', 2),
#  ('sofa', 2),
#  ('visitor', 2),
#  ('outsider', 2),
#  ('exchange', 2),
#  ('head', 2),
#  ('announcement', 2),
#  ('aim', 2),
#  ('debate', 2),
#  ('Development', 2),
#  ('organ', 2),
#  ('conversation', 2),
#  ('mechanism', 2),
#  ('qualification', 2),
#  ('interest', 2),
#  ('grip', 2),
#  ('dispute', 2),
#  ('abuse', 2),
#  ('heavy-electrical-good', 2),
#  ('management', 2),
#  ('penaltie', 2),
#  ('commoditie', 2),
#  ('bag', 2),
#  ('mechanic', 2),
#  ('measure', 2),
#  ('tank', 2),
#  ('gate', 2),
#  ('elector', 2),
#  ('white', 2),
#  ('three-fifth', 2),
#  ('winning', 2),
#  ('birdie', 2),
#  ('fairway', 2),
#  ('tie', 2),
#  ('second', 2),
#  ('grad', 2),
#  ('boundarie', 2),
#  ('grouping', 2),
#  ('war', 2),
#  ('pirate', 2),
#  ('gun', 2),
#  ('toll', 2),
#  ('seam', 2),
#  ('budget', 2),
#  ('display', 2),
#  ('presentment', 1),
#  ('appraiser', 1),
#  ('administrator', 1),
#  ('jurie', 1),
#  ('ward', 1),
#  ('influence', 1),
#  ('concessionaire', 1),
#  ('response', 1),
#  ('dissent', 1),
#  ('threat', 1),
#  ('protest', 1),
#  ('depositor', 1),
#  ('Senator', 1),
#  ('scholastic', 1),
#  ('parimutuel', 1),
#  ('ponie', 1),
#  ('reservoir', 1),
#  ('vacancie', 1),
#  ('majoritie', 1),
#  ('Opponent', 1),
#  ('Statement', 1),
#  ('defender', 1),
#  ('co-signer', 1),
#  ('regent', 1),
#  ('Principal', 1),
#  ('breakup', 1),
#  ('portion', 1),
#  ('aid', 1),
#  ('subpena', 1),
#  ('boost', 1),
#  ('figure', 1),
#  ('stay', 1),
#  ('aye', 1),
#  ('noe', 1),
#  ('selection', 1),
#  ('power', 1),
#  ('tragedie', 1),
#  ('critic', 1),
#  ('manifestation', 1),
#  ('speeche', 1),
#  ('setback', 1),
#  ('direction', 1),
#  ('modification', 1),
#  ('confrontation', 1),
#  ('blunder', 1),
#  ('educator', 1),
#  ('professor', 1),
#  ('channel', 1),
#  ('Policie', 1),
#  ('offender', 1),
#  ('radio', 1),
#  ('siren', 1),
#  ('revision', 1),
#  ('statute', 1),
#  ('shop', 1),
#  ('outlet', 1),
#  ('Liberal', 1),
#  ('justice', 1),
#  ('pretense', 1),
#  ('signer', 1),
#  ('fine', 1),
#  ('use', 1),
#  ('barb', 1),
#  ('crise', 1),
#  ('vehicle', 1),
#  ('opponent', 1),
#  ('ballot', 1),
#  ('plow', 1),
#  ('slogan', 1),
#  ('1940', 1),
#  ('tract', 1),
#  ('municipalitie', 1),
#  ('colleague', 1),
#  ('tusk', 1),
#  ('retirement', 1),
#  ('1920', 1),
#  ('choice', 1),
#  ('scandal', 1),
#  ('investigation', 1),
#  ('down-payment', 1),
#  ('slum', 1),
#  ('Interview', 1),
#  ('neutralist', 1),
#  ('half-brother', 1),
#  ('delegation', 1),
#  ('diplomat', 1),
#  ('consultation', 1),
#  ('tactic', 1),
#  ('Thousand', 1),
#  ('shrine', 1),
#  ('monument', 1),
#  ('chapter', 1),
#  ('suffragette', 1),
#  ('track', 1),
#  ('statue', 1),
#  ('academie', 1),
#  ('representation', 1),
#  ('territorie', 1),
#  ('edge', 1),
#  ('job-seeker', 1),
#  ('crossroad', 1),
#  ('loyalist', 1),
#  ('independent', 1),
#  ('Report', 1),
#  ('stresse', 1),
#  ('inconsistencie', 1),
#  ('politico', 1),
#  ('alternative', 1),
#  ('trim', 1),
#  ('allegation', 1),
#  ('Estimate', 1),
#  ('shortcut', 1),
#  ('voucher', 1),
#  ('repair', 1),
#  ('permit', 1),
#  ('accomodation', 1),
#  ('male', 1),
#  ('female', 1),
#  ('catcher', 1),
#  ('bite', 1),
#  ('Petition', 1),
#  ('redeveloper', 1),
#  ('sector', 1),
#  ('walkway', 1),
#  ('fracture', 1),
#  ('pledge', 1),
#  ('people', 1),
#  ('blueprint', 1),
#  ('specification', 1),
#  ('Poll', 1),
#  ('truth', 1),
#  ('scripture', 1),
#  ('miracle', 1),
#  ('mission', 1),
#  ('Survey', 1),
#  ('pastor', 1),
#  ('apprentice', 1),
#  ('Denial', 1),
#  ('trial', 1),
#  ('Indication', 1),
#  ('batter', 1),
#  ('blow', 1),
#  ('offering', 1),
#  ('safetie', 1),
#  ('pinch-hitter', 1),
#  ('pitche', 1),
#  ('runner', 1),
#  ('hitter', 1),
#  ('specialist', 1),
#  ('hurler', 1),
#  ('colt', 1),
#  ('furlong', 1),
#  ('celebrant', 1),
#  ('horse', 1),
#  ('race', 1),
#  ('third', 1),
#  ('tenth', 1),
#  ('pad', 1),
#  ('thrust', 1),
#  ('sweat-suit', 1),
#  ('reckoning', 1),
#  ('collector', 1),
#  ('quarterback', 1),
#  ('linebacker', 1),
#  ('touchdown', 1),
#  ('ball-carrier', 1),
#  ('tosse', 1),
#  ('baseball', 1),
#  ('flie', 1),
#  ('at-bat', 1),
#  ('heroic', 1),
#  ('feat', 1),
#  ('achievement', 1),
#  ('heart', 1),
#  ('guy', 1),
#  ('laurel', 1),
#  ('lefthander', 1),
#  ('ruler', 1),
#  ('afternoon', 1),
#  ('champ', 1),
#  ('aerial', 1),
#  ('cufflink', 1),
#  ('disappointment', 1),
#  ('incompetent', 1),
#  ('pixie', 1),
#  ('zombie', 1),
#  ('banshee', 1),
#  ('hacker', 1),
#  ('echoe', 1),
#  ('rain', 1),
#  ('father', 1),
#  ('amendment', 1),
#  ('plunker', 1),
#  ('Speaker', 1),
#  ('fault', 1),
#  ('defeat', 1),
#  ('cow', 1),
#  ('expectation', 1),
#  ("rbi'", 1),
#  ('peak', 1),
#  ('professional', 1),
#  ('sight', 1),
#  ('uncle', 1),
#  ('aunt', 1),
#  ('huzzah', 1),
#  ('ear', 1),
#  ('embassie', 1),
#  ('dervishe', 1),
#  ('singer', 1),
#  ('song', 1),
#  ('train', 1),
#  ('shelter', 1),
#  ('pub', 1),
#  ('night', 1),
#  ('ethic', 1),
#  ('moral', 1),
#  ('gal', 1),
#  ('phonie', 1),
#  ('phone', 1),
#  ('contrib', 1),
#  ('exhibitor', 1),
#  ('screening', 1),
#  ('touche', 1),
#  ('clashe', 1),
#  ('bomb', 1),
#  ('peasant', 1),
#  ('struggle', 1),
#  ('medic', 1),
#  ('doing', 1),
#  ('lesson', 1),
#  ('suite', 1),
#  ('sweet', 1),
#  ('motel-keeper', 1),
#  ('suitcase', 1),
#  ('wagon', 1),
#  ('restaurant', 1),
#  ('taste', 1),
#  ('peculiaritie', 1),
#  ('Motorist', 1),
#  ('tourist', 1),
#  ('towel', 1),
#  ('attendant', 1),
#  ('applique', 1),
#  ('gardenia', 1),
#  ('bridesmaid', 1),
#  ('newlywed', 1),
#  ('orchid', 1),
#  ('specialtie', 1),
#  ('effect', 1),
#  ('shelve', 1),
#  ('suburb', 1),
#  ('dinner', 1),
#  ('fund-raiser', 1),
#  ('husband', 1),
#  ('hostesse', 1),
#  ('controller', 1),
#  ('Model', 1),
#  ('temperature', 1),
#  ('sponsor', 1),
#  ('Proceed', 1),
#  ('host', 1),
#  ('ballgown', 1),
#  ('dance', 1),
#  ('tier', 1),
#  ('slipper', 1),
#  ('maid', 1),
#  ('ashe', 1),
#  ('rose', 1),
#  ('thread', 1),
#  ('sequin', 1),
#  ('bead', 1),
#  ('supervisor', 1),
#  ('discrepancie', 1),
#  ('misunderstanding', 1),
#  ('Doctor', 1),
#  ('deficiencie', 1),
#  ('crew', 1),
#  ('storm', 1),
#  ...]

# %%
NN = dict((word ,cdf["NN"][word]) for (word, freq) in NNS )

# %%
NN #NN that are in NNS
# Out:
# {'irregularitie': 0,
#  'presentment': 0,
#  'thank': 0,
#  'report': 19,
#  'voter': 2,
#  'law': 38,
#  'legislator': 2,
#  'topic': 0,
#  'department': 12,
#  'practice': 8,
#  'government': 52,
#  'office': 24,
#  'policie': 0,
#  'step': 7,
#  'fund': 11,
#  'service': 37,
#  'home': 72,
#  'item': 1,
#  'countie': 0,
#  'juror': 4,
#  'taxpayer': 3,
#  'appraiser': 0,
#  'guardian': 0,
#  'administrator': 5,
#  'fee': 7,
#  'procedure': 2,
#  'recommendation': 1,
#  'jurie': 0,
#  'citizen': 1,
#  'action': 20,
#  'ward': 7,
#  'cost': 13,
#  'servant': 0,
#  'criticism': 0,
#  'influence': 1,
#  'concessionaire': 0,
#  'price': 13,
#  'matter': 21,
#  'deputie': 0,
#  'official': 6,
#  'employe': 0,
#  'farm': 21,
#  'Attorney': 1,
#  'response': 5,
#  'petition': 6,
#  'precinct': 5,
#  'signature': 1,
#  'dissent': 1,
#  'course': 24,
#  'name': 12,
#  'candidate': 17,
#  'relation': 0,
#  'year': 137,
#  'area': 39,
#  'adjustment': 1,
#  'chamber': 1,
#  'bond': 11,
#  'court': 26,
#  'sale': 8,
#  'contract': 11,
#  'highway': 7,
#  'one': 0,
#  'authoritie': 0,
#  'road': 12,
#  'plan': 42,
#  'allowance': 2,
#  'detail': 2,
#  'raise': 1,
#  'session': 37,
#  'member': 35,
#  'vote': 21,
#  'poll': 5,
#  'call': 4,
#  'threat': 6,
#  'day': 61,
#  'protest': 0,
#  'banker': 1,
#  'rule': 16,
#  'question': 18,
#  'witnesse': 0,
#  'dollar': 5,
#  'mean': 0,
#  'book': 13,
#  'account': 5,
#  'stock': 20,
#  'person': 9,
#  'bank': 11,
#  'firm': 28,
#  'companie': 0,
#  'corporation': 7,
#  'obligation': 1,
#  'depositor': 0,
#  'customer': 0,
#  'million': 0,
#  'pocket': 1,
#  'Senator': 0,
#  'school': 65,
#  'student': 17,
#  'saving': 0,
#  'scholastic': 0,
#  'parimutuel': 0,
#  'folk': 1,
#  'letter': 7,
#  'ponie': 0,
#  'citie': 0,
#  'bill': 45,
#  'committee': 38,
#  'act': 15,
#  'district': 17,
#  'senator': 3,
#  'gift': 5,
#  'donation': 0,
#  'retailer': 0,
#  'taxe': 0,
#  'broker': 0,
#  'site': 3,
#  'reservoir': 1,
#  'vacancie': 0,
#  'election': 38,
#  'representative': 4,
#  'two-third': 0,
#  'majoritie': 0,
#  'Opponent': 0,
#  'proposal': 13,
#  'need': 22,
#  'place': 21,
#  'Statement': 0,
#  'defender': 0,
#  'method': 3,
#  'hour': 17,
#  'teacher': 9,
#  'subject': 8,
#  'co-signer': 0,
#  'regent': 0,
#  'Principal': 1,
#  'cause': 0,
#  'recipient': 3,
#  'problem': 37,
#  'case': 35,
#  'skill': 0,
#  'breakup': 0,
#  'relative': 0,
#  'parent': 1,
#  'project': 25,
#  'defendant': 3,
#  'statement': 23,
#  'observer': 1,
#  'attorney': 17,
#  'other': 0,
#  'draft': 1,
#  'portion': 2,
#  'aid': 23,
#  'adviser': 3,
#  'decision': 13,
#  'demand': 15,
#  'right': 8,
#  'proceeding': 0,
#  'hearing': 10,
#  'subpena': 0,
#  'individual': 4,
#  'judge': 10,
#  'processe': 0,
#  'worker': 2,
#  'program': 65,
#  'request': 8,
#  'grant': 5,
#  'scholarship': 3,
#  'boost': 3,
#  'Official': 0,
#  'benefit': 6,
#  'figure': 7,
#  'part': 31,
#  'system': 47,
#  'stay': 1,
#  'state': 88,
#  'requirement': 4,
#  'hospital': 19,
#  'contribution': 3,
#  'facilitie': 0,
#  'element': 2,
#  'line': 20,
#  'Legislator': 0,
#  'aye': 0,
#  'noe': 0,
#  'appointment': 8,
#  'selection': 4,
#  'discussion': 4,
#  'meeting': 58,
#  'change': 4,
#  'minister': 1,
#  'power': 19,
#  'difficultie': 0,
#  'tragedie': 0,
#  'allie': 0,
#  'circumstance': 0,
#  'trouble': 8,
#  'week': 85,
#  'critic': 2,
#  'position': 16,
#  'surprise': 6,
#  'car': 49,
#  'manifestation': 0,
#  'arm': 2,
#  'speeche': 0,
#  'point': 17,
#  'setback': 2,
#  'correspondent': 1,
#  'spot': 1,
#  'event': 15,
#  'month': 32,
#  'submarine': 6,
#  'water': 10,
#  'societie': 0,
#  'direction': 6,
#  'countrie': 0,
#  'force': 4,
#  'attack': 16,
#  'modification': 1,
#  'error': 1,
#  'reform': 3,
#  'confrontation': 2,
#  'blunder': 0,
#  'educator': 0,
#  'group': 38,
#  'effort': 23,
#  'condition': 11,
#  'victorie': 0,
#  'opinion': 12,
#  'professor': 1,
#  'channel': 0,
#  'Policie': 0,
#  'negotiation': 1,
#  'nation': 13,
#  'losse': 0,
#  'neighbor': 4,
#  'idea': 7,
#  'communitie': 0,
#  'arrest': 6,
#  'offender': 0,
#  'resident': 2,
#  'radio': 6,
#  'siren': 0,
#  'truck': 1,
#  'ground': 10,
#  'interval': 0,
#  'thing': 15,
#  'classe': 0,
#  'revision': 3,
#  'view': 11,
#  'officer': 7,
#  'statute': 0,
#  'instance': 3,
#  'time': 97,
#  'type': 5,
#  'food': 13,
#  'store': 3,
#  'supermarket': 0,
#  'shop': 7,
#  'thousand': 0,
#  'license': 7,
#  'outlet': 0,
#  'Liberal': 0,
#  'conservative': 0,
#  'partie': 0,
#  'utilitie': 0,
#  'resource': 1,
#  'increase': 15,
#  'manufacturer': 5,
#  'canvasser': 0,
#  'justice': 3,
#  'post': 9,
#  'pretense': 0,
#  'signer': 0,
#  'motorist': 2,
#  'offense': 4,
#  'fine': 4,
#  'boo': 0,
#  'remain': 0,
#  'issue': 24,
#  'use': 13,
#  'minute': 1,
#  'barb': 0,
#  'crise': 0,
#  'way': 42,
#  'vehicle': 4,
#  'intention': 4,
#  'opponent': 0,
#  'leader': 22,
#  'manager': 17,
#  'ballot': 8,
#  'machine': 5,
#  'result': 29,
#  'fire': 21,
#  'technique': 1,
#  'plow': 3,
#  'unit': 10,
#  'warden': 3,
#  'slogan': 1,
#  'sign': 3,
#  'hoodlum': 1,
#  '1940': 0,
#  'tract': 4,
#  'municipalitie': 0,
#  'colleague': 0,
#  'term': 13,
#  'elephant': 0,
#  'tusk': 0,
#  'retirement': 6,
#  '1920': 0,
#  'mate': 0,
#  'choice': 6,
#  'talk': 3,
#  'interview': 6,
#  'reporter': 2,
#  'politician': 0,
#  'reason': 18,
#  'scandal': 0,
#  'work': 45,
#  'investigation': 9,
#  'newspaper': 1,
#  'forecast': 0,
#  'mortgage': 2,
#  'down-payment': 0,
#  'familie': 0,
#  'slum': 0,
#  'college': 18,
#  'dormitorie': 0,
#  'loan': 5,
#  'language': 2,
#  'agencie': 0,
#  'universitie': 0,
#  'Interview': 0,
#  'goal': 10,
#  'estimate': 2,
#  'technician': 0,
#  'expert': 5,
#  'job': 16,
#  'inhabitant': 0,
#  'affair': 6,
#  'neutralist': 2,
#  'half-brother': 0,
#  'delegation': 3,
#  'diplomat': 1,
#  'consultation': 2,
#  'tactic': 2,
#  'principle': 4,
#  'factor': 6,
#  'Thousand': 0,
#  'seat': 3,
#  'hundred': 0,
#  'ceremonie': 0,
#  'building': 9,
#  'shrine': 0,
#  'monument': 1,
#  'chapter': 1,
#  'suffragette': 0,
#  'soldier': 1,
#  'record': 35,
#  'track': 10,
#  'spectator': 2,
#  'statue': 0,
#  'branche': 0,
#  'academie': 0,
#  'representation': 1,
#  'territorie': 0,
#  'development': 17,
#  'foe': 0,
#  'friend': 2,
#  'edge': 4,
#  'job-seeker': 0,
#  'commitment': 2,
#  'lawmaker': 0,
#  'odd': 0,
#  'eye': 5,
#  'crossroad': 0,
#  'camp': 3,
#  'loyalist': 1,
#  'independent': 0,
#  'rank': 3,
#  'Report': 0,
#  'stresse': 0,
#  'finance': 1,
#  'revenue': 3,
#  'inconsistencie': 0,
#  'hand': 17,
#  'politico': 0,
#  'purpose': 9,
#  'expense': 7,
#  'alternative': 2,
#  'trim': 0,
#  'allegation': 0,
#  'follower': 0,
#  'affiliation': 0,
#  'bid': 6,
#  'Estimate': 0,
#  'contractor': 2,
#  'shortcut': 0,
#  'disclosure': 2,
#  'voucher': 0,
#  'charge': 16,
#  'director': 30,
#  'violation': 3,
#  'joint': 6,
#  'repair': 2,
#  'rate': 7,
#  'hotel': 10,
#  'room': 17,
#  'permit': 1,
#  'house': 24,
#  'dwelling': 0,
#  'accomodation': 0,
#  'dog': 7,
#  'male': 1,
#  'female': 1,
#  'owner': 3,
#  'catcher': 2,
#  'bite': 0,
#  'Petition': 0,
#  'agreement': 14,
#  'redeveloper': 0,
#  'hazard': 0,
#  'pedestrian': 2,
#  'apartment': 10,
#  'park': 3,
#  'churche': 0,
#  'cluster': 0,
#  'builder': 1,
#  'sector': 0,
#  'walkway': 0,
#  'bridge': 1,
#  'fighter': 0,
#  'teamster': 1,
#  'fracture': 0,
#  'ankle': 2,
#  'son': 21,
#  'guard': 4,
#  'pledge': 1,
#  'path': 1,
#  'door': 6,
#  'people': 0,
#  'good': 3,
#  'product': 10,
#  'lot': 8,
#  'mother': 14,
#  'blueprint': 0,
#  'specification': 0,
#  'speaker': 4,
#  'Poll': 0,
#  'belief': 6,
#  'delegate': 0,
#  'trend': 6,
#  'truth': 7,
#  'live': 0,
#  'scripture': 0,
#  'miracle': 1,
#  'mission': 5,
#  'Survey': 0,
#  'babie': 0,
#  'center': 29,
#  'pastor': 0,
#  'volunteer': 0,
#  'graduate': 9,
#  'apprentice': 1,
#  'motion': 2,
#  'Denial': 0,
#  'trial': 20,
#  'conspirator': 0,
#  'mail': 2,
#  'club': 29,
#  'Indication': 1,
#  'frame': 3,
#  'hit': 4,
#  'batter': 1,
#  'run': 20,
#  'start': 12,
#  'blow': 2,
#  'offering': 4,
#  'pitcher': 3,
#  'double': 9,
#  'chore': 1,
#  'safetie': 0,
#  'ball': 33,
#  'pinch-hitter': 1,
#  'pitche': 0,
#  'tallie': 0,
#  'runner': 0,
#  'homer': 8,
#  'player': 6,
#  'pound': 0,
#  'hitter': 1,
#  'specialist': 0,
#  'champion': 10,
#  'crowd': 8,
#  'game': 51,
#  'coache': 0,
#  'teammate': 2,
#  'hurler': 1,
#  'colt': 0,
#  'stage': 14,
#  'furlong': 0,
#  'celebrant': 0,
#  'steward': 0,
#  'horse': 2,
#  'race': 19,
#  'yard': 1,
#  'third': 0,
#  'tenth': 0,
#  'play': 11,
#  'pad': 0,
#  'trie': 0,
#  'conversion': 1,
#  'boy': 16,
#  'completion': 2,
#  'attempt': 8,
#  'kid': 5,
#  'performance': 11,
#  'stop': 3,
#  'thrust': 0,
#  'reserve': 3,
#  'sweat-suit': 0,
#  'reckoning': 0,
#  'collector': 0,
#  'quarterback': 4,
#  'linebacker': 0,
#  'movie': 6,
#  'passe': 0,
#  'touchdown': 5,
#  'strike': 10,
#  'ball-carrier': 0,
#  'statistic': 0,
#  'tosse': 0,
#  'average': 13,
#  'check': 3,
#  'baseball': 23,
#  'league': 14,
#  'test': 13,
#  'viewer': 0,
#  'inning': 7,
#  'base': 14,
#  'flie': 0,
#  'light': 6,
#  'fan': 2,
#  'reflexe': 0,
#  'at-bat': 0,
#  'chance': 7,
#  'masse': 0,
#  'heroic': 0,
#  'tongue': 0,
#  'feat': 2,
#  'achievement': 8,
#  'heart': 5,
#  'guy': 3,
#  'rookie': 4,
#  'laurel': 0,
#  'lefthander': 2,
#  'slugger': 3,
#  'merit': 2,
#  'season': 43,
#  'ruler': 0,
#  'afternoon': 19,
#  'injurie': 0,
#  'champ': 0,
#  'bleacher': 0,
#  'end': 18,
#  'aerial': 0,
#  'cufflink': 0,
#  'award': 11,
#  'sport': 2,
#  'writer': 2,
#  'personalitie': 0,
#  'barrier': 0,
#  'disappointment': 2,
#  'major': 2,
#  'matche': 0,
#  'tournament': 13,
#  'incompetent': 0,
#  'frustration': 0,
#  'pixie': 0,
#  'zombie': 0,
#  'banshee': 0,
#  'bound': 0,
#  'shot': 11,
#  'stroke': 6,
#  'duffer': 1,
#  'hacker': 0,
#  'echoe': 0,
#  'nerve': 1,
#  'string': 1,
#  'competitor': 1,
#  'rain': 1,
#  'father': 14,
#  'amendment': 5,
#  'team': 33,
#  'date': 15,
#  'bat': 6,
#  'plunker': 0,
#  'triumph': 4,
#  'Speaker': 0,
#  'word': 14,
#  'honor': 10,
#  'fault': 0,
#  'defeat': 1,
#  'trip': 10,
#  'cow': 0,
#  'talent': 7,
#  'career': 10,
#  'expectation': 1,
#  'height': 1,
#  "rbi'": 0,
#  'peak': 3,
#  'professional': 0,
#  'sight': 1,
#  'holiday': 2,
#  'uncle': 4,
#  'aunt': 3,
#  'huzzah': 0,
#  'ear': 0,
#  'embassie': 0,
#  'bushe': 0,
#  'activitie': 0,
#  'dancer': 2,
#  'dervishe': 0,
#  'invitation': 4,
#  'singer': 0,
#  'song': 2,
#  'costume': 0,
#  'tree': 0,
#  'street': 5,
#  'train': 3,
#  'shelter': 2,
#  'pub': 0,
#  'night': 64,
#  'ethic': 0,
#  'moral': 1,
#  'appearance': 2,
#  'gal': 0,
#  'phonie': 0,
#  'phone': 5,
#  'contrib': 0,
#  'exhibitor': 0,
#  'screening': 0,
#  'touche': 0,
#  'charitie': 0,
#  'holder': 0,
#  'clashe': 0,
#  'bomb': 10,
#  'peasant': 1,
#  'struggle': 2,
#  'role': 5,
#  'medic': 0,
#  'doing': 0,
#  'lesson': 1,
#  'suggestion': 4,
#  'boxe': 0,
#  'Member': 0,
#  'guest': 5,
#  'suite': 2,
#  'Grandparent': 0,
#  'Cocktail': 0,
#  'Guest': 1,
#  'junior': 3,
#  'decoration': 1,
#  'qualitie': 0,
#  'task': 5,
#  'alcoholic': 0,
#  'parolee': 0,
#  'schedule': 9,
#  'ticket': 6,
#  'concert': 12,
#  'cookie': 2,
#  'sweet': 0,
#  'motel-keeper': 0,
#  'suitcase': 0,
#  'mile': 1,
#  'motel': 4,
#  'station': 10,
#  'wagon': 0,
#  'restaurant': 5,
#  'stand': 9,
#  'accommodation': 0,
#  'taste': 5,
#  'peculiaritie': 0,
#  'pool': 1,
#  'adult': 4,
#  'Motorist': 0,
#  'tourist': 0,
#  'chair': 1,
#  'towel': 1,
#  'ant': 3,
#  'Parent': 0,
#  'attendant': 0,
#  'applique': 0,
#  'gardenia': 0,
#  'bridesmaid': 0,
#  'newlywed': 0,
#  'orchid': 0,
#  'studie': 0,
#  'prospect': 5,
#  'hat': 1,
#  'festivitie': 0,
#  'oyster': 0,
#  'specialtie': 0,
#  'effect': 14,
#  'flower': 1,
#  'reproduction': 0,
#  'shelve': 0,
#  'headquarter': 0,
#  'suburb': 2,
#  'bundle': 4,
#  'dinner': 23,
#  'fund-raiser': 1,
#  'husband': 13,
#  'hostesse': 0,
#  'arrangement': 2,
#  'dutie': 0,
#  'aide': 1,
#  'controller': 0,
#  'Model': 0,
#  'decade': 5,
#  'temperature': 0,
#  'poster': 1,
#  'painting': 1,
#  'sponsor': 2,
#  'artist': 2,
#  'Proceed': 0,
#  'level': 14,
#  'host': 0,
#  'ladie': 0,
#  'ballgown': 0,
#  'dance': 6,
#  'panel': 9,
#  'tier': 0,
#  'slipper': 1,
#  'maid': 3,
#  'ashe': 0,
#  'rose': 1,
#  'thread': 0,
#  'sequin': 0,
#  'bead': 0,
#  'cut': 3,
#  'lay-off': 0,
#  'employee': 1,
#  'supervisor': 1,
#  'union': 21,
#  'wage': 2,
#  'burn': 0,
#  'remark': 3,
#  'discrepancie': 0,
#  'bodie': 0,
#  'suit': 6,
#  'misunderstanding': 1,
#  'board': 47,
#  'Doctor': 0,
#  'deficiencie': 0,
#  'crew': 6,
#  'storm': 4,
#  'improvement': 7,
#  'operation': 15,
#  'laborer': 0,
#  'tire': 0,
#  'chain': 2,
#  'merchant': 0,
#  'observation': 0,
#  'supplie': 0,
#  'blade': 0,
#  'victim': 4,
#  'detective': 0,
#  'shooting': 1,
#  'brother': 8,
#  'spirit': 16,
#  'seeker': 0,
#  'component': 0,
#  'structure': 3,
#  'Other': 0,
#  'stair': 0,
#  'balconie': 0,
#  'secret': 0,
#  'agent': 5,
#  'design': 5,
#  'sub': 4,
#  'strongroom': 0,
#  'dot': 1,
#  'mark': 8,
#  '1950': 0,
#  '1960': 0,
#  'drawing': 2,
#  'lawyer': 9,
#  'client': 4,
#  'reactor': 3,
#  'turbine': 0,
#  'destroyer': 1,
#  'ship': 5,
#  'torpedoe': 0,
#  'Design': 1,
#  'signal': 1,
#  'wavelength': 0,
#  'code': 1,
#  'lighter': 1,
#  'narcotic': 1,
#  'indictment': 5,
#  'addict': 0,
#  'peddler': 1,
#  'rivalrie': 0,
#  'criminal': 1,
#  'jealousie': 0,
#  'grievance': 0,
#  'mention': 0,
#  'compensation': 4,
#  'comment': 2,
#  'youth': 8,
#  'homeowner': 0,
#  'casket': 0,
#  'fume': 0,
#  'girl': 9,
#  'arrear': 0,
#  'meal': 0,
#  'surpluse': 0,
#  'proceed': 0,
#  'troop': 0,
#  'move': 7,
#  'assault': 3,
#  'source': 7,
#  'claim': 3,
#  'squad': 3,
#  'tribunal': 1,
#  'collaborator': 0,
#  'execution': 0,
#  'rebel': 2,
#  'rifle': 1,
#  'jail': 5,
#  'priest': 0,
#  'prisoner': 0,
#  'by-law': 0,
#  'institution': 8,
#  'standard': 2,
#  'privilege': 3,
#  'provision': 2,
#  'obstacle': 1,
#  'endowment': 1,
#  'document': 0,
#  'application': 2,
#  'occupant': 0,
#  'laceration': 0,
#  'bruise': 0,
#  'stand-in': 0,
#  'theater': 13,
#  'operator': 2,
#  'profit': 2,
#  'Survivor': 0,
#  'sister': 6,
#  'daughter': 26,
#  'scratche': 0,
#  'uniform': 3,
#  'count': 2,
#  'doctor': 3,
#  'entrie': 0,
#  'transfer': 0,
#  'employment': 7,
#  'pension': 5,
#  'acre': 2,
#  'plane': 18,
#  'crop': 4,
#  'human': 2,
#  'Student': 2,
#  'computer': 0,
#  'camera': 5,
#  'engineer': 2,
#  'crashe': 0,
#  'Trooper': 0,
#  'flame': 0,
#  'commissioner': 5,
#  'wheel': 3,
#  'argument': 6,
#  'weaknesse': 0,
#  'communication': 3,
#  'robberie': 0,
#  'paper': 2,
#  'Employe': 0,
#  'function': 2,
#  'entertainer': 0,
#  'Service': 0,
#  'spice': 0,
#  'stockholder': 1,
#  'teenager': 0,
#  'youngster': 0,
#  'businesse': 0,
#  'Participant': 0,
#  'advisor': 0,
#  'Advisor': 0,
#  'show': 18,
#  'skie': 0,
#  'fairgoer': 0,
#  'Finalist': 0,
#  'ribbon': 4,
#  'blue': 0,
#  'egg': 0,
#  'championship': 5,
#  'appeal': 2,
#  'assessor': 0,
#  'assessment': 1,
#  'Appeal': 0,
#  'propertie': 0,
#  'pain': 1,
#  'Thieve': 0,
#  'fur': 1,
#  'jewel': 0,
#  'coin': 0,
#  'intruder': 0,
#  'ring': 5,
#  'earring': 0,
#  'thieve': 0,
#  'Drawer': 0,
#  'cabinet': 4,
#  'bedroom': 6,
#  'plant': 8,
#  'collection': 24,
#  'rib': 0,
#  'damage': 4,
#  'lieutenant': 1,
#  'Person': 0,
#  'Score': 0,
#  'contributor': 0,
#  'pennie': 0,
#  'nickel': 0,
#  'dime': 0,
#  'quarter': 4,
#  'alteration': 0,
#  'bed': 3,
#  'incident': 2,
#  'connection': 7,
#  'control': 18,
#  'mistake': 1,
#  'experiment': 1,
#  'farmer': 3,
#  'bird': 2,
#  'enemie': 0,
#  'insect': 0,
#  'rodent': 0,
#  'grape': 0,
#  'blueberrie': 0,
#  'restriction': 1,
#  'wetland': 0,
#  'pesticide': 0,
#  'tideland': 0,
#  'animal': 2,
#  'pilot': 4,
#  'rocket-bomb': 1,
#  'surface': 0,
#  'wing': 4,
#  'aileron': 0,
#  'Moment': 0,
#  'flight': 8,
#  'missile': 9,
#  'Pilot': 0,
#  'glider': 0,
#  'Nation': 0,
#  'weapon': 1,
#  'Government': 2,
#  'buddie': 0,
#  'chief': 6,
#  'prosecutor': 2,
#  'gangster': 0,
#  'payment': 6,
#  'janitor': 1,
#  'factorie': 0,
#  'amount': 10,
#  'lien': 0,
#  'share': 10,
#  'Investor': 0,
#  'inquirie': 0,
#  'Letter': 0,
#  'ream': 0,
#  'underwriter': 1,
#  'kind': 18,
#  'earning': 0,
#  'investor': 1,
#  'run-up': 1,
#  'price-earning': 0,
#  'Food': 0,
#  'ratio': 0,
#  'executive': 12,
#  'abilitie': 0,
#  'merger': 3,
#  'buyer': 0,
#  'ton': 1,
#  'gin': 12,
#  "1900'": 0,
#  'drier': 0,
#  'cleaner': 0,
#  'Headquarter': 0,
#  'Factorie': 0,
#  'heater': 0,
#  'extractor': 0,
#  'separator': 0,
#  'saw': 0,
#  'bearing': 0,
#  'doldrum': 0,
#  'Registration': 0,
#  'dealer': 4,
#  'maker': 4,
#  ...}

# %%
result = []
for (word1, freq1) in NNS:
    if NN[word1] > freq1:
        result.append((word1, "plural", NN[word1]) )
    else: result.append((word1, "singular", freq1))

# %%
result
# Out:
# [('irregularitie', 'singular', 3),
#  ('presentment', 'singular', 1),
#  ('thank', 'singular', 5),
#  ('report', 'plural', 19),
#  ('voter', 'singular', 12),
#  ('law', 'plural', 38),
#  ('legislator', 'singular', 8),
#  ('topic', 'singular', 2),
#  ('department', 'plural', 12),
#  ('practice', 'plural', 8),
#  ('government', 'plural', 52),
#  ('office', 'plural', 24),
#  ('policie', 'singular', 8),
#  ('step', 'singular', 8),
#  ('fund', 'singular', 27),
#  ('service', 'plural', 37),
#  ('home', 'plural', 72),
#  ('item', 'singular', 4),
#  ('countie', 'singular', 13),
#  ('juror', 'singular', 4),
#  ('taxpayer', 'singular', 5),
#  ('appraiser', 'singular', 1),
#  ('guardian', 'singular', 2),
#  ('administrator', 'plural', 5),
#  ('fee', 'singular', 12),
#  ('procedure', 'singular', 5),
#  ('recommendation', 'singular', 6),
#  ('jurie', 'singular', 1),
#  ('citizen', 'singular', 6),
#  ('action', 'plural', 20),
#  ('ward', 'plural', 7),
#  ('cost', 'singular', 17),
#  ('servant', 'singular', 5),
#  ('criticism', 'singular', 2),
#  ('influence', 'singular', 1),
#  ('concessionaire', 'singular', 1),
#  ('price', 'singular', 19),
#  ('matter', 'plural', 21),
#  ('deputie', 'singular', 2),
#  ('official', 'singular', 12),
#  ('employe', 'singular', 9),
#  ('farm', 'plural', 21),
#  ('Attorney', 'singular', 2),
#  ('response', 'plural', 5),
#  ('petition', 'plural', 6),
#  ('precinct', 'plural', 5),
#  ('signature', 'singular', 5),
#  ('dissent', 'singular', 1),
#  ('course', 'plural', 24),
#  ('name', 'plural', 12),
#  ('candidate', 'plural', 17),
#  ('relation', 'singular', 15),
#  ('year', 'plural', 137),
#  ('area', 'plural', 39),
#  ('adjustment', 'singular', 2),
#  ('chamber', 'singular', 2),
#  ('bond', 'singular', 28),
#  ('court', 'plural', 26),
#  ('sale', 'singular', 51),
#  ('contract', 'plural', 11),
#  ('highway', 'plural', 7),
#  ('one', 'singular', 8),
#  ('authoritie', 'singular', 7),
#  ('road', 'plural', 12),
#  ('plan', 'plural', 42),
#  ('allowance', 'singular', 3),
#  ('detail', 'singular', 3),
#  ('raise', 'singular', 3),
#  ('session', 'plural', 37),
#  ('member', 'singular', 69),
#  ('vote', 'plural', 21),
#  ('poll', 'plural', 5),
#  ('call', 'singular', 7),
#  ('threat', 'plural', 6),
#  ('day', 'plural', 61),
#  ('protest', 'singular', 1),
#  ('banker', 'singular', 8),
#  ('rule', 'plural', 16),
#  ('question', 'plural', 18),
#  ('witnesse', 'singular', 7),
#  ('dollar', 'singular', 15),
#  ('mean', 'singular', 13),
#  ('book', 'plural', 13),
#  ('account', 'plural', 5),
#  ('stock', 'plural', 20),
#  ('person', 'singular', 24),
#  ('bank', 'plural', 11),
#  ('firm', 'plural', 28),
#  ('companie', 'singular', 18),
#  ('corporation', 'plural', 7),
#  ('obligation', 'singular', 4),
#  ('depositor', 'singular', 1),
#  ('customer', 'singular', 7),
#  ('million', 'singular', 9),
#  ('pocket', 'singular', 2),
#  ('Senator', 'singular', 1),
#  ('school', 'plural', 65),
#  ('student', 'singular', 21),
#  ('saving', 'singular', 3),
#  ('scholastic', 'singular', 1),
#  ('parimutuel', 'singular', 1),
#  ('folk', 'singular', 2),
#  ('letter', 'singular', 12),
#  ('ponie', 'singular', 1),
#  ('citie', 'singular', 6),
#  ('bill', 'plural', 45),
#  ('committee', 'plural', 38),
#  ('act', 'plural', 15),
#  ('district', 'plural', 17),
#  ('senator', 'singular', 4),
#  ('gift', 'plural', 5),
#  ('donation', 'singular', 2),
#  ('retailer', 'singular', 2),
#  ('taxe', 'singular', 10),
#  ('broker', 'singular', 2),
#  ('site', 'singular', 3),
#  ('reservoir', 'singular', 1),
#  ('vacancie', 'singular', 1),
#  ('election', 'plural', 38),
#  ('representative', 'singular', 5),
#  ('two-third', 'singular', 3),
#  ('majoritie', 'singular', 1),
#  ('Opponent', 'singular', 1),
#  ('proposal', 'plural', 13),
#  ('need', 'plural', 22),
#  ('place', 'plural', 21),
#  ('Statement', 'singular', 1),
#  ('defender', 'singular', 1),
#  ('method', 'singular', 10),
#  ('hour', 'singular', 22),
#  ('teacher', 'plural', 9),
#  ('subject', 'plural', 8),
#  ('co-signer', 'singular', 1),
#  ('regent', 'singular', 1),
#  ('Principal', 'singular', 1),
#  ('cause', 'singular', 3),
#  ('recipient', 'plural', 3),
#  ('problem', 'plural', 37),
#  ('case', 'plural', 35),
#  ('skill', 'singular', 3),
#  ('breakup', 'singular', 1),
#  ('relative', 'singular', 2),
#  ('parent', 'singular', 4),
#  ('project', 'plural', 25),
#  ('defendant', 'singular', 9),
#  ('statement', 'plural', 23),
#  ('observer', 'singular', 2),
#  ('attorney', 'plural', 17),
#  ('other', 'singular', 14),
#  ('draft', 'singular', 2),
#  ('portion', 'plural', 2),
#  ('aid', 'plural', 23),
#  ('adviser', 'singular', 7),
#  ('decision', 'plural', 13),
#  ('demand', 'plural', 15),
#  ('right', 'plural', 8),
#  ('proceeding', 'singular', 2),
#  ('hearing', 'plural', 10),
#  ('subpena', 'singular', 1),
#  ('individual', 'singular', 5),
#  ('judge', 'plural', 10),
#  ('processe', 'singular', 3),
#  ('worker', 'singular', 15),
#  ('program', 'plural', 65),
#  ('request', 'plural', 8),
#  ('grant', 'singular', 13),
#  ('scholarship', 'singular', 4),
#  ('boost', 'plural', 3),
#  ('Official', 'singular', 2),
#  ('benefit', 'plural', 6),
#  ('figure', 'plural', 7),
#  ('part', 'plural', 31),
#  ('system', 'plural', 47),
#  ('stay', 'singular', 1),
#  ('state', 'plural', 88),
#  ('requirement', 'singular', 4),
#  ('hospital', 'plural', 19),
#  ('contribution', 'singular', 8),
#  ('facilitie', 'singular', 10),
#  ('element', 'singular', 3),
#  ('line', 'plural', 20),
#  ('Legislator', 'singular', 2),
#  ('aye', 'singular', 1),
#  ('noe', 'singular', 1),
#  ('appointment', 'plural', 8),
#  ('selection', 'plural', 4),
#  ('discussion', 'plural', 4),
#  ('meeting', 'plural', 58),
#  ('change', 'singular', 10),
#  ('minister', 'singular', 2),
#  ('power', 'plural', 19),
#  ('difficultie', 'singular', 3),
#  ('tragedie', 'singular', 1),
#  ('allie', 'singular', 4),
#  ('circumstance', 'singular', 5),
#  ('trouble', 'plural', 8),
#  ('week', 'plural', 85),
#  ('critic', 'plural', 2),
#  ('position', 'plural', 16),
#  ('surprise', 'plural', 6),
#  ('car', 'plural', 49),
#  ('manifestation', 'singular', 1),
#  ('arm', 'singular', 8),
#  ('speeche', 'singular', 1),
#  ('point', 'plural', 17),
#  ('setback', 'plural', 2),
#  ('correspondent', 'singular', 2),
#  ('spot', 'singular', 2),
#  ('event', 'plural', 15),
#  ('month', 'singular', 42),
#  ('submarine', 'plural', 6),
#  ('water', 'plural', 10),
#  ('societie', 'singular', 2),
#  ('direction', 'plural', 6),
#  ('countrie', 'singular', 28),
#  ('force', 'singular', 16),
#  ('attack', 'plural', 16),
#  ('modification', 'singular', 1),
#  ('error', 'singular', 8),
#  ('reform', 'singular', 4),
#  ('confrontation', 'plural', 2),
#  ('blunder', 'singular', 1),
#  ('educator', 'singular', 1),
#  ('group', 'plural', 38),
#  ('effort', 'plural', 23),
#  ('condition', 'plural', 11),
#  ('victorie', 'singular', 4),
#  ('opinion', 'plural', 12),
#  ('professor', 'singular', 1),
#  ('channel', 'singular', 1),
#  ('Policie', 'singular', 1),
#  ('negotiation', 'singular', 11),
#  ('nation', 'plural', 13),
#  ('losse', 'singular', 4),
#  ('neighbor', 'singular', 6),
#  ('idea', 'plural', 7),
#  ('communitie', 'singular', 4),
#  ('arrest', 'plural', 6),
#  ('offender', 'singular', 1),
#  ('resident', 'singular', 6),
#  ('radio', 'plural', 6),
#  ('siren', 'singular', 1),
#  ('truck', 'singular', 6),
#  ('ground', 'plural', 10),
#  ('interval', 'singular', 3),
#  ('thing', 'plural', 15),
#  ('classe', 'singular', 3),
#  ('revision', 'plural', 3),
#  ('view', 'plural', 11),
#  ('officer', 'singular', 18),
#  ('statute', 'singular', 1),
#  ('instance', 'plural', 3),
#  ('time', 'plural', 97),
#  ('type', 'plural', 5),
#  ('food', 'plural', 13),
#  ('store', 'singular', 4),
#  ('supermarket', 'singular', 2),
#  ('shop', 'plural', 7),
#  ('thousand', 'singular', 7),
#  ('license', 'plural', 7),
#  ('outlet', 'singular', 1),
#  ('Liberal', 'singular', 1),
#  ('conservative', 'singular', 2),
#  ('partie', 'singular', 14),
#  ('utilitie', 'singular', 2),
#  ('resource', 'singular', 6),
#  ('increase', 'plural', 15),
#  ('manufacturer', 'singular', 10),
#  ('canvasser', 'singular', 2),
#  ('justice', 'plural', 3),
#  ('post', 'plural', 9),
#  ('pretense', 'singular', 1),
#  ('signer', 'singular', 1),
#  ('motorist', 'singular', 3),
#  ('offense', 'plural', 4),
#  ('fine', 'plural', 4),
#  ('boo', 'singular', 2),
#  ('remain', 'singular', 2),
#  ('issue', 'plural', 24),
#  ('use', 'plural', 13),
#  ('minute', 'singular', 25),
#  ('barb', 'singular', 1),
#  ('crise', 'singular', 1),
#  ('way', 'plural', 42),
#  ('vehicle', 'plural', 4),
#  ('intention', 'singular', 6),
#  ('opponent', 'singular', 1),
#  ('leader', 'singular', 22),
#  ('manager', 'plural', 17),
#  ('ballot', 'plural', 8),
#  ('machine', 'singular', 7),
#  ('result', 'plural', 29),
#  ('fire', 'plural', 21),
#  ('technique', 'singular', 2),
#  ('plow', 'plural', 3),
#  ('unit', 'plural', 10),
#  ('warden', 'plural', 3),
#  ('slogan', 'singular', 1),
#  ('sign', 'singular', 3),
#  ('hoodlum', 'singular', 2),
#  ('1940', 'singular', 1),
#  ('tract', 'plural', 4),
#  ('municipalitie', 'singular', 1),
#  ('colleague', 'singular', 1),
#  ('term', 'plural', 13),
#  ('elephant', 'singular', 2),
#  ('tusk', 'singular', 1),
#  ('retirement', 'plural', 6),
#  ('1920', 'singular', 1),
#  ('mate', 'singular', 6),
#  ('choice', 'plural', 6),
#  ('talk', 'singular', 7),
#  ('interview', 'plural', 6),
#  ('reporter', 'singular', 4),
#  ('politician', 'singular', 4),
#  ('reason', 'plural', 18),
#  ('scandal', 'singular', 1),
#  ('work', 'plural', 45),
#  ('investigation', 'plural', 9),
#  ('newspaper', 'singular', 2),
#  ('forecast', 'singular', 2),
#  ('mortgage', 'singular', 2),
#  ('down-payment', 'singular', 1),
#  ('familie', 'singular', 8),
#  ('slum', 'singular', 1),
#  ('college', 'plural', 18),
#  ('dormitorie', 'singular', 2),
#  ('loan', 'singular', 6),
#  ('language', 'singular', 3),
#  ('agencie', 'singular', 8),
#  ('universitie', 'singular', 4),
#  ('Interview', 'singular', 1),
#  ('goal', 'plural', 10),
#  ('estimate', 'singular', 3),
#  ('technician', 'singular', 4),
#  ('expert', 'plural', 5),
#  ('job', 'plural', 16),
#  ('inhabitant', 'singular', 2),
#  ('affair', 'singular', 8),
#  ('neutralist', 'plural', 2),
#  ('half-brother', 'singular', 1),
#  ('delegation', 'plural', 3),
#  ('diplomat', 'singular', 1),
#  ('consultation', 'plural', 2),
#  ('tactic', 'plural', 2),
#  ('principle', 'plural', 4),
#  ('factor', 'plural', 6),
#  ('Thousand', 'singular', 1),
#  ('seat', 'singular', 4),
#  ('hundred', 'singular', 5),
#  ('ceremonie', 'singular', 5),
#  ('building', 'plural', 9),
#  ('shrine', 'singular', 1),
#  ('monument', 'singular', 1),
#  ('chapter', 'singular', 1),
#  ('suffragette', 'singular', 1),
#  ('soldier', 'singular', 2),
#  ('record', 'plural', 35),
#  ('track', 'plural', 10),
#  ('spectator', 'singular', 5),
#  ('statue', 'singular', 1),
#  ('branche', 'singular', 3),
#  ('academie', 'singular', 1),
#  ('representation', 'singular', 1),
#  ('territorie', 'singular', 1),
#  ('development', 'plural', 17),
#  ('foe', 'singular', 2),
#  ('friend', 'singular', 11),
#  ('edge', 'plural', 4),
#  ('job-seeker', 'singular', 1),
#  ('commitment', 'singular', 3),
#  ('lawmaker', 'singular', 2),
#  ('odd', 'singular', 2),
#  ('eye', 'singular', 5),
#  ('crossroad', 'singular', 1),
#  ('camp', 'plural', 3),
#  ('loyalist', 'singular', 1),
#  ('independent', 'singular', 1),
#  ('rank', 'plural', 3),
#  ('Report', 'singular', 1),
#  ('stresse', 'singular', 1),
#  ('finance', 'singular', 2),
#  ('revenue', 'singular', 13),
#  ('inconsistencie', 'singular', 1),
#  ('hand', 'plural', 17),
#  ('politico', 'singular', 1),
#  ('purpose', 'plural', 9),
#  ('expense', 'singular', 7),
#  ('alternative', 'plural', 2),
#  ('trim', 'singular', 1),
#  ('allegation', 'singular', 1),
#  ('follower', 'singular', 2),
#  ('affiliation', 'singular', 2),
#  ('bid', 'plural', 6),
#  ('Estimate', 'singular', 1),
#  ('contractor', 'singular', 2),
#  ('shortcut', 'singular', 1),
#  ('disclosure', 'singular', 2),
#  ('voucher', 'singular', 1),
#  ('charge', 'plural', 16),
#  ('director', 'plural', 30),
#  ('violation', 'plural', 3),
#  ('joint', 'plural', 6),
#  ('repair', 'plural', 2),
#  ('rate', 'singular', 9),
#  ('hotel', 'plural', 10),
#  ('room', 'plural', 17),
#  ('permit', 'singular', 1),
#  ('house', 'plural', 24),
#  ('dwelling', 'singular', 2),
#  ('accomodation', 'singular', 1),
#  ('dog', 'plural', 7),
#  ('male', 'singular', 1),
#  ('female', 'singular', 1),
#  ('owner', 'singular', 10),
#  ('catcher', 'plural', 2),
#  ('bite', 'singular', 1),
#  ('Petition', 'singular', 1),
#  ('agreement', 'plural', 14),
#  ('redeveloper', 'singular', 1),
#  ('hazard', 'singular', 2),
#  ('pedestrian', 'singular', 2),
#  ('apartment', 'plural', 10),
#  ('park', 'singular', 3),
#  ('churche', 'singular', 13),
#  ('cluster', 'singular', 2),
#  ('builder', 'singular', 7),
#  ('sector', 'singular', 1),
#  ('walkway', 'singular', 1),
#  ('bridge', 'singular', 2),
#  ('fighter', 'singular', 3),
#  ('teamster', 'singular', 4),
#  ('fracture', 'singular', 1),
#  ('ankle', 'singular', 2),
#  ('son', 'plural', 21),
#  ('guard', 'plural', 4),
#  ('pledge', 'singular', 1),
#  ('path', 'singular', 2),
#  ('door', 'plural', 6),
#  ('people', 'singular', 1),
#  ('good', 'singular', 5),
#  ('product', 'singular', 16),
#  ('lot', 'plural', 8),
#  ('mother', 'plural', 14),
#  ('blueprint', 'singular', 1),
#  ('specification', 'singular', 1),
#  ('speaker', 'plural', 4),
#  ('Poll', 'singular', 1),
#  ('belief', 'plural', 6),
#  ('delegate', 'singular', 7),
#  ('trend', 'plural', 6),
#  ('truth', 'plural', 7),
#  ('live', 'singular', 3),
#  ('scripture', 'singular', 1),
#  ('miracle', 'singular', 1),
#  ('mission', 'plural', 5),
#  ('Survey', 'singular', 1),
#  ('babie', 'singular', 2),
#  ('center', 'plural', 29),
#  ('pastor', 'singular', 1),
#  ('volunteer', 'singular', 5),
#  ('graduate', 'plural', 9),
#  ('apprentice', 'singular', 1),
#  ('motion', 'singular', 4),
#  ('Denial', 'singular', 1),
#  ('trial', 'plural', 20),
#  ('conspirator', 'singular', 2),
#  ('mail', 'singular', 3),
#  ('club', 'plural', 29),
#  ('Indication', 'singular', 1),
#  ('frame', 'plural', 3),
#  ('hit', 'singular', 11),
#  ('batter', 'singular', 1),
#  ('run', 'singular', 30),
#  ('start', 'plural', 12),
#  ('blow', 'plural', 2),
#  ('offering', 'plural', 4),
#  ('pitcher', 'singular', 3),
#  ('double', 'plural', 9),
#  ('chore', 'singular', 4),
#  ('safetie', 'singular', 1),
#  ('ball', 'plural', 33),
#  ('pinch-hitter', 'singular', 1),
#  ('pitche', 'singular', 1),
#  ('tallie', 'singular', 2),
#  ('runner', 'singular', 1),
#  ('homer', 'plural', 8),
#  ('player', 'singular', 12),
#  ('pound', 'singular', 4),
#  ('hitter', 'singular', 1),
#  ('specialist', 'singular', 1),
#  ('champion', 'plural', 10),
#  ('crowd', 'plural', 8),
#  ('game', 'plural', 51),
#  ('coache', 'singular', 4),
#  ('teammate', 'singular', 2),
#  ('hurler', 'singular', 1),
#  ('colt', 'singular', 1),
#  ('stage', 'plural', 14),
#  ('furlong', 'singular', 1),
#  ('celebrant', 'singular', 1),
#  ('steward', 'singular', 2),
#  ('horse', 'plural', 2),
#  ('race', 'plural', 19),
#  ('yard', 'singular', 22),
#  ('third', 'singular', 1),
#  ('tenth', 'singular', 1),
#  ('play', 'plural', 11),
#  ('pad', 'singular', 1),
#  ('trie', 'singular', 4),
#  ('conversion', 'singular', 2),
#  ('boy', 'plural', 16),
#  ('completion', 'singular', 3),
#  ('attempt', 'plural', 8),
#  ('kid', 'singular', 5),
#  ('performance', 'plural', 11),
#  ('stop', 'plural', 3),
#  ('thrust', 'singular', 1),
#  ('reserve', 'plural', 3),
#  ('sweat-suit', 'singular', 1),
#  ('reckoning', 'singular', 1),
#  ('collector', 'singular', 1),
#  ('quarterback', 'plural', 4),
#  ('linebacker', 'singular', 1),
#  ('movie', 'plural', 6),
#  ('passe', 'singular', 4),
#  ('touchdown', 'plural', 5),
#  ('strike', 'plural', 10),
#  ('ball-carrier', 'singular', 1),
#  ('statistic', 'singular', 2),
#  ('tosse', 'singular', 1),
#  ('average', 'plural', 13),
#  ('check', 'plural', 3),
#  ('baseball', 'plural', 23),
#  ('league', 'plural', 14),
#  ('test', 'plural', 13),
#  ('viewer', 'singular', 2),
#  ('inning', 'plural', 7),
#  ('base', 'plural', 14),
#  ('flie', 'singular', 1),
#  ('light', 'plural', 6),
#  ('fan', 'singular', 3),
#  ('reflexe', 'singular', 2),
#  ('at-bat', 'singular', 1),
#  ('chance', 'plural', 7),
#  ('masse', 'singular', 3),
#  ('heroic', 'singular', 1),
#  ('tongue', 'singular', 2),
#  ('feat', 'plural', 2),
#  ('achievement', 'plural', 8),
#  ('heart', 'plural', 5),
#  ('guy', 'plural', 3),
#  ('rookie', 'plural', 4),
#  ('laurel', 'singular', 1),
#  ('lefthander', 'plural', 2),
#  ('slugger', 'plural', 3),
#  ('merit', 'singular', 2),
#  ('season', 'plural', 43),
#  ('ruler', 'singular', 1),
#  ('afternoon', 'plural', 19),
#  ('injurie', 'singular', 3),
#  ('champ', 'singular', 1),
#  ('bleacher', 'singular', 2),
#  ('end', 'plural', 18),
#  ('aerial', 'singular', 1),
#  ('cufflink', 'singular', 1),
#  ('award', 'plural', 11),
#  ('sport', 'singular', 6),
#  ('writer', 'singular', 4),
#  ('personalitie', 'singular', 2),
#  ('barrier', 'singular', 2),
#  ('disappointment', 'plural', 2),
#  ('major', 'singular', 3),
#  ('matche', 'singular', 2),
#  ('tournament', 'plural', 13),
#  ('incompetent', 'singular', 1),
#  ('frustration', 'singular', 2),
#  ('pixie', 'singular', 1),
#  ('zombie', 'singular', 1),
#  ('banshee', 'singular', 1),
#  ('bound', 'singular', 2),
#  ('shot', 'plural', 11),
#  ('stroke', 'singular', 8),
#  ('duffer', 'singular', 2),
#  ('hacker', 'singular', 1),
#  ('echoe', 'singular', 1),
#  ('nerve', 'singular', 2),
#  ('string', 'singular', 4),
#  ('competitor', 'singular', 2),
#  ('rain', 'singular', 1),
#  ('father', 'plural', 14),
#  ('amendment', 'plural', 5),
#  ('team', 'plural', 33),
#  ('date', 'plural', 15),
#  ('bat', 'plural', 6),
#  ('plunker', 'singular', 1),
#  ('triumph', 'plural', 4),
#  ('Speaker', 'singular', 1),
#  ('word', 'plural', 14),
#  ('honor', 'plural', 10),
#  ('fault', 'singular', 1),
#  ('defeat', 'singular', 1),
#  ('trip', 'plural', 10),
#  ('cow', 'singular', 1),
#  ('talent', 'plural', 7),
#  ('career', 'plural', 10),
#  ('expectation', 'singular', 1),
#  ('height', 'singular', 2),
#  ("rbi'", 'singular', 1),
#  ('peak', 'plural', 3),
#  ('professional', 'singular', 1),
#  ('sight', 'singular', 1),
#  ('holiday', 'singular', 2),
#  ('uncle', 'plural', 4),
#  ('aunt', 'plural', 3),
#  ('huzzah', 'singular', 1),
#  ('ear', 'singular', 1),
#  ('embassie', 'singular', 1),
#  ('bushe', 'singular', 2),
#  ('activitie', 'singular', 9),
#  ('dancer', 'singular', 3),
#  ('dervishe', 'singular', 1),
#  ('invitation', 'plural', 4),
#  ('singer', 'singular', 1),
#  ('song', 'plural', 2),
#  ('costume', 'singular', 5),
#  ('tree', 'singular', 2),
#  ('street', 'singular', 7),
#  ('train', 'plural', 3),
#  ('shelter', 'plural', 2),
#  ('pub', 'singular', 1),
#  ('night', 'plural', 64),
#  ('ethic', 'singular', 1),
#  ('moral', 'singular', 1),
#  ('appearance', 'singular', 3),
#  ('gal', 'singular', 1),
#  ('phonie', 'singular', 1),
#  ('phone', 'plural', 5),
#  ('contrib', 'singular', 1),
#  ('exhibitor', 'singular', 1),
#  ('screening', 'singular', 1),
#  ('touche', 'singular', 1),
#  ('charitie', 'singular', 2),
#  ('holder', 'singular', 2),
#  ('clashe', 'singular', 1),
#  ('bomb', 'plural', 10),
#  ('peasant', 'singular', 1),
#  ('struggle', 'plural', 2),
#  ('role', 'plural', 5),
#  ('medic', 'singular', 1),
#  ('doing', 'singular', 1),
#  ('lesson', 'singular', 1),
#  ('suggestion', 'plural', 4),
#  ('boxe', 'singular', 3),
#  ('Member', 'singular', 5),
#  ('guest', 'singular', 14),
#  ('suite', 'plural', 2),
#  ('Grandparent', 'singular', 2),
#  ('Cocktail', 'singular', 2),
#  ('Guest', 'singular', 3),
#  ('junior', 'plural', 3),
#  ('decoration', 'singular', 2),
#  ('qualitie', 'singular', 2),
#  ('task', 'plural', 5),
#  ('alcoholic', 'singular', 2),
#  ('parolee', 'singular', 2),
#  ('schedule', 'plural', 9),
#  ('ticket', 'plural', 6),
#  ('concert', 'plural', 12),
#  ('cookie', 'singular', 3),
#  ('sweet', 'singular', 1),
#  ('motel-keeper', 'singular', 1),
#  ('suitcase', 'singular', 1),
#  ('mile', 'singular', 10),
#  ('motel', 'singular', 4),
#  ('station', 'plural', 10),
#  ('wagon', 'singular', 1),
#  ('restaurant', 'plural', 5),
#  ('stand', 'plural', 9),
#  ('accommodation', 'singular', 2),
#  ('taste', 'plural', 5),
#  ('peculiaritie', 'singular', 1),
#  ('pool', 'singular', 3),
#  ('adult', 'plural', 4),
#  ('Motorist', 'singular', 1),
#  ('tourist', 'singular', 1),
#  ('chair', 'singular', 4),
#  ('towel', 'singular', 1),
#  ('ant', 'plural', 3),
#  ('Parent', 'singular', 2),
#  ('attendant', 'singular', 1),
#  ('applique', 'singular', 1),
#  ('gardenia', 'singular', 1),
#  ('bridesmaid', 'singular', 1),
#  ('newlywed', 'singular', 1),
#  ('orchid', 'singular', 1),
#  ('studie', 'singular', 2),
#  ('prospect', 'singular', 7),
#  ('hat', 'singular', 3),
#  ('festivitie', 'singular', 4),
#  ('oyster', 'singular', 2),
#  ('specialtie', 'singular', 1),
#  ('effect', 'plural', 14),
#  ('flower', 'singular', 3),
#  ('reproduction', 'singular', 2),
#  ('shelve', 'singular', 1),
#  ('headquarter', 'singular', 8),
#  ('suburb', 'plural', 2),
#  ('bundle', 'plural', 4),
#  ('dinner', 'plural', 23),
#  ('fund-raiser', 'singular', 1),
#  ('husband', 'plural', 13),
#  ('hostesse', 'singular', 1),
#  ('arrangement', 'singular', 4),
#  ('dutie', 'singular', 2),
#  ('aide', 'singular', 3),
#  ('controller', 'singular', 1),
#  ('Model', 'singular', 1),
#  ('decade', 'plural', 5),
#  ('temperature', 'singular', 1),
#  ('poster', 'singular', 2),
#  ('painting', 'singular', 5),
#  ('sponsor', 'plural', 2),
#  ('artist', 'singular', 5),
#  ('Proceed', 'singular', 1),
#  ('level', 'plural', 14),
#  ('host', 'singular', 1),
#  ('ladie', 'singular', 3),
#  ('ballgown', 'singular', 1),
#  ('dance', 'plural', 6),
#  ('panel', 'plural', 9),
#  ('tier', 'singular', 1),
#  ('slipper', 'singular', 1),
#  ('maid', 'plural', 3),
#  ('ashe', 'singular', 1),
#  ('rose', 'singular', 1),
#  ('thread', 'singular', 1),
#  ('sequin', 'singular', 1),
#  ('bead', 'singular', 1),
#  ('cut', 'singular', 4),
#  ('lay-off', 'singular', 3),
#  ('employee', 'singular', 11),
#  ('supervisor', 'singular', 1),
#  ('union', 'plural', 21),
#  ('wage', 'singular', 11),
#  ('burn', 'singular', 5),
#  ('remark', 'plural', 3),
#  ('discrepancie', 'singular', 1),
#  ('bodie', 'singular', 4),
#  ('suit', 'plural', 6),
#  ('misunderstanding', 'singular', 1),
#  ('board', 'plural', 47),
#  ('Doctor', 'singular', 1),
#  ('deficiencie', 'singular', 1),
#  ('crew', 'plural', 6),
#  ('storm', 'plural', 4),
#  ('improvement', 'plural', 7),
#  ('operation', 'plural', 15),
#  ('laborer', 'singular', 2),
#  ('tire', 'singular', 3),
#  ('chain', 'plural', 2),
#  ('merchant', 'singular', 1),
#  ('observation', 'singular', 1),
#  ('supplie', 'singular', 6),
#  ('blade', 'singular', 1),
#  ('victim', 'plural', 4),
#  ('detective', 'singular', 6),
#  ('shooting', 'singular', 1),
#  ('brother', 'plural', 8),
#  ('spirit', 'plural', 16),
#  ('seeker', 'singular', 1),
#  ('component', 'singular', 1),
#  ('structure', 'plural', 3),
#  ('Other', 'singular', 4),
#  ('stair', 'singular', 1),
#  ('balconie', 'singular', 1),
#  ('secret', 'singular', 13),
#  ('agent', 'plural', 5),
#  ('design', 'singular', 9),
#  ('sub', 'plural', 4),
#  ('strongroom', 'singular', 1),
#  ('dot', 'singular', 1),
#  ('mark', 'plural', 8),
#  ('1950', 'singular', 2),
#  ('1960', 'singular', 1),
#  ('drawing', 'plural', 2),
#  ('lawyer', 'plural', 9),
#  ('client', 'plural', 4),
#  ('reactor', 'plural', 3),
#  ('turbine', 'singular', 1),
#  ('destroyer', 'singular', 2),
#  ('ship', 'plural', 5),
#  ('torpedoe', 'singular', 1),
#  ('Design', 'singular', 1),
#  ('signal', 'singular', 1),
#  ('wavelength', 'singular', 1),
#  ('code', 'singular', 1),
#  ('lighter', 'singular', 1),
#  ('narcotic', 'singular', 6),
#  ('indictment', 'plural', 5),
#  ('addict', 'singular', 1),
#  ('peddler', 'singular', 1),
#  ('rivalrie', 'singular', 2),
#  ('criminal', 'singular', 1),
#  ('jealousie', 'singular', 1),
#  ('grievance', 'singular', 1),
#  ('mention', 'singular', 1),
#  ('compensation', 'plural', 4),
#  ('comment', 'singular', 2),
#  ('youth', 'plural', 8),
#  ('homeowner', 'singular', 1),
#  ('casket', 'singular', 1),
#  ('fume', 'singular', 1),
#  ('girl', 'plural', 9),
#  ('arrear', 'singular', 1),
#  ('meal', 'singular', 3),
#  ('surpluse', 'singular', 1),
#  ('proceed', 'singular', 2),
#  ('troop', 'singular', 10),
#  ('move', 'plural', 7),
#  ('assault', 'plural', 3),
#  ('source', 'plural', 7),
#  ('claim', 'plural', 3),
#  ('squad', 'plural', 3),
#  ('tribunal', 'singular', 1),
#  ('collaborator', 'singular', 1),
#  ('execution', 'singular', 2),
#  ('rebel', 'singular', 3),
#  ('rifle', 'singular', 2),
#  ('jail', 'plural', 5),
#  ('priest', 'singular', 1),
#  ('prisoner', 'singular', 1),
#  ('by-law', 'singular', 2),
#  ('institution', 'singular', 10),
#  ('standard', 'singular', 4),
#  ('privilege', 'singular', 3),
#  ('provision', 'plural', 2),
#  ('obstacle', 'singular', 2),
#  ('endowment', 'singular', 2),
#  ('document', 'singular', 1),
#  ('application', 'singular', 4),
#  ('occupant', 'singular', 1),
#  ('laceration', 'singular', 1),
#  ('bruise', 'singular', 1),
#  ('stand-in', 'singular', 3),
#  ('theater', 'plural', 13),
#  ('operator', 'singular', 2),
#  ('profit', 'singular', 2),
#  ('Survivor', 'singular', 5),
#  ('sister', 'plural', 6),
#  ('daughter', 'plural', 26),
#  ('scratche', 'singular', 3),
#  ('uniform', 'plural', 3),
#  ('count', 'singular', 2),
#  ('doctor', 'plural', 3),
#  ('entrie', 'singular', 1),
#  ('transfer', 'singular', 1),
#  ('employment', 'plural', 7),
#  ('pension', 'plural', 5),
#  ('acre', 'singular', 8),
#  ('plane', 'plural', 18),
#  ('crop', 'plural', 4),
#  ('human', 'singular', 2),
#  ('Student', 'singular', 2),
#  ('computer', 'singular', 1),
#  ('camera', 'plural', 5),
#  ('engineer', 'singular', 2),
#  ('crashe', 'singular', 1),
#  ('Trooper', 'singular', 1),
#  ('flame', 'singular', 1),
#  ('commissioner', 'plural', 5),
#  ('wheel', 'plural', 3),
#  ('argument', 'plural', 6),
#  ('weaknesse', 'singular', 1),
#  ('communication', 'plural', 3),
#  ('robberie', 'singular', 1),
#  ('paper', 'plural', 2),
#  ('Employe', 'singular', 2),
#  ('function', 'plural', 2),
#  ('entertainer', 'singular', 1),
#  ('Service', 'singular', 1),
#  ('spice', 'singular', 1),
#  ('stockholder', 'singular', 1),
#  ('teenager', 'singular', 3),
#  ('youngster', 'singular', 3),
#  ('businesse', 'singular', 2),
#  ('Participant', 'singular', 1),
#  ('advisor', 'singular', 2),
#  ('Advisor', 'singular', 1),
#  ('show', 'plural', 18),
#  ('skie', 'singular', 2),
#  ('fairgoer', 'singular', 1),
#  ('Finalist', 'singular', 1),
#  ('ribbon', 'plural', 4),
#  ('blue', 'singular', 4),
#  ('egg', 'singular', 1),
#  ('championship', 'plural', 5),
#  ('appeal', 'singular', 6),
#  ('assessor', 'singular', 1),
#  ('assessment', 'singular', 1),
#  ('Appeal', 'singular', 1),
#  ('propertie', 'singular', 1),
#  ('pain', 'singular', 2),
#  ('Thieve', 'singular', 1),
#  ('fur', 'singular', 1),
#  ('jewel', 'singular', 1),
#  ('coin', 'singular', 2),
#  ('intruder', 'singular', 1),
#  ('ring', 'plural', 5),
#  ('earring', 'singular', 2),
#  ('thieve', 'singular', 1),
#  ('Drawer', 'singular', 1),
#  ('cabinet', 'plural', 4),
#  ('bedroom', 'plural', 6),
#  ('plant', 'plural', 8),
#  ('collection', 'plural', 24),
#  ('rib', 'singular', 1),
#  ('damage', 'plural', 4),
#  ('lieutenant', 'singular', 2),
#  ('Person', 'singular', 1),
#  ('Score', 'singular', 1),
#  ('contributor', 'singular', 1),
#  ('pennie', 'singular', 1),
#  ('nickel', 'singular', 1),
#  ('dime', 'singular', 2),
#  ('quarter', 'plural', 4),
#  ('alteration', 'singular', 1),
#  ('bed', 'singular', 3),
#  ('incident', 'plural', 2),
#  ('connection', 'plural', 7),
#  ('control', 'plural', 18),
#  ('mistake', 'singular', 2),
#  ('experiment', 'singular', 1),
#  ('farmer', 'singular', 5),
#  ('bird', 'singular', 4),
#  ('enemie', 'singular', 1),
#  ('insect', 'singular', 1),
#  ('rodent', 'singular', 1),
#  ('grape', 'singular', 2),
#  ('blueberrie', 'singular', 1),
#  ('restriction', 'singular', 3),
#  ('wetland', 'singular', 1),
#  ('pesticide', 'singular', 1),
#  ('tideland', 'singular', 1),
#  ('animal', 'plural', 2),
#  ('pilot', 'plural', 4),
#  ('rocket-bomb', 'singular', 1),
#  ('surface', 'singular', 1),
#  ('wing', 'plural', 4),
#  ('aileron', 'singular', 1),
#  ('Moment', 'singular', 1),
#  ('flight', 'plural', 8),
#  ('missile', 'plural', 9),
#  ('Pilot', 'singular', 1),
#  ('glider', 'singular', 1),
#  ('Nation', 'singular', 1),
#  ('weapon', 'singular', 6),
#  ('Government', 'plural', 2),
#  ('buddie', 'singular', 1),
#  ('chief', 'plural', 6),
#  ('prosecutor', 'singular', 2),
#  ('gangster', 'singular', 1),
#  ('payment', 'singular', 8),
#  ('janitor', 'singular', 2),
#  ('factorie', 'singular', 2),
#  ('amount', 'plural', 10),
#  ('lien', 'singular', 1),
#  ('share', 'singular', 19),
#  ('Investor', 'singular', 3),
#  ('inquirie', 'singular', 3),
#  ('Letter', 'singular', 1),
#  ('ream', 'singular', 1),
#  ('underwriter', 'singular', 2),
#  ('kind', 'plural', 18),
#  ('earning', 'singular', 7),
#  ('investor', 'singular', 7),
#  ('run-up', 'singular', 1),
#  ('price-earning', 'singular', 2),
#  ('Food', 'singular', 1),
#  ('ratio', 'singular', 1),
#  ('executive', 'plural', 12),
#  ('abilitie', 'singular', 1),
#  ('merger', 'plural', 3),
#  ('buyer', 'singular', 2),
#  ('ton', 'singular', 1),
#  ('gin', 'plural', 12),
#  ("1900'", 'singular', 1),
#  ('drier', 'singular', 3),
#  ('cleaner', 'singular', 2),
#  ('Headquarter', 'singular', 3),
#  ('Factorie', 'singular', 1),
#  ('heater', 'singular', 1),
#  ('extractor', 'singular', 1),
#  ('separator', 'singular', 1),
#  ('saw', 'singular', 2),
#  ('bearing', 'singular', 1),
#  ('doldrum', 'singular', 1),
#  ('Registration', 'singular', 1),
#  ('dealer', 'singular', 10),
#  ('maker', 'plural', 4),
#  ...]

# %%
#B. Which word has the greatest number of distinct tags?
tagged_words = brown.tagged_words(categories = "news")
cdf = nltk.ConditionalFreqDist(( word.lower(), tag) for (word, tag) in tagged_words)
#This format saves the tags assoicated with the words. We want distinct number .
#Thus we increament one if NN is used x times. Increament one if NNS is used n times.

# %%
len(cdf["the"])

# %%
result = [  (word, len(cdf[word] ) ) for word in cdf.keys() ]

# %%
sorted( result, key = itemgetter(1) , reverse = True)
# Out:
# [('to', 7),
#  ('house', 7),
#  ('home', 6),
#  ('that', 5),
#  ('for', 5),
#  ('a', 5),
#  ('best', 5),
#  ('fair', 5),
#  ('back', 5),
#  ('first', 5),
#  ('near', 5),
#  ('set', 5),
#  ('last', 5),
#  ('like', 5),
#  ('march', 5),
#  ('good', 5),
#  ('little', 5),
#  ('better', 5),
#  ('3', 5),
#  ('high', 5),
#  ('white', 5),
#  ('cut', 5),
#  ('open', 5),
#  ('second', 5),
#  ('hit', 5),
#  ('french', 5),
#  ('no', 4),
#  ('place', 4),
#  ('in', 4),
#  ('by', 4),
#  ('only', 4),
#  ('act', 4),
#  ('end', 4),
#  ('on', 4),
#  ('cost', 4),
#  ('as', 4),
#  ('major', 4),
#  ('general', 4),
#  ('plan', 4),
#  ('police', 4),
#  ('more', 4),
#  ('present', 4),
#  ('held', 4),
#  ('force', 4),
#  ('out', 4),
#  ('must', 4),
#  ('issue', 4),
#  ('most', 4),
#  ('increase', 4),
#  ('past', 4),
#  ('read', 4),
#  ('post', 4),
#  ('down', 4),
#  ('left', 4),
#  ('help', 4),
#  ('report', 4),
#  ('red', 4),
#  ('fine', 4),
#  ('right', 4),
#  ('chief', 4),
#  ('close', 4),
#  ('cook', 4),
#  ('case', 4),
#  ('grant', 4),
#  ('even', 4),
#  ('st.', 4),
#  ('reading', 4),
#  ('hill', 4),
#  ('field', 4),
#  ('met', 4),
#  ('half', 4),
#  ('point', 4),
#  ('green', 4),
#  ('works', 4),
#  ('round', 4),
#  ('beat', 4),
#  ('brown', 4),
#  ('lay', 4),
#  ('gold', 4),
#  ('mother', 4),
#  ('swim', 4),
#  ('ballet', 4),
#  ('congolese', 4),
#  ('the', 3),
#  ('grand', 3),
#  ('jury', 3),
#  ('of', 3),
#  ('further', 3),
#  ('city', 3),
#  ('executive', 3),
#  ('had', 3),
#  ('charge', 3),
#  ('and', 3),
#  ('charged', 3),
#  ('court', 3),
#  ('judge', 3),
#  ('such', 3),
#  ('are', 3),
#  ('studied', 3),
#  ('purchasing', 3),
#  ('well', 3),
#  ('accepted', 3),
#  ('proposed', 3),
#  ('however', 3),
#  ('two', 3),
#  ('urged', 3),
#  ('next', 3),
#  ('so', 3),
#  ('may', 3),
#  ('at', 3),
#  ('state', 3),
#  ('welfare', 3),
#  ('services', 3),
#  ('one', 3),
#  ('fit', 3),
#  ('all', 3),
#  ('less', 3),
#  ('future', 3),
#  ('will', 3),
#  ('under', 3),
#  ('elected', 3),
#  ('new', 3),
#  ('1', 3),
#  ('added', 3),
#  ('there', 3),
#  ('jail', 3),
#  ('four', 3),
#  ('2', 3),
#  ('tax', 3),
#  ('mayor', 3),
#  ('son', 3),
#  ('year', 3),
#  ('e.', 3),
#  ('since', 3),
#  ('run', 3),
#  ('georgia', 3),
#  ('race', 3),
#  ('top', 3),
#  ('party', 3),
#  ('w.', 3),
#  ('up', 3),
#  ('texas', 3),
#  ('john', 3),
#  ('asked', 3),
#  ('before', 3),
#  ('public', 3),
#  ('relations', 3),
#  ('expected', 3),
#  ('head', 3),
#  ('senate', 3),
#  ('study', 3),
#  ('made', 3),
#  ('worth', 3),
#  ('go', 3),
#  ('roads', 3),
#  ('road', 3),
#  ('fund', 3),
#  ('off', 3),
#  ('battle', 3),
#  ('about', 3),
#  ('plans', 3),
#  ('day', 3),
#  ('research', 3),
#  ('sought', 3),
#  ('while', 3),
#  ('pay', 3),
#  ('jackson', 3),
#  ('aid', 3),
#  ('barber', 3),
#  ('support', 3),
#  ('washington', 3),
#  ('board', 3),
#  ('long', 3),
#  ('put', 3),
#  ('ordinary', 3),
#  ('order', 3),
#  ('just', 3),
#  ('church', 3),
#  ('calls', 3),
#  ('shot', 3),
#  ('days', 3),
#  ('local', 3),
#  ('led', 3),
#  ('fight', 3),
#  ('hearing', 3),
#  ('revenue', 3),
#  ('rules', 3),
#  ('week', 3),
#  ('termed', 3),
#  ('over', 3),
#  ('jones', 3),
#  ('enough', 3),
#  ('dallas', 3),
#  ('here', 3),
#  ('harris', 3),
#  ('estimated', 3),
#  ('pro', 3),
#  ('question', 3),
#  ('faces', 3),
#  ('sent', 3),
#  ('planning', 3),
#  ('coast', 3),
#  ('paris', 3),
#  ('need', 3),
#  ('kept', 3),
#  ('u.s.', 3),
#  ('west', 3),
#  ('reported', 3),
#  ('water', 3),
#  ('big', 3),
#  ('cover', 3),
#  ('attack', 3),
#  ('de', 3),
#  ('la', 3),
#  ('junior', 3),
#  ('master', 3),
#  ('&', 3),
#  ('institute', 3),
#  ('served', 3),
#  ('corps', 3),
#  ('denton', 3),
#  ('living', 3),
#  ('criminal', 3),
#  ('six', 3),
#  ('honor', 3),
#  ('conflict', 3),
#  ('business', 3),
#  ('american', 3),
#  ('much', 3),
#  ('quite', 3),
#  ('way', 3),
#  ('press', 3),
#  ("it's", 3),
#  ('involved', 3),
#  ('meet', 3),
#  ('acting', 3),
#  ('building', 3),
#  ('ward', 3),
#  ('outside', 3),
#  ('east', 3),
#  ('faced', 3),
#  ('9', 3),
#  ('care', 3),
#  ('raised', 3),
#  ('finance', 3),
#  ('higher', 3),
#  ('noted', 3),
#  ('stay', 3),
#  ('needed', 3),
#  ('equal', 3),
#  ('criticized', 3),
#  ('republican', 3),
#  ('change', 3),
#  ('housing', 3),
#  ('rule', 3),
#  ('demand', 3),
#  ('north', 3),
#  ('atlantic', 3),
#  ('route', 3),
#  ('allies', 3),
#  ('advance', 3),
#  ('daily', 3),
#  ('arms', 3),
#  ('dean', 3),
#  ('soviet', 3),
#  ('individual', 3),
#  ('inside', 3),
#  ('lack', 3),
#  ('come', 3),
#  ('laos', 3),
#  ('military', 3),
#  ('international', 3),
#  ('control', 3),
#  ('boston', 3),
#  ('trade', 3),
#  ('far', 3),
#  ('nations', 3),
#  ('show', 3),
#  ('war', 3),
#  ('royal', 3),
#  ('juvenile', 3),
#  ('crime', 3),
#  ('advisory', 3),
#  ('labor', 3),
#  ('bet', 3),
#  ('across', 3),
#  ('concern', 3),
#  ('rotary', 3),
#  ('hand', 3),
#  ('hope', 3),
#  ('model', 3),
#  ('cited', 3),
#  ('traffic', 3),
#  ('fall', 3),
#  ('common', 3),
#  ('jersey', 3),
#  ('industry', 3),
#  ('plant', 3),
#  ('answer', 3),
#  ('commissioner', 3),
#  ('conservation', 3),
#  ('bid', 3),
#  ('planned', 3),
#  ('lives', 3),
#  ('representative', 3),
#  ('7', 3),
#  ('view', 3),
#  ('key', 3),
#  ('hunter', 3),
#  ('escape', 3),
#  ('encounter', 3),
#  ('low', 3),
#  ('stage', 3),
#  ('u.', 3),
#  ('s.', 3),
#  ('n.', 3),
#  ('due', 3),
#  ('officer', 3),
#  ('above', 3),
#  ('artist', 3),
#  ('miles', 3),
#  ('street', 3),
#  ('square', 3),
#  ('throw', 3),
#  ('cash', 3),
#  ('philadelphia', 3),
#  ('played', 3),
#  ('charges', 3),
#  ('sue', 3),
#  ('wide', 3),
#  ('single', 3),
#  ('account', 3),
#  ('drive', 3),
#  ('kansas', 3),
#  ('blast', 3),
#  ('flash', 3),
#  ('wall', 3),
#  ('hood', 3),
#  ('flies', 3),
#  ('graduate', 3),
#  ('total', 3),
#  ('rush', 3),
#  ('al', 3),
#  ('grove', 3),
#  ('lodge', 3),
#  ('light', 3),
#  ('miami', 3),
#  ('hits', 3),
#  ('homer', 3),
#  ('wild', 3),
#  ('fashion', 3),
#  ('stadium', 3),
#  ('double', 3),
#  ('buddy', 3),
#  ('ball', 3),
#  ('break', 3),
#  ('lighter', 3),
#  ('camp', 3),
#  ('art', 3),
#  ('yankee', 3),
#  ('coach', 3),
#  ('king', 3),
#  ('ohio', 3),
#  ('chicago', 3),
#  ('cotton', 3),
#  ('slaughter', 3),
#  ('happy', 3),
#  ('treatment', 3),
#  ('ogden', 3),
#  ('standard', 3),
#  ('player', 3),
#  ('guy', 3),
#  ('tv', 3),
#  ('cincinnati', 3),
#  ('23', 3),
#  ('award', 3),
#  ('branch', 3),
#  ('amateur', 3),
#  ('golden', 3),
#  ('human', 3),
#  ('19', 3),
#  ('supply', 3),
#  ('hall', 3),
#  ('spread', 3),
#  ('marriage', 3),
#  ('london', 3),
#  ('italian', 3),
#  ('flower', 3),
#  ('stock', 3),
#  ('rest', 3),
#  ('gala', 3),
#  ('black', 3),
#  ('dining', 3),
#  ('welcome', 3),
#  ('motel', 3),
#  ('methodist', 3),
#  ('christian', 3),
#  ('flowers', 3),
#  ('brothers', 3),
#  ('rose', 3),
#  ('putt', 3),
#  ('lady', 3),
#  ('register', 3),
#  ('annapolis', 3),
#  ('summoned', 3),
#  ("navy's", 3),
#  ('british', 3),
#  ('highest', 3),
#  ('electric', 3),
#  ('witness', 3),
#  ('appeal', 3),
#  ('havana', 3),
#  ('northwest', 3),
#  ('birdie', 3),
#  ('investment', 3),
#  ('rear', 3),
#  ('birmingham', 3),
#  ('pride', 3),
#  ('strip', 3),
#  ('lists', 3),
#  ('exchange', 3),
#  ('stars', 3),
#  ('hollywood', 3),
#  ('mine', 3),
#  ('fulton', 2),
#  ('county', 2),
#  ('said', 2),
#  ('investigation', 2),
#  ('primary', 2),
#  ('election', 2),
#  ('produced', 2),
#  ('.', 2),
#  ('committee', 2),
#  (',', 2),
#  ('thanks', 2),
#  ('atlanta', 2),
#  ('was', 2),
#  ('conducted', 2),
#  ('superior', 2),
#  ('reports', 2),
#  ('won', 2),
#  ('received', 2),
#  ('considering', 2),
#  ('number', 2),
#  ('size', 2),
#  ('this', 2),
#  ('it', 2),
#  ('many', 2),
#  ('recommended', 2),
#  ('legislators', 2),
#  ('revised', 2),
#  ('commented', 2),
#  ('other', 2),
#  ('operated', 2),
#  ('practices', 2),
#  ('merger', 2),
#  ('be', 2),
#  ('combined', 2),
#  ('greater', 2),
#  ('administration', 2),
#  ('department', 2),
#  ('is', 2),
#  ('lacking', 2),
#  ('result', 2),
#  ('policies', 2),
#  ('problem', 2),
#  ('law', 2),
#  ('legislature', 2),
#  ('funds', 2),
#  ('date', 2),
#  ('handling', 2),
#  ('federal', 2),
#  ('foster', 2),
#  ('program', 2),
#  ('but', 2),
#  ('through', 2),
#  ('counties', 2),
#  ('with', 2),
#  ('might', 2),
#  ('our', 2),
#  ('we', 2),
#  ('feel', 2),
#  ('some', 2),
#  ('do', 2),
#  ('fire', 2),
#  ('fees', 2),
#  ('wards', 2),
#  ('found', 2),
#  ('into', 2),
#  ('bar', 2),
#  ('association', 2),
#  ('citizens', 2),
#  ('effect', 2),
#  ('from', 2),
#  ('costs', 2),
#  ('appointed', 2),
#  ('airport', 2),
#  ('jan.', 2),
#  ('not', 2),
#  ('pricing', 2),
#  ('ask', 2),
#  ('deputies', 2),
#  (':', 2),
#  ('(', 2),
#  (')', 2),
#  ('doctor', 2),
#  ('medical', 2),
#  ('night', 2),
#  ('work', 2),
#  ('pass', 2),
#  ('permit', 2),
#  ('operation', 2),
#  ('office', 2),
#  ('grady', 2),
#  ('hospital', 2),
#  ('health', 2),
#  ('william', 2),
#  ('b.', 2),
#  ('filed', 2),
#  ('divorce', 2),
#  ('his', 2),
#  ('pearl', 2),
#  ('mrs.', 2),
#  ('j.', 2),
#  ('property', 2),
#  ('agreed', 2),
#  ('upon', 2),
#  ('listed', 2),
#  ("mayor's", 2),
#  ('attorney', 2),
#  ('ala.', 2),
#  ('lived', 2),
#  ('man', 2),
#  ('than', 2),
#  ('council', 2),
#  ('succeeded', 2),
#  ('after', 2),
#  ('announced', 2),
#  ('would', 2),
#  ('republicans', 2),
#  ('strong', 2),
#  ("governor's", 2),
#  ('official', 2),
#  ('gop', 2),
#  ('chairman', 2),
#  ('meeting', 2),
#  ('blue', 2),
#  ('brought', 2),
#  ('james', 2),
#  ('8', 2),
#  ('newly', 2),
#  ('tower', 2),
#  ('speaker', 2),
#  ('warned', 2),
#  ('governor', 2),
#  ('petitions', 2),
#  ('warning', 2),
#  ('vote', 2),
#  ('attended', 2),
#  ('wanted', 2),
#  ('wait', 2),
#  ('face', 2),
#  ('making', 2),
#  ('alternative', 2),
#  ('five', 2),
#  ('sign', 2),
#  ('allowed', 2),
#  ('hold', 2),
#  ('unit', 2),
#  ('system', 2),
#  ('highway', 2),
#  ('director', 2),
#  ('campaign', 2),
#  ('time', 2),
#  ('assistant', 2),
#  ('three', 2),
#  ('years', 2),
#  ('starts', 2),
#  ('become', 2),
#  ('wind', 2),
#  ('bond', 2),
#  ('approved', 2),
#  ('allotted', 2),
#  ('rural', 2),
#  ('visit', 2),
#  ('likely', 2),
#  ('earlier', 2),
#  ('construction', 2),
#  ('bonds', 2),
#  ('learned', 2),
#  ('very', 2),
#  ('reconstruction', 2),
#  ('test', 2),
#  ('then', 2),
#  ('sales', 2),
#  ('contracts', 2),
#  ('let', 2),
#  ('heavily', 2),
#  ('traveled', 2),
#  ('authority', 2),
#  ('revolving', 2),
#  ('issued', 2),
#  ('old', 2),
#  ('paid', 2),
#  ('opened', 2),
#  ('against', 2),
#  ('told', 2),
#  ('constitution', 2),
#  ('consulted', 2),
#  ('yet', 2),
#  ('offer', 2),
#  ('action', 2),
#  ('outright', 2),
#  ('notice', 2),
#  ('given', 2),
#  ('worked', 2),
#  ('passed', 2),
#  ('offered', 2),
#  ('rejected', 2),
#  ('veteran', 2),
#  ('education', 2),
#  ('opposed', 2),
#  ('commerce', 2),
#  ('increased', 2),
#  ('provided', 2),
#  ('congressional', 2),
#  ('congress', 2),
#  ('directed', 2),
#  ('colquitt', 2),
#  ('miller', 2),
#  ('school', 2),
#  ('policeman', 2),
#  ('i', 2),
#  ('saw', 2),
#  ('agriculture', 2),
#  ('defeated', 2),
#  ('principal', 2),
#  ('democratic', 2),
#  ('votes', 2),
#  ('got', 2),
#  ('carey', 2),
#  ('armed', 2),
#  ('drop', 2),
#  ('liquor', 2),
#  ('bit', 2),
#  ('p.', 2),
#  ('18', 2),
#  ('too', 2),
#  ('scheduled', 2),
#  ('sheriff', 2),
#  ('promise', 2),
#  ('real', 2),
#  ('austin', 2),
#  ('price', 2),
#  ('abandoned', 2),
#  ('bankers', 2),
#  ('measure', 2),
#  ('considerably', 2),
#  ('taxation', 2),
#  ('questions', 2),
#  ('doubt', 2),
#  ('extremely', 2),
#  ('estimate', 2),
#  ('17', 2),
#  ('merely', 2),
#  ('means', 2),
#  ('republic', 2),
#  ('permits', 2),
#  ('bank', 2),
#  ('stocks', 2),
#  ('seven', 2),
#  ('bill', 2),
#  ('banks', 2),
#  ('insurance', 2),
#  ('because', 2),
#  ('almost', 2),
#  ('declared', 2),
#  ('lawrence', 2),
#  ('opposition', 2),
#  ('keynote', 2),
#  ('you', 2),
#  ('charles', 2),
#  ('hughes', 2),
#  ('sherman', 2),
#  ('sponsor', 2),
#  ('amount', 2),
#  ('gift', 2),
#  ('denied', 2),
#  ('howard', 2),
#  ('argued', 2),
#  ('introduced', 2),
#  ('senators', 2),
#  ('schools', 2),
#  ('deaf', 2),
#  ('special', 2),
#  ('schooling', 2),
#  ('students', 2),
#  ('reduced', 2),
#  ('agency', 2),
#  ('children', 2),
#  ('between', 2),
#  ('attend', 2),
#  ('residential', 2),
#  ('savings', 2),
#  ("year's", 2),
#  ('live', 2),
#  ('still', 2),
#  ('betting', 2),
#  ('people', 2),
#  ('informed', 2),
#  ('san', 2),
#  ('heard', 2),
#  ('proposal', 2),
#  ('hard', 2),
#  ('later', 2),
#  ('bills', 2),
#  ('committees', 2),
#  ('districts', 2),
#  ('beaumont', 2),
#  ('district', 2),
#  ('third', 2),
#  ('lamar', 2),
#  ('adopted', 2),
#  ('r.', 2),
#  ('gulf', 2),
#  ('louis', 2),
#  ('group', 2),
#  ('return', 2),
#  ('plus', 2),
#  ('series', 2),
#  ('league', 2),
#  ('own', 2),
#  ('license', 2),
#  ('gas', 2),
#  ('frank', 2),
#  ('underground', 2),
#  ('marshall', 2),
#  ('commission', 2),
#  ('suggested', 2),
#  ('selected', 2),
#  ('justice', 2),
#  ('supreme', 2),
#  ('representatives', 2),
#  ('decided', 2),
#  ('taking', 2),
#  ('kind', 2),
#  ('affairs', 2),
#  ('april', 2),
#  ('4', 2),
#  ('senator', 2),
#  ('delay', 2),
#  ('feb.', 2),
#  ('22', 2),
#  ('legislative', 2),
#  ('two-thirds', 2),
#  ('choice', 2),
#  ('lost', 2),
#  ('needs', 2),
#  ('development', 2),
#  ('fort', 2),
#  ('places', 2),
#  ('ended', 2),
#  ('sponsored', 2),
#  ('maximum', 2),
#  ('loan', 2),
#  ('could', 2),
#  ('project', 2),
#  ('felt', 2),
#  ('spent', 2),
#  ('providing', 2),
#  ('benefit', 2),
#  ("bill's", 2),
#  ('mission', 2),
#  ('serving', 2),
#  ('learning', 2),
#  ('c.', 2),
#  ('24', 2),
#  ('12', 2),
#  ('teaching', 2),
#  ('required', 2),
#  ('senior', 2),
#  ('college', 2),
#  ('teachers', 2),
#  ('credit', 2),
#  ('person', 2),
#  ('english', 2),
#  ('permitted', 2),
#  ('joined', 2),
#  ('named', 2),
#  ('dr.', 2),
#  ('president', 2),
#  ('earned', 2),
#  ('university', 2),
#  ('oklahoma', 2),
#  ('science', 2),
#  ('bachelor', 2),
#  ('southwestern', 2),
#  ('island', 2),
#  ('massachusetts', 2),
#  ('technology', 2),
#  ('captain', 2),
#  ('basketball', 2),
#  ('football', 2),
#  ('athletic', 2),
#  ('associate', 2),
#  ('border', 2),
#  ('patrolman', 2),
#  ('signal', 2),
#  ('army', 2),
#  ('independent', 2),
#  ('chester', 2),
#  ('o.', 2),
#  ('called', 2),
#  ('firm', 2),
#  ('10', 2),
#  ('range', 2),
#  ('causes', 2),
#  ('family', 2),
#  ('solve', 2),
#  ('monthly', 2),
#  ('forced', 2),
#  ('cases', 2),
#  ('deal', 2),
#  ('relatively', 2),
#  ('limited', 2),
#  ('underlying', 2),
#  ('extension', 2),
#  ('trial', 2),
#  ('defense', 2),
#  ('viewed', 2),
#  ('eight', 2),
#  ('policemen', 2),
#  ('request', 2),
#  ('prejudicial', 2),
#  ('aspects', 2),
#  ('indicated', 2),
#  ('others', 2),
#  ('amounts', 2),
#  ('july', 2),
#  ('kennedy', 2),
#  ('pushed', 2),
#  ('berlin', 2),
#  ('tomorrow', 2),
#  ('radio', 2),
#  ('summer', 2),
#  ('writing', 2),
#  ('talked', 2),
#  ('returned', 2),
#  ('decisions', 2),
#  ('pierre', 2),
#  ('secretary', 2),
#  ('staff', 2),
#  ('wording', 2),
#  ('rather', 2),
#  ('obtained', 2),
#  ('matter', 2),
#  ('rights', 2),
#  ('ruling', 2),
#  ('ruled', 2),
#  ('133', 2),
#  ('morris', 2),
#  ('prosecutor', 2),
#  ('admitted', 2),
#  ('questioned', 2),
#  ('constituted', 2),
#  ('used', 2),
#  ('room', 2),
#  ('24th', 2),
#  ('claims', 2),
#  ('precedent', 2),
#  ('social', 2),
#  ('security', 2),
#  ('workers', 2),
#  ('covered', 2),
#  ('railroad', 2),
#  ('tied', 2),
#  ('requests', 2),
#  ('capitol', 2),
#  ('$37', 2),
#  ('boost', 2),
#  ('rise', 2),
#  ('figures', 2),
#  ('nursing', 2),
#  ('full', 2),
#  ('payment', 2),
#  ('patient', 2),
#  ('following', 2),
#  ('formula', 2),
#  ('use', 2),
#  ('service', 2),
#  ('states', 2),
#  ('modest', 2),
#  ('wish', 2),
#  ('staggered', 2),
#  ('caused', 2),
#  ('essential', 2),
#  ('freedom', 2),
#  ("wouldn't", 2),
#  ('doctors', 2),
#  ("president's", 2),
#  ("nation's", 2),
#  ('student', 2),
#  ('young', 2),
#  ('contributions', 2),
#  ('government', 2),
#  ('matching', 2),
#  ('area', 2),
#  ('sum', 2),
#  ('bureau', 2),
#  ('national', 2),
#  ('asks', 2),
#  ('vocational', 2),
#  ('how', 2),
#  ('reaction', 2),
#  ('along', 2),
#  ('lines', 2),
#  ('hailed', 2),
#  ('leader', 2),
#  ('ill.', 2),
#  ('tex.', 2),
#  ('mighty', 2),
#  ('11', 2),
#  ('speed', 2),
#  ('administrator', 2),
#  ('presidential', 2),
#  ('cabinet', 2),
#  ('enforce', 2),
#  ('wayne', 2),
#  ('connection', 2),
#  ('oslo', 2),
#  ('organization', 2),
#  ('foreign', 2),
#  ('ministers', 2),
#  ('mutual', 2),
#  ('understanding', 2),
#  ('step', 2),
#  ('changes', 2),
#  ('particularly', 2),
#  ('powers', 2),
#  ('africa', 2),
#  ('troubles', 2),
#  ('explosion', 2),
#  ('weeks', 2),
#  ('walk', 2),
#  ('tension', 2),
#  ('assembly', 2),
#  ('discussed', 2),
#  ('canada', 2),
#  ('somewhat', 2),
#  ('allied', 2),
#  ('track', 2),
#  ('behind', 2),
#  ('alliance', 2),
#  ('closer', 2),
#  ('line', 2),
#  ('united', 2),
#  ('leadership', 2),
#  ('hoped', 2),
#  ('clear', 2),
#  ('danger', 2),
#  ('exploratory', 2),
#  ('mood', 2),
#  ('waters', 2),
#  ('union', 2),
#  ('stand', 2),
#  ('once', 2),
#  ('again', 2),
#  ('whole', 2),
#  ('surveyed', 2),
#  ('achievement', 2),
#  ('around', 2),
#  ('treated', 2),
#  ('regard', 2),
#  ('spring', 2),
#  ('main', 2),
#  ('economic', 2),
#  ('cooperation', 2),
#  ('strengthening', 2),
#  ('forces', 2),
#  ('maintenance', 2),
#  ('threshold', 2),
#  ('laid', 2),
#  ('completely', 2),
#  ('fulfilled', 2),
#  ('moves', 2),
#  ('geneva', 2),
#  ('conference', 2),
#  ('interested', 2),
#  ('setting', 2),
#  ('communist', 2),
#  ('attacks', 2),
#  ('south', 2),
#  ('viet', 2),
#  ('nam', 2),
#  ('count', 2),
#  ('hopes', 2),
#  ('lao', 2),
#  ('modified', 2),
#  ('showing', 2),
#  ('gain', 2),
#  ...]

# %% [markdown]
# Thus "to" and "house" have the greatest number of distinct tags

# %%
#C. List tags in order of decreasing frequency. What do the 20 most frequent tags represent?

#Only cars about the frequency of tags. The cdf from A. should work for this. 
cdf = nltk.ConditionalFreqDist((tag, word.lower()) for (word, tag) in tagged_words)

# %%
cdf.items()
# Out:
# dict_items([('AT', FreqDist({'the': 6333, 'a': 2112, 'an': 311, 'no': 109, 'every': 28})), ('NP-TL', FreqDist({'york': 52, 'texas': 13, 'u.s.': 12, 'dallas': 11, 'fulton': 10, 'providence': 10, 'orleans': 10, 'emory': 10, 'rhode': 9, 'chicago': 9, ...})), ('NN-TL', FreqDist({'president': 88, 'house': 68, 'state': 59, 'university': 42, 'city': 41, 'dr.': 41, 'county': 36, 'committee': 35, 'senate': 32, 'court': 28, ...})), ('JJ-TL', FreqDist({'new': 88, 'national': 39, 'democratic': 35, 'white': 34, 'north': 28, 'american': 25, 'south': 17, 'federal': 16, 'west': 15, 'central': 15, ...})), ('VBD', FreqDist({'said': 384, 'took': 47, 'told': 45, 'made': 44, 'got': 42, 'came': 41, 'went': 37, 'began': 34, 'added': 24, 'received': 23, ...})), ('NR', FreqDist({'yesterday': 56, 'today': 55, 'home': 54, 'monday': 54, 'sunday': 51, 'tuesday': 43, 'friday': 41, 'saturday': 33, 'wednesday': 22, 'thursday': 20, ...})), ('NN', FreqDist({'year': 137, 'time': 98, 'state': 92, 'week': 86, 'man': 72, 'home': 72, 'program': 65, 'school': 65, 'night': 64, 'day': 62, ...})), ('IN', FreqDist({'of': 2724, 'in': 1953, 'for': 927, 'to': 889, 'on': 648, 'at': 632, 'with': 564, 'by': 500, 'from': 349, 'into': 114, ...})), ('NP$', FreqDist({"kennedy's": 11, "georgia's": 7, "ruth's": 7, "palmer's": 6, "mantle's": 5, "atlanta's": 4, "gardner's": 4, "willie's": 4, "stein's": 4, "america's": 4, ...})), ('JJ', FreqDist({'new': 150, 'such': 54, 'good': 45, 'high': 45, 'american': 40, 'own': 39, 'public': 38, 'special': 38, 'big': 38, 'local': 37, ...})), ('``', FreqDist({'``': 732})), ("''", FreqDist({"''": 702})), ('CS', FreqDist({'that': 546, 'as': 424, 'if': 103, 'after': 68, 'than': 68, 'while': 47, 'because': 42, 'before': 38, 'like': 28, 'since': 25, ...})), ('DTI', FreqDist({'some': 111, 'any': 94})), ('NNS', FreqDist({'years': 101, 'members': 74, 'people': 54, 'sales': 51, 'men': 46, 'children': 45, 'months': 42, 'days': 37, 'schools': 37, 'laws': 30, ...})), ('.', FreqDist({'.': 4012, ';': 314, '?': 90, '!': 36})), ('RBR', FreqDist({'later': 36, 'earlier': 18, 'better': 8, 'more': 7, 'further': 5, 'longer': 3, 'higher': 2, 'harder': 2, 'closer': 2, 'sooner': 2, ...})), (',', FreqDist({',': 5133})), ('WDT', FreqDist({'which': 245, 'what': 95, 'whatever': 2, 'whichever': 1})), ('HVD', FreqDist({'had': 262})), ('VBZ', FreqDist({'says': 28, 'seems': 11, 'makes': 11, 'comes': 9, 'looks': 9, 'lives': 9, 'believes': 8, 'takes': 7, 'gets': 7, 'expects': 6, ...})), ('CC', FreqDist({'and': 2153, 'but': 276, 'or': 174, 'nor': 15, '&': 14, 'plus': 11, 'neither': 11, 'either': 9, 'yet': 1})), ('IN-TL', FreqDist({'of': 131, 'for': 11, 'on': 7, 'to': 5, 'in': 4, 'against': 2, 'between': 1, 'at': 1, 'by': 1, 'inside': 1})), ('BEDZ', FreqDist({'was': 716})), ('VBN', FreqDist({'made': 62, 'given': 37, 'expected': 35, 'taken': 30, 'held': 27, 'done': 24, 'set': 23, 'said': 22, 'used': 20, 'called': 19, ...})), ('NP', FreqDist({'mrs.': 252, 'mr.': 170, 'john': 63, 'kennedy': 63, 'jr.': 46, 'miss': 46, 'mantle': 46, 'u.s.': 44, 'palmer': 42, 'j.': 41, ...})), ('BEN', FreqDist({'been': 212})), ('TO', FreqDist({'to': 1237})), ('VB', FreqDist({'get': 68, 'take': 50, 'make': 44, 'go': 40, 'see': 40, 'give': 34, 'play': 31, 'pay': 27, 'think': 27, 'know': 26, ...})), ('RB', FreqDist({'also': 129, 'now': 87, 'then': 72, 'here': 67, 'about': 60, 'back': 56, 'only': 51, 'even': 46, 'p.m.': 41, 'just': 40, ...})), ('DT', FreqDist({'this': 319, 'that': 150, 'each': 74, 'another': 46})), ('PPS', FreqDist({'he': 642, 'it': 337, 'she': 77})), ('DOD', FreqDist({'did': 64})), ('AP', FreqDist({'last': 169, 'other': 163, 'more': 132, 'many': 70, 'only': 56, 'several': 39, 'next': 38, 'same': 37, 'much': 36, 'most': 35, ...})), ('BER', FreqDist({'are': 328})), ('HV', FreqDist({'have': 265})), ('DTS', FreqDist({'these': 70, 'those': 66})), ('VBG', FreqDist({'making': 22, 'going': 22, 'playing': 20, 'coming': 19, 'getting': 18, 'taking': 16, 'working': 16, 'using': 14, 'following': 13, 'run ...

# %%
#We now need to sum the items in the value area. 
sum(cdf["AT"].values())
# Out:
# 8893

# %%
values = list(( key, sum(cdf[key].values())) for key in cdf.keys())

# %%
sorted(values, key = itemgetter(1), reverse = True)
# Out:
# [('NN', 13162),
#  ('IN', 10616),
#  ('AT', 8893),
#  ('NP', 6866),
#  (',', 5133),
#  ('NNS', 5066),
#  ('.', 4452),
#  ('JJ', 4392),
#  ('CC', 2664),
#  ('VBD', 2524),
#  ('NN-TL', 2486),
#  ('VB', 2440),
#  ('VBN', 2269),
#  ('RB', 2166),
#  ('CD', 2020),
#  ('CS', 1509),
#  ('VBG', 1398),
#  ('TO', 1237),
#  ('PPS', 1056),
#  ('PP$', 1051),
#  ('MD', 1031),
#  ('AP', 923),
#  ('NP-TL', 741),
#  ('``', 732),
#  ('BEZ', 730),
#  ('BEDZ', 716),
#  ("''", 702),
#  ('JJ-TL', 689),
#  ('PPSS', 602),
#  ('DT', 589),
#  ('BE', 525),
#  ('VBZ', 519),
#  ('NR', 495),
#  ('RP', 482),
#  ('QL', 468),
#  ('PPO', 412),
#  ('WPS', 395),
#  ('NNS-TL', 344),
#  ('WDT', 343),
#  ('BER', 328),
#  ('WRB', 328),
#  ('OD', 309),
#  ('HVZ', 301),
#  ('--', 300),
#  ('NP$', 279),
#  ('HV', 265),
#  ('HVD', 262),
#  ('*', 256),
#  ('BED', 252),
#  ('NPS', 215),
#  ('BEN', 212),
#  ('NN$', 210),
#  ('DTI', 205),
#  ('NP-HL', 186),
#  ('ABN', 183),
#  ('NN-HL', 171),
#  ('IN-TL', 164),
#  ('EX', 161),
#  (')', 151),
#  ('(', 148),
#  ('JJR', 145),
#  (':', 137),
#  ('DTS', 136),
#  ('JJT', 100),
#  ('CD-TL', 96),
#  ('NNS-HL', 92),
#  ('PN', 89),
#  ('RBR', 88),
#  ('VBN-TL', 87),
#  ('ABX', 73),
#  ('NN$-TL', 69),
#  ('IN-HL', 65),
#  ('DOD', 64),
#  ('DO', 63),
#  ('BEG', 57),
#  (',-HL', 55),
#  ('VBN-HL', 53),
#  ('AT-TL', 50),
#  ('NNS$', 50),
#  ('CD-HL', 50),
#  ('JJS', 49),
#  ('CC-TL', 46),
#  ("'", 46),
#  ('JJ-HL', 46),
#  ('MD*', 43),
#  ('VBZ-HL', 39),
#  ('PPL', 36),
#  ('PPSS+MD', 31),
#  ('PPS+BEZ', 31),
#  ('OD-TL', 30),
#  ('DOZ', 26),
#  ('VB-HL', 25),
#  ('NR$', 24),
#  ('FW-NN', 22),
#  ('WP$', 22),
#  ('PPLS', 21),
#  ('ABL', 21),
#  ('PPSS+BER', 20),
#  ('(-HL', 20),
#  (')-HL', 20),
#  ('NNS$-TL', 20),
#  ('.-HL', 20),
#  ('PPSS+HV', 19),
#  ('PPSS+BEM', 18),
#  ('HVN', 18),
#  ('NPS$', 17),
#  ('DO*', 17),
#  ('FW-NN-TL', 16),
#  ('VBG-TL', 15),
#  ('DOD*', 15),
#  ('RB-HL', 15),
#  ('NPS-TL', 15),
#  ('AT-HL', 14),
#  ('FW-IN', 14),
#  ('NR-TL', 14),
#  ('HVG', 14),
#  ('BEM', 13),
#  ('DOZ*', 13),
#  ('VBG-HL', 12),
#  ('NN-TL-HL', 12),
#  ('QLP', 12),
#  ('DT+BEZ', 12),
#  (':-HL', 12),
#  ('UH', 12),
#  ('FW-JJ-TL', 12),
#  ('NP$-TL', 11),
#  ('WPO', 9),
#  ('DTX', 8),
#  ('PPS+MD', 8),
#  ('BEZ*', 8),
#  ('VB-TL', 8),
#  ('RB-TL', 8),
#  ('AP-HL', 7),
#  ('CC-HL', 7),
#  ('VBD-HL', 6),
#  ('TO-HL', 6),
#  ('FW-AT-TL', 6),
#  ('RBT', 5),
#  ('MD-HL', 5),
#  ('PPS+HVZ', 4),
#  ('RP-HL', 4),
#  ('JJR-HL', 4),
#  ('JJR-TL', 4),
#  ('BER*', 4),
#  ('BEDZ*', 3),
#  ('NPS-HL', 3),
#  ('BEZ-HL', 3),
#  ('PP$$', 3),
#  ('FW-JJ', 3),
#  ('NN-NC', 3),
#  ('FW-AT', 3),
#  ('JJS-TL', 2),
#  ('FW-IN+NN', 2),
#  ('JJT-HL', 2),
#  ('EX+BEZ', 2),
#  ('FW-NNS', 2),
#  ('NN$-HL', 2),
#  ('HVD*', 2),
#  ('NR-HL', 2),
#  ('WPS+BEZ', 2),
#  ('DTI-HL', 2),
#  ('CD$', 2),
#  ('NNS$-HL', 2),
#  ('BER-HL', 1),
#  ('MD*-HL', 1),
#  ('CS-HL', 1),
#  ('DT$', 1),
#  ('FW-DT', 1),
#  ('AP-TL', 1),
#  ('UH-TL', 1),
#  ('VBN-TL-HL', 1),
#  ('NNS-TL-HL', 1),
#  ('DT-HL', 1),
#  ('BE-HL', 1),
#  ('PPSS+HVD', 1),
#  ('NP-TL-HL', 1),
#  ('MD+HV', 1),
#  ('OD-HL', 1),
#  ('VBD-TL', 1),
#  ('FW-CC', 1),
#  ('BEDZ-HL', 1),
#  ('AP$', 1),
#  ('NP+BEZ', 1),
#  ('MD-TL', 1),
#  ('PN+HVZ', 1),
#  ('ABN-HL', 1),
#  ('PPS+BEZ-HL', 1),
#  ('HVD-HL', 1),
#  ('RB$', 1),
#  ('FW-AT-HL', 1),
#  ('DO-HL', 1),
#  ('PP$-TL', 1),
#  ('FW-IN-TL', 1),
#  ('*-HL', 1),
#  ('PN-HL', 1),
#  ('PN$', 1),
#  ('BER-TL', 1),
#  ('TO-TL', 1),
#  ('BED*', 1),
#  ('RB+BEZ', 1),
#  ('VB+PPO', 1),
#  ('PPSS-HL', 1),
#  ('HVZ*', 1),
#  ('FW-IN+NN-TL', 1),
#  ('FW-IN+AT-TL', 1),
#  ('JJ-NC', 1),
#  ('NR$-TL', 1),
#  ('FW-PP$-NC', 1),
#  ('FW-VB', 1),
#  ('FW-VB-NC', 1),
#  ('JJR-NC', 1),
#  ('NPS$-TL', 1),
#  ('QL-TL', 1),
#  ('FW-*', 1),
#  ('FW-CD', 1),
#  ('WQL', 1),
#  ('FW-WDT', 1),
#  ('WDT+BEZ', 1)]

# %% [markdown]
# The most common [tags](https://en.wikipedia.org/wiki/Brown_Corpus#Part-of-speech_tags_used) are nouns(NN), prepositions(IN), articles(AT), proper noun or part of name phrase(NP), commas(,), etc.

# %%
#D. Which tags are nouns most commonly found after? What do these tags represent?

from collections import defaultdict
from nltk.corpus import brown
counts = defaultdict(int)
for tagged_sent in brown.tagged_sents():
    for (w1,t1), (w2,t2) in nltk.bigrams(tagged_sent): 
        if t2 == 'NN': 
            counts[t1] += 1

# %%
counts #Sweet, its already sorted
# Out:
# defaultdict(int,
#             {'AT': 48372,
#              'JJ': 28407,
#              'NN': 11646,
#              'VBD': 531,
#              'IN': 17225,
#              'NP': 1361,
#              'DT': 4367,
#              'NP$': 1282,
#              'CC': 4326,
#              'JJT': 422,
#              'JJR': 679,
#              'NN$-TL': 136,
#              'DTI': 1164,
#              '``': 770,
#              'NN$': 887,
#              'NNS': 362,
#              'VBZ': 325,
#              'VBG': 2798,
#              "''": 231,
#              'PP$': 8636,
#              'CS': 992,
#              'NN-TL': 521,
#              'BEN': 25,
#              'CD': 1633,
#              'JJS': 202,
#              ',': 2394,
#              'NR': 214,
#              'VBN': 2300,
#              'AP': 2671,
#              'OD': 1139,
#              'BEDZ': 156,
#              'VB': 1463,
#              'NR$': 24,
#              '--': 118,
#              'WDT': 265,
#              'RP': 68,
#              'RB': 326,
#              'JJ-TL': 292,
#              '*': 48,
#              'NNS$': 116,
#              'FW-DT': 1,
#              'NNS-TL': 65,
#              'FW-NN': 14,
#              'BE': 65,
#              'DO': 12,
#              'BEZ': 184,
#              'NP-TL': 124,
#              'ABN': 219,
#              'NNS$-TL': 6,
#              'DTX': 41,
#              'VBN-TL': 10,
#              "'": 35,
#              'WP$': 125,
#              'HV': 108,
#              'CD-TL': 20,
#              ')': 102,
#              'NPS$': 16,
#              'ABX': 46,
#              'PPS+BEZ': 6,
#              '(': 152,
#              'HVD': 73,
#              'DOZ': 5,
#              'PPO': 131,
#              'AP$': 3,
#              'HVZ': 33,
#              'NP$-TL': 12,
#              'BER': 36,
#              'WRB': 141,
#              'DOD': 5,
#              'AT-TL': 4,
#              'DTS': 41,
#              'RB$': 4,
#              'TO': 6,
#              'BED': 21,
#              'QL': 16,
#              'CD$': 1,
#              'PN$': 49,
#              ':': 93,
#              'HVN': 9,
#              'OD-TL': 4,
#              'FW-NN-TL': 2,
#              'NR$-TL': 4,
#              'NPS$-TL': 1,
#              ':-HL': 1,
#              'HVG': 20,
#              'NPS': 2,
#              'MD': 22,
#              'RB-NC': 1,
#              'WPO': 10,
#              'IN-NC': 1,
#              'PPLS': 2,
#              'RBR': 4,
#              'PPS': 4,
#              'FW-NN$-TL': 1,
#              'BEG': 7,
#              'NR-TL': 4,
#              'EX+BEZ': 8,
#              'EX': 4,
#              'NN-HL': 2,
#              'PPSS': 16,
#              'FW-VBN': 2,
#              'PN': 4,
#              'UH': 4,
#              'PPL': 1,
#              'FW-JJ': 2,
#              'WPS': 2,
#              'FW-WDT': 1,
#              'QLP': 4,
#              'JJ$-TL': 1,
#              'BEM': 1,
#              'AP-TL': 1,
#              'PPSS+BEM': 1,
#              'DT+BEZ': 2,
#              'PP$$': 1,
#              'WPS+BEZ': 2,
#              'FW-NN$': 2,
#              'BEDZ*': 2,
#              'WRB+IN': 1,
#              'HVD*': 1,
#              'DO*': 1,
#              'BEZ*': 2,
#              'PPSS+BER': 1,
#              'VB+PPO': 1,
#              'PPSS+MD': 1,
#              'VB+AT': 2,
#              'RB-TL': 1,
#              'MD*': 1})

# %% [markdown]
# Nouns are commonly found after articles.

# %% [markdown]
# # 16.
# Explore the following issues that arise in connection with the lookup tagger:
#
# - What happens to the tagger performance for the various model sizes when a backoff tagger is omitted?
# - Consider the curve in 4.2; suggest a good size for a lookup tagger that balances memory and performance. Can you come up with scenarios where it would be preferable to minimize

# %% [markdown]
# A. When omitting backoff tagers, we lose performance as we only rely on one method of tagging. A tri/bi-gram tagger might leave us with too many nones and thus the evaluation would be poor. The small the number of instance, the worse we will do.
#
# b. The more instances we have the better the model gets. The point where an increase in performace starts to drop off is around 2000 instances. Despite this we can get 90% accuracy with a set of neark 17k instances. Depending on the application we might need to keep the data used small. For instance, if are working on a small project where the goal is too show understanding, we might pick a smaller number to save time on computational time. When inserting the model into user applicaitons, we need to keep it small of phones, which often have limited memory.

# %% [markdown]
# # 17.
#
# What is the upper limit of performance for a lookup tagger, assuming no limit to the size of its table? (Hint: write a program to work out what percentage of tokens of a word are assigned the most likely tag for that word, on average.)

# %% [markdown]
# From 4.2 we see that the performance increases at a decreasing rate when the number of instances increases. Due to my knowledge of statistics, I see no issues approaching 100% performance and the number of instances approaches infinity.

# %% [markdown]
# # 18.
#
# Generate some statistics for tagged data to answer the following questions:
#
# - What proportion of word types are always assigned the same part-of-speech tag?
# - How many words are ambiguous, in the sense that they appear with at least two tags?
# - What percentage of word tokens in the Brown Corpus involve these ambiguous words?

# %%
#A
n = len(cdf.items())
oneTag = [key for (key, value) in cdf.items() if len(cdf[key]) == 1 ]
len(oneTag)/n # 46% of the wordtypes are always assigned the same part of speech tag

# %%
#B/C
multTag = [key for (key, value) in cdf.items() if len(cdf[key]) > 1 ]
len(multTag)/n # 53% of the wordtypes are always assigned the same part of speech tag
# Out:
# 0.5321100917431193

# %% [markdown]
# # 19.
#
# The evaluate() method works out how accurately the tagger performs on this text. For example, if the supplied tagged text was [('the', 'DT'), ('dog', 'NN')] and the tagger produced the output [('the', 'NN'), ('dog', 'NN')], then the score would be 0.5. Let's try to figure out how the evaluation method works:
#
# - A tagger t takes a list of words as input, and produces a list of tagged words as output. However, t.evaluate() is given correctly tagged text as its only parameter. What must it do with this input before performing the tagging?
#
# Answer: The input must be guessed from the model "t". We can do this by calling t.tag(somedata to be tagged)
#
# - Once the tagger has created newly tagged text, how might the evaluate() method go about comparing it with the original tagged text and computing the accuracy score?
#
# The evaluate method will look for the tagged text it is given then compare the tagged text to the solution.
#
# - Now examine the source code to see how the method is implemented. Inspect nltk.tag.api.__file__ to discover the location of the source code, and open this file using an editor (be sure to use the api.py file and not the compiled api.pyc binary file).

# %%
help(nltk.tag.api)
# Out:
# Help on module nltk.tag.api in nltk.tag:
#
# NAME
#     nltk.tag.api
#
# DESCRIPTION
#     Interface for tagging each token in a sentence with supplementary
#     information, such as its part of speech.
#
# CLASSES
#     builtins.object
#         TaggerI
#             FeaturesetTaggerI
#
#     class FeaturesetTaggerI(TaggerI)
#      |  A tagger that requires tokens to be ``featuresets``.  A featureset
#      |  is a dictionary that maps from feature names to feature
#      |  values.  See ``nltk.classify`` for more information about features
#      |  and featuresets.
#      |
#      |  Method resolution order:
#      |      FeaturesetTaggerI
#      |      TaggerI
#      |      builtins.object
#      |
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset({'tag'})
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from TaggerI:
#      |
#      |  evaluate(self, gold)
#      |      Score the accuracy of the tagger against the gold standard.
#      |      Strip the tags from the gold standard text, retag it using
#      |      the tagger, then compute the accuracy score.
#      |
#      |      :type gold: list(list(tuple(str, str)))
#      |      :param gold: The list of tagged sentences to score the tagger on.
#      |      :rtype: float
#      |
#      |  tag(self, tokens)
#      |      Determine the most appropriate tag sequence for the given
#      |      token sequence, and return a corresponding list of tagged
#      |      tokens.  A tagged token is encoded as a tuple ``(token, tag)``.
#      |
#      |      :rtype: list(tuple(str, str))
#      |
#      |  tag_sents(self, sentences)
#      |      Apply ``self.tag()`` to each element of *sentences*.  I.e.:
#      |
#      |          return [self.tag(sent) for sent in sentences]
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from TaggerI:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class TaggerI(builtins.object)
#      |  A processing interface for assigning a tag to each token in a list.
#      |  Tags are case sensitive strings that identify some property of each
#      |  token, such as its part of speech or its sense.
#      |
#      |  Some taggers require specific types for their tokens.  This is
#      |  generally indicated by the use of a sub-interface to ``TaggerI``.
#      |  For example, featureset taggers, which are subclassed from
#      |  ``FeaturesetTagger``, require that each token be a ``featureset``.
#      |
#      |  Subclasses must define:
#      |    - either ``tag()`` or ``tag_sents()`` (or both)
#      |
#      |  Methods defined here:
#      |
#      |  evaluate(self, gold)
#      |      Score the accuracy of the tagger against the gold standard.
#      |      Strip the tags from the gold standard text, retag it using
#      |      the tagger, then compute the accuracy score.
#      |
#      |      :type gold: list(list(tuple(str, str)))
#      |      :param gold: The list of tagged sentences to score the tagger on.
#      |      :rtype: float
#      |
#      |  tag(self, tokens)
#      |      Determine the most appropriate tag sequence for the given
#      |      token sequence, and return a corresponding list of tagged
#      |      tokens.  A tagged token is encoded as a tuple ``(token, tag)``.
#      |
#      |      :rtype: list(tuple(str, str))
#      |
#      |  tag_sents(self, sentences)
#      |      Apply ``self.tag()`` to each element of *sentences*.  I.e.:
#      |
#      |          return [self.tag(sent) for sent in sentences]
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset({'tag'})
#
# FILE
#     c:\users\junglebook\anaconda3\lib\site-packages\nltk\tag\api.py

# %%
nltk.tag.api.__file__
# Out:
# 'C:\\Users\\JungleBook\\Anaconda3\\lib\\site-packages\\nltk\\tag\\api.py'

# %% [markdown]
# # 20.
#
# Write code to search the Brown Corpus for particular words and phrases according to tags, to answer the following questions:
#
# - Produce an alphabetically sorted list of the distinct words tagged as MD.
# - Identify words that can be plural nouns or third person singular verbs (e.g. deals, flies).
# - Identify three-word prepositional phrases of the form IN + DET + NN (eg. in the lab).
# - What is the ratio of masculine to feminine pronouns?

# %%
#A 
sorted(cdf["MD"].keys())
# Out:
# ['can',
#  'could',
#  'may',
#  'might',
#  'must',
#  'need',
#  'ought',
#  'shall',
#  'should',
#  'will',
#  'would']

# %%
help(dict)
# Out:
# Help on class dict in module builtins:
#
# class dict(object)
#  |  dict() -> new empty dictionary
#  |  dict(mapping) -> new dictionary initialized from a mapping object's
#  |      (key, value) pairs
#  |  dict(iterable) -> new dictionary initialized as if via:
#  |      d = {}
#  |      for k, v in iterable:
#  |          d[k] = v
#  |  dict(**kwargs) -> new dictionary initialized with the name=value pairs
#  |      in the keyword argument list.  For example:  dict(one=1, two=2)
#  |
#  |  Methods defined here:
#  |
#  |  __contains__(self, key, /)
#  |      True if the dictionary has the specified key, else False.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __setitem__(self, key, value, /)
#  |      Set self[key] to value.
#  |
#  |  __sizeof__(...)
#  |      D.__sizeof__() -> size of D in memory, in bytes
#  |
#  |  clear(...)
#  |      D.clear() -> None.  Remove all items from D.
#  |
#  |  copy(...)
#  |      D.copy() -> a shallow copy of D
#  |
#  |  get(self, key, default=None, /)
#  |      Return the value for key if key is in the dictionary, else default.
#  |
#  |  items(...)
#  |      D.items() -> a set-like object providing a view on D's items
#  |
#  |  keys(...)
#  |      D.keys() -> a set-like object providing a view on D's keys
#  |
#  |  pop(...)
#  |      D.pop(k[,d]) -> v, remove specified key and return the corresponding value.
#  |      If key is not found, d is returned if given, otherwise KeyError is raised
#  |
#  |  popitem(...)
#  |      D.popitem() -> (k, v), remove and return some (key, value) pair as a
#  |      2-tuple; but raise KeyError if D is empty.
#  |
#  |  setdefault(self, key, default=None, /)
#  |      Insert key with a value of default if key is not in the dictionary.
#  |
#  |      Return the value for key if key is in the dictionary, else default.
#  |
#  |  update(...)
#  |      D.update([E, ]**F) -> None.  Update D from dict/iterable E and F.
#  |      If E is present and has a .keys() method, then does:  for k in E: D[k] = E[k]
#  |      If E is present and lacks a .keys() method, then does:  for k, v in E: D[k] = v
#  |      In either case, this is followed by: for k in F:  D[k] = F[k]
#  |
#  |  values(...)
#  |      D.values() -> an object providing a view on D's values
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  fromkeys(iterable, value=None, /) from builtins.type
#  |      Create a new dictionary with keys from iterable and values set to value.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None

# %%
#B. The tag for third person singular verbs are VBZ 
cdf["NNS"] - cdf["VBZ"] #This would be only nns not in VBZ
# Out:
# FreqDist({'years': 101, 'members': 74, 'people': 54, 'sales': 51, 'men': 46, 'children': 45, 'months': 42, 'days': 37, 'schools': 37, 'laws': 30, ...})

# %%
#Instead we want the intersection 
intersection = cdf["NNS"].keys() & cdf["VBZ"].keys()
intersection
# Out:
# {'amounts',
#  'bats',
#  'calls',
#  'causes',
#  'charges',
#  'contracts',
#  'controls',
#  'costs',
#  'credits',
#  'cuts',
#  'declines',
#  'faces',
#  'features',
#  'figures',
#  'flies',
#  'forces',
#  'graduates',
#  'heads',
#  'hits',
#  'hopes',
#  'houses',
#  'kids',
#  'lines',
#  'lists',
#  'lives',
#  'marks',
#  'means',
#  'merits',
#  'moderates',
#  'moves',
#  'needs',
#  'passes',
#  'permits',
#  'petitions',
#  'plans',
#  'plays',
#  'powers',
#  'practices',
#  'ranks',
#  'remains',
#  'remarks',
#  'reports',
#  'requests',
#  'shows',
#  'stands',
#  'starts',
#  'supplies',
#  'talks',
#  'totals',
#  'touches',
#  'tries',
#  'views',
#  'votes',
#  'wants',
#  'works'}

# %%
#C. Identify three-word prepositional phrases of the form IN + DET + NN

#Taken from the notes 
from nltk.corpus import brown
def process(sentence):
    for (w1,t1), (w2,t2), (w3,t3) in nltk.trigrams(sentence): 
        if (t1 == "IN" and t2 == "DET" and t3 =="NN" ): #Changed to match the desired pattern 
            print(w1, w2, w3) 

for tagged_sent in brown.tagged_words():
    process(tagged_sent)
#It didn't produce anything. ODD

# %%
#D. What is the ratio of masculine to feminine pronouns?
cdf["PPO"]
# Out:
# FreqDist({'it': 141, 'them': 96, 'him': 93, 'me': 31, 'her': 22, 'you': 16, 'us': 12, "'em": 1})

# %%
cdf["PPS"]
# Out:
# FreqDist({'he': 642, 'it': 337, 'she': 77})

# %%
cdf["PPSS"]
# Out:
# FreqDist({'they': 267, 'i': 178, 'we': 106, 'you': 50, 'ye': 1})

# %%
(cdf["PPS"] | cdf["PPO"])
# Out:
# FreqDist({'he': 642, 'it': 337, 'them': 96, 'him': 93, 'she': 77, 'me': 31, 'her': 22, 'you': 16, 'us': 12, "'em": 1})

# %%
#PPO and PPS show that the feminine/ masc pronouns are: him,her, he,she
#With this we can look up the instances
masc = [ "him", "he"]
fem = ["her","she"]
pronCDF = (cdf["PPS"] | cdf["PPO"]) 

mascCount = sum( value for (key, value) in pronCDF.items() if key in masc) 
femCount = sum( value for (key, value) in pronCDF.items() if key in fem) 
mascCount/femCount
# Out:
# 7.424242424242424

# %% [markdown]
# # 21.
# In 3.1 we saw a table involving frequency counts for the verbs adore, love, like, prefer and preceding qualifiers absolutely and definitely. Investigate the full range of adverbs that appear before these four verbs.

# %%
verbs = ["adore", "love", "like", "prefer"]
#Finna use brown corpus for this exploration. 
pos = defaultdict(lambda: defaultdict(int))

#Taken from the notes 
from nltk.corpus import brown
def process(sentence):
    for (w1,t1), (w2,t2) in nltk.bigrams(sentence):
        for verb in verbs:
            if (t1 == "RB" and w2 == verb ): #Changed to match the desired pattern 
                 pos[w2][w1] += 1 
                    
for tagged_sent in brown.tagged_sents():
    process(tagged_sent)

# %%
pos
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'like': defaultdict(int,
#                          {'just': 17,
#                           'always': 3,
#                           'together': 4,
#                           'somewhat': 3,
#                           'increasingly': 1,
#                           'around': 2,
#                           'much': 9,
#                           'jist': 1,
#                           'exactly': 3,
#                           'roughly': 1,
#                           'so': 1,
#                           'gloriously': 1,
#                           'deceptively': 1,
#                           'remarkably': 1,
#                           'simply': 1,
#                           'close': 1,
#                           'quick': 1,
#                           'alone': 1,
#                           'here': 1,
#                           'particularly': 1,
#                           'Kinda': 1,
#                           'almost': 3,
#                           'by': 1,
#                           'sure': 1,
#                           'Just': 2,
#                           'often': 1,
#                           'wildly': 1,
#                           'yet': 1,
#                           'Jist': 1,
#                           'there': 1,
#                           'abreast': 1,
#                           'even': 2,
#                           'rather': 1}),
#              'love': defaultdict(int, {'just': 1, 'dearly': 1, 'always': 1}),
#              'prefer': defaultdict(int,
#                          {'generally': 1, 'much': 1, 'spontaneously': 1})})

# %% [markdown]
# # 22.
#
# We defined the regexp_tagger that can be used as a fall-back tagger for unknown words. This tagger only checks for cardinal numbers. By testing for particular prefix or suffix strings, it should be possible to guess other tags. For example, we could tag any word that ends with -s as a plural noun. Define a regular expression tagger (using RegexpTagger()) that tests for at least five other patterns in the spelling of words. (Use inline documentation to explain the rules.)

# %%
patterns = [
    (r'.*ing$', 'VBG'),                # gerunds
    (r'.*ed$', 'VBD'),                 # simple past
    (r'.*es$', 'VBZ'),                 # 3rd singular present
    (r'.*ould$', 'MD'),                # modals
    (r'.*\'s$', 'NN$'),                # possessive nouns
    (r'.*s$', 'NNS'),                  # plural nouns
    (r'^-?[0-9]+(\.[0-9]+)?$', 'CD'),  # cardinal numbers
    (r'.*', 'NN'),                    # nouns (default)
    (r'.*:', 'colon')   ,  #Colon
    (r'.*,', 'comma') ,    #Comma
    (r'\b(be)+\b', "BE")  ,   #be
    (r'\b(do)+\b', "DO") ,    #do
    (r'\b(is)+\b', "BBB")  ,   #is
]

# %%
#Note that these are processed in order, and the first one that matches is applied. 
#Now we can set up a tagger and use it to tag a sentence. Now its right about a fifth of the time.
regexp_tagger = nltk.RegexpTagger(patterns)
#regexp_tagger.tag(brown_sents[3])
regexp_tagger.evaluate(brown_tagged_sents)
# Out:
# 0.19008681607106803

# %% [markdown]
# # 23
#
# Consider the regular expression tagger developed in the exercises in the previous section. Evaluate the tagger using its accuracy() method, and try to come up with ways to improve its performance. Discuss your findings. How does objective evaluation help in the development process?

# %%
help(nltk.RegexpTagger)
# Out:
# Help on class RegexpTagger in module nltk.tag.sequential:
#
# class RegexpTagger(SequentialBackoffTagger)
#  |  RegexpTagger(regexps, backoff=None)
#  |
#  |  Regular Expression Tagger
#  |
#  |  The RegexpTagger assigns tags to tokens by comparing their
#  |  word strings to a series of regular expressions.  The following tagger
#  |  uses word suffixes to make guesses about the correct Brown Corpus part
#  |  of speech tag:
#  |
#  |      >>> from nltk.corpus import brown
#  |      >>> from nltk.tag import RegexpTagger
#  |      >>> test_sent = brown.sents(categories='news')[0]
#  |      >>> regexp_tagger = RegexpTagger(
#  |      ...     [(r'^-?[0-9]+(.[0-9]+)?$', 'CD'),   # cardinal numbers
#  |      ...      (r'(The|the|A|a|An|an)$', 'AT'),   # articles
#  |      ...      (r'.*able$', 'JJ'),                # adjectives
#  |      ...      (r'.*ness$', 'NN'),                # nouns formed from adjectives
#  |      ...      (r'.*ly$', 'RB'),                  # adverbs
#  |      ...      (r'.*s$', 'NNS'),                  # plural nouns
#  |      ...      (r'.*ing$', 'VBG'),                # gerunds
#  |      ...      (r'.*ed$', 'VBD'),                 # past tense verbs
#  |      ...      (r'.*', 'NN')                      # nouns (default)
#  |      ... ])
#  |      >>> regexp_tagger
#  |      <Regexp Tagger: size=9>
#  |      >>> regexp_tagger.tag(test_sent)
#  |      [('The', 'AT'), ('Fulton', 'NN'), ('County', 'NN'), ('Grand', 'NN'), ('Jury', 'NN'),
#  |      ('said', 'NN'), ('Friday', 'NN'), ('an', 'AT'), ('investigation', 'NN'), ('of', 'NN'),
#  |      ("Atlanta's", 'NNS'), ('recent', 'NN'), ('primary', 'NN'), ('election', 'NN'),
#  |      ('produced', 'VBD'), ('``', 'NN'), ('no', 'NN'), ('evidence', 'NN'), ("''", 'NN'),
#  |      ('that', 'NN'), ('any', 'NN'), ('irregularities', 'NNS'), ('took', 'NN'),
#  |      ('place', 'NN'), ('.', 'NN')]
#  |
#  |  :type regexps: list(tuple(str, str))
#  |  :param regexps: A list of ``(regexp, tag)`` pairs, each of
#  |      which indicates that a word matching ``regexp`` should
#  |      be tagged with ``tag``.  The pairs will be evalutated in
#  |      order.  If none of the regexps match a word, then the
#  |      optional backoff tagger is invoked, else it is
#  |      assigned the tag None.
#  |
#  |  Method resolution order:
#  |      RegexpTagger
#  |      SequentialBackoffTagger
#  |      nltk.tag.api.TaggerI
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, regexps, backoff=None)
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  __unicode__ = __str__(self, /)
#  |
#  |  choose_tag(self, tokens, index, history)
#  |      Decide which tag should be used for the specified token, and
#  |      return that tag.  If this tagger is unable to determine a tag
#  |      for the specified token, return None -- do not consult
#  |      the backoff tagger.  This method should be overridden by
#  |      subclasses of SequentialBackoffTagger.
#  |
#  |      :rtype: str
#  |      :type tokens: list
#  |      :param tokens: The list of words that are being tagged.
#  |      :type index: int
#  |      :param index: The index of the word whose tag should be
#  |          returned.
#  |      :type history: list(str)
#  |      :param history: A list of the tags for all words before *index*.
#  |
#  |  encode_json_obj(self)
#  |
#  |  unicode_repr = __repr__(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  decode_json_obj(obj) from abc.ABCMeta
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __abstractmethods__ = frozenset()
#  |
#  |  json_tag = 'nltk.tag.sequential.RegexpTagger'
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from SequentialBackoffTagger:
#  |
#  |  tag(self, tokens)
#  |      Determine the most appropriate tag sequence for the given
#  |      token sequence, and return a corresponding list of tagged
#  |      tokens.  A tagged token is encoded as a tuple ``(token, tag)``.
#  |
#  |      :rtype: list(tuple(str, str))
#  |
#  |  tag_one(self, tokens, index, history)
#  |      Determine an appropriate tag for the specified token, and
#  |      return that tag.  If this tagger is unable to determine a tag
#  |      for the specified token, then its backoff tagger is consulted.
#  |
#  |      :rtype: str
#  |      :type tokens: list
#  |      :param tokens: The list of words that are being tagged.
#  |      :type index: int
#  |      :param index: The index of the word whose tag should be
#  |          returned.
#  |      :type history: list(str)
#  |      :param history: A list of the tags for all words before *index*.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from SequentialBackoffTagger:
#  |
#  |  backoff
#  |      The backoff tagger for this tagger.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from nltk.tag.api.TaggerI:
#  |
#  |  evaluate(self, gold)
#  |      Score the accuracy of the tagger against the gold standard.
#  |      Strip the tags from the gold standard text, retag it using
#  |      the tagger, then compute the accuracy score.
#  |
#  |      :type gold: list(list(tuple(str, str)))
#  |      :param gold: The list of tagged sentences to score the tagger on.
#  |      :rtype: float
#  |
#  |  tag_sents(self, sentences)
#  |      Apply ``self.tag()`` to each element of *sentences*.  I.e.:
#  |
#  |          return [self.tag(sent) for sent in sentences]
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from nltk.tag.api.TaggerI:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %% [markdown]
# There is no .accuracy() method. It could have been excluded as the package updated.

# %% [markdown]
# # 24.
#
# How serious is the sparse data problem? Investigate the performance of n-gram taggers as n increases from 1 to 6. Tabulate the accuracy score. Estimate the training data required for these taggers, assuming a vocabulary size of $10^5$ and a tagset size of $10^2$.
#
# |n| Max number of possible n-grams|Max number of possible tag combinations |
# |-|-----------------|------------|
# |1|      $10^5$     | $10^2$     |
# |2|      $10^{10}$     | $10^4$     |
# |3|      $10^{15}$     | $10^6$     |
# |4|      $10^{20}$     | $10^8$     |
# |5|      $10^{25}$     | $10^{10}$     |
# |6|      $10^{30}$     | $10^{12}$     |

# %% [markdown]
# This one stumped me so I decided to take a look at the [solutions](https://github.com/Sturzgefahr/Natural-Language-Processing-with-Python-Analyzing-Text-with-the-Natural-Language-Toolkit/blob/master/Chapter%2005/NLTK%20Chapter%205%20-%20Exercises.ipynb)
#
# The solutions modeled the brown corpus and did some math at the different n-grams and training set sizes. I attempted to run the code by it was too much for my machine.

# %% [markdown]
# # 25.
#
#  Obtain some tagged data for another language, and train and evaluate a variety of taggers on it. If the language is morphologically complex, or if there are any orthographic clues (e.g. capitalization) to word classes, consider developing a regular expression tagger for it (ordered after the unigram tagger, and before the default tagger). How does the accuracy of your tagger(s) compare with the same taggers run on English data? Discuss any issues you encounter in applying these methods to the language.

# %%
#taken from 
# https://stackoverflow.com/questions/14732465/nltk-tagging-spanish-words-using-a-corpus
from nltk.corpus import cess_esp as cess # The spanish tagged corpus 
from nltk import UnigramTagger as ut
from nltk import BigramTagger as bt

# Read the corpus into a list, 
# each entry in the list is one sentence.
cess_sents = cess.tagged_sents() 

# Train the unigram tagger
uni_tag = ut(cess_sents )

sentence = "Hola , esta foo bar ."

# Tagger reads a list of tokens.
uni_tag.tag(sentence.split(" "))
# Out:
# [('Hola', None),
#  (',', 'Fc'),
#  ('esta', 'dd0fs0'),
#  ('foo', None),
#  ('bar', 'ncms000'),
#  ('.', 'Fp')]

# %% [markdown]
# Spanish has morphological similar to english. Capilitizion is the same as with english, titles, names, and begining of sentences are capitalized. Despite this it is more complex when it comes to using acents. Depending on the pronoun, a word might have a suffix -O fro masculine, or -A for feminine, and the verbs come after the noun.

# %%
from nltk.corpus import brown 
uni_tag = ut( brown.tagged_sents() )

sentence = "Hello, to be foo bar ."

# Tagger reads a list of tokens.
uni_tag.tag(sentence.split(" "))
# Out:
# [('Hello,', None),
#  ('to', 'TO'),
#  ('be', 'BE'),
#  ('foo', None),
#  ('bar', 'NN'),
#  ('.', '.')]

# %% [markdown]
# With the data used english performed better. This is likely due to the quantity and quality of data fed to the model.

# %% [markdown]
# # 26
#
# 4.1 plotted a curve showing change in the performance of a lookup tagger as the model size was increased. Plot the performance curve for a unigram tagger, as the amount of training data is varied.

# %%
help(nltk.UnigramTagger)
# Out:
# Help on class UnigramTagger in module nltk.tag.sequential:
#
# class UnigramTagger(NgramTagger)
#  |  UnigramTagger(train=None, model=None, backoff=None, cutoff=0, verbose=False)
#  |
#  |  Unigram Tagger
#  |
#  |  The UnigramTagger finds the most likely tag for each word in a training
#  |  corpus, and then uses that information to assign tags to new tokens.
#  |
#  |      >>> from nltk.corpus import brown
#  |      >>> from nltk.tag import UnigramTagger
#  |      >>> test_sent = brown.sents(categories='news')[0]
#  |      >>> unigram_tagger = UnigramTagger(brown.tagged_sents(categories='news')[:500])
#  |      >>> for tok, tag in unigram_tagger.tag(test_sent):
#  |      ...     print("(%s, %s), " % (tok, tag))
#  |      (The, AT), (Fulton, NP-TL), (County, NN-TL), (Grand, JJ-TL),
#  |      (Jury, NN-TL), (said, VBD), (Friday, NR), (an, AT),
#  |      (investigation, NN), (of, IN), (Atlanta's, NP$), (recent, JJ),
#  |      (primary, NN), (election, NN), (produced, VBD), (``, ``),
#  |      (no, AT), (evidence, NN), ('', ''), (that, CS), (any, DTI),
#  |      (irregularities, NNS), (took, VBD), (place, NN), (., .),
#  |
#  |  :param train: The corpus of training data, a list of tagged sentences
#  |  :type train: list(list(tuple(str, str)))
#  |  :param model: The tagger model
#  |  :type model: dict
#  |  :param backoff: Another tagger which this tagger will consult when it is
#  |      unable to tag a word
#  |  :type backoff: TaggerI
#  |  :param cutoff: The number of instances of training data the tagger must see
#  |      in order not to use the backoff tagger
#  |  :type cutoff: int
#  |
#  |  Method resolution order:
#  |      UnigramTagger
#  |      NgramTagger
#  |      ContextTagger
#  |      SequentialBackoffTagger
#  |      nltk.tag.api.TaggerI
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, train=None, model=None, backoff=None, cutoff=0, verbose=False)
#  |      :param context_to_tag: A dictionary mapping contexts to tags.
#  |      :param backoff: The backoff tagger that should be used for this tagger.
#  |
#  |  context(self, tokens, index, history)
#  |      :return: the context that should be used to look up the tag
#  |          for the specified token; or None if the specified token
#  |          should not be handled by this tagger.
#  |      :rtype: (hashable)
#  |
#  |  encode_json_obj(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  decode_json_obj(obj) from abc.ABCMeta
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __abstractmethods__ = frozenset()
#  |
#  |  json_tag = 'nltk.tag.sequential.UnigramTagger'
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from ContextTagger:
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  __unicode__ = __str__(self, /)
#  |
#  |  choose_tag(self, tokens, index, history)
#  |      Decide which tag should be used for the specified token, and
#  |      return that tag.  If this tagger is unable to determine a tag
#  |      for the specified token, return None -- do not consult
#  |      the backoff tagger.  This method should be overridden by
#  |      subclasses of SequentialBackoffTagger.
#  |
#  |      :rtype: str
#  |      :type tokens: list
#  |      :param tokens: The list of words that are being tagged.
#  |      :type index: int
#  |      :param index: The index of the word whose tag should be
#  |          returned.
#  |      :type history: list(str)
#  |      :param history: A list of the tags for all words before *index*.
#  |
#  |  size(self)
#  |      :return: The number of entries in the table used by this
#  |          tagger to map from contexts to tags.
#  |
#  |  unicode_repr = __repr__(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from SequentialBackoffTagger:
#  |
#  |  tag(self, tokens)
#  |      Determine the most appropriate tag sequence for the given
#  |      token sequence, and return a corresponding list of tagged
#  |      tokens.  A tagged token is encoded as a tuple ``(token, tag)``.
#  |
#  |      :rtype: list(tuple(str, str))
#  |
#  |  tag_one(self, tokens, index, history)
#  |      Determine an appropriate tag for the specified token, and
#  |      return that tag.  If this tagger is unable to determine a tag
#  |      for the specified token, then its backoff tagger is consulted.
#  |
#  |      :rtype: str
#  |      :type tokens: list
#  |      :param tokens: The list of words that are being tagged.
#  |      :type index: int
#  |      :param index: The index of the word whose tag should be
#  |          returned.
#  |      :type history: list(str)
#  |      :param history: A list of the tags for all words before *index*.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from SequentialBackoffTagger:
#  |
#  |  backoff
#  |      The backoff tagger for this tagger.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from nltk.tag.api.TaggerI:
#  |
#  |  evaluate(self, gold)
#  |      Score the accuracy of the tagger against the gold standard.
#  |      Strip the tags from the gold standard text, retag it using
#  |      the tagger, then compute the accuracy score.
#  |
#  |      :type gold: list(list(tuple(str, str)))
#  |      :param gold: The list of tagged sentences to score the tagger on.
#  |      :rtype: float
#  |
#  |  tag_sents(self, sentences)
#  |      Apply ``self.tag()`` to each element of *sentences*.  I.e.:
#  |
#  |          return [self.tag(sent) for sent in sentences]
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from nltk.tag.api.TaggerI:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
def performance(wordlist):
    baseline_tagger = nltk.UnigramTagger(wordlist, backoff=nltk.DefaultTagger('NN'))
    return baseline_tagger.evaluate(brown.tagged_sents(categories='news'))

def display():
    import pylab
    sizes = 2 ** pylab.arange(15) #This is various sizes 
    perfs = [performance(brown.tagged_sents()[:size]) for size in sizes]
    
    pylab.plot(sizes, perfs, '-bo')
    pylab.title('Unigram Tagger Performance with various model sizes')
    pylab.xlabel('Model Size, in sentences')
    pylab.ylabel('Performance')
    pylab.show()

# %%
display()

# %% [markdown]
# By using the unigram tagger on all data rather than the nth most common words(aka a look up tagger), we achieve an better performace quicker. At around 2500 entries we have performance of almost 90%. While a lookup tagger had a performance below 80%.

# %% [markdown]
# # 27.
#
# Inspect the confusion matrix for the bigram tagger t2 defined in 5, and identify one or more sets of tags to collapse. Define a dictionary to do the mapping, and evaluate the tagger on the simplified data.

# %%
brown_tagged_sents = brown.tagged_sents(categories='news')
size = int(len(brown_tagged_sents) * 0.9)
train_sents = brown_tagged_sents[:size]
test_sents = brown_tagged_sents[size:]

t0 = nltk.DefaultTagger('NN')
t1 = nltk.UnigramTagger(train_sents, backoff=t0)
t2 = nltk.BigramTagger(train_sents, backoff=t1)
t2.evaluate(test_sents)
# Out:
# 0.8452108043456593

# %% [markdown]
# I was a little lost on the inital confusion matrix table because it didn't produce something legible. Reading the solutions I found that table was much to large to be helpful. Using the solutions I mitigated the table.

# %%
test_tags = [tag for sent in brown.sents()[size:size + 5]
             for (word, tag) in t2.tag(sent)]
gold_tags = [tag for sent in brown.tagged_sents()[size:size + 5] for (word, tag) in sent]
print(nltk.ConfusionMatrix(gold_tags, test_tags))
# Out:
#       |                                                  J        N           N                                  |
#       |                          B                       J        N           P        P                         |
#       |                 A        E           H  H        -        -  N     N  -     P  P              V  V  W    |
#       |  '        -     B  A  A  D  C  C  C  V  V  I  J  T  M  N  T  N  N  P  T  O  P  S  Q  R  T  V  B  B  R  ` |
#       |  '  *  ,  -  .  N  P  T  Z  C  D  S  D  Z  N  J  L  D  N  L  S  P  $  L  D  $  S  L  B  O  B  D  N  B  ` |
# ------+----------------------------------------------------------------------------------------------------------+
#    '' | <1> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#     * |  . <1> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#     , |  .  .<10> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#    -- |  .  .  . <1> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#     . |  .  .  .  . <5> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#   ABN |  .  .  .  .  . <2> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#    AP |  .  .  .  .  .  . <2> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#    AT |  .  .  .  .  .  .  . <6> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#  BEDZ |  .  .  .  .  .  .  .  . <1> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#    CC |  .  .  .  .  .  .  .  .  . <6> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#    CD |  .  .  .  .  .  .  .  .  .  . <3> .  .  .  .  .  .  .  1  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#    CS |  .  .  .  .  .  .  .  .  .  .  . <.> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#   HVD |  .  .  .  .  .  .  .  .  .  .  .  . <1> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#   HVZ |  .  .  .  .  .  .  .  .  .  .  .  .  . <1> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#    IN |  .  .  .  .  .  .  .  .  .  .  .  .  .  .<10> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#    JJ |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <.> .  .  1  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
# JJ-TL |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <3> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#    MD |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <1> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#    NN |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .<14> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
# NN-TL |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  1 <3> .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#   NNS |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  1  . <2> .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#    NP |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  7  .  . <6> .  1  .  .  .  .  .  .  .  .  .  .  . |
#   NP$ |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <1> .  .  .  .  .  .  .  .  .  .  .  . |
# NP-TL |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  1  . <1> .  .  .  .  .  .  .  .  .  .  . |
#    OD |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <1> .  .  .  1  .  .  .  .  .  . |
#   PP$ |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <3> .  .  .  .  .  .  .  .  . |
#  PPSS |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <1> .  .  .  .  .  .  .  . |
#    QL |  .  .  .  .  .  .  .  .  .  .  .  1  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <.> .  .  .  .  .  .  . |
#    RB |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <3> .  .  .  .  .  . |
#    TO |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <2> .  .  .  .  . |
#    VB |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  1  .  .  1  .  .  .  .  .  .  .  .  .  .  . <1> .  .  .  . |
#   VBD |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <.> 2  .  . |
#   VBN |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  1 <2> .  . |
#   WRB |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <1> . |
#    `` |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <1>|
# ------+----------------------------------------------------------------------------------------------------------+
# (row = reference; col = test)

# %% [markdown]
# We know that 7 NP tags were incorrectly identified as NN. Lets use dictonaries to fix this.

# %%
rule = dict(NP = "NN")

# %%
rule
# Out:
# {'NP': 'NN'}

# %%
def rules(listEntry):
    if(rule.__contains__(listEntry) ):
        return rule[listEntry]
    else: return listEntry

# %%
test_tags2 = [rules(tag) for sent in brown.sents()[size:size + 5] for (word, tag) in t2.tag(sent)]

print(nltk.ConfusionMatrix(gold_tags,  test_tags2) )
# Out:
#       |                                                  J        N           N                                  |
#       |                          B                       J        N           P        P                         |
#       |                 A        E           H  H        -        -  N     N  -     P  P              V  V  W    |
#       |  '        -     B  A  A  D  C  C  C  V  V  I  J  T  M  N  T  N  N  P  T  O  P  S  Q  R  T  V  B  B  R  ` |
#       |  '  *  ,  -  .  N  P  T  Z  C  D  S  D  Z  N  J  L  D  N  L  S  P  $  L  D  $  S  L  B  O  B  D  N  B  ` |
# ------+----------------------------------------------------------------------------------------------------------+
#    '' | <1> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#     * |  . <1> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#     , |  .  .<10> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#    -- |  .  .  . <1> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#     . |  .  .  .  . <5> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#   ABN |  .  .  .  .  . <2> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#    AP |  .  .  .  .  .  . <2> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#    AT |  .  .  .  .  .  .  . <6> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#  BEDZ |  .  .  .  .  .  .  .  . <1> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#    CC |  .  .  .  .  .  .  .  .  . <6> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#    CD |  .  .  .  .  .  .  .  .  .  . <3> .  .  .  .  .  .  .  1  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#    CS |  .  .  .  .  .  .  .  .  .  .  . <.> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#   HVD |  .  .  .  .  .  .  .  .  .  .  .  . <1> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#   HVZ |  .  .  .  .  .  .  .  .  .  .  .  .  . <1> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#    IN |  .  .  .  .  .  .  .  .  .  .  .  .  .  .<10> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#    JJ |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <.> .  .  1  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
# JJ-TL |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <3> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#    MD |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <1> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#    NN |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .<14> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
# NN-TL |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  1 <3> .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#   NNS |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  1  . <2> .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#    NP |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . 13  .  . <.> .  1  .  .  .  .  .  .  .  .  .  .  . |
#   NP$ |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <1> .  .  .  .  .  .  .  .  .  .  .  . |
# NP-TL |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  1  .  .  .  . <1> .  .  .  .  .  .  .  .  .  .  . |
#    OD |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <1> .  .  .  1  .  .  .  .  .  . |
#   PP$ |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <3> .  .  .  .  .  .  .  .  . |
#  PPSS |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <1> .  .  .  .  .  .  .  . |
#    QL |  .  .  .  .  .  .  .  .  .  .  .  1  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <.> .  .  .  .  .  .  . |
#    RB |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <3> .  .  .  .  .  . |
#    TO |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <2> .  .  .  .  . |
#    VB |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  1  .  .  1  .  .  .  .  .  .  .  .  .  .  . <1> .  .  .  . |
#   VBD |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <.> 2  .  . |
#   VBN |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  1 <2> .  . |
#   WRB |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <1> . |
#    `` |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <1>|
# ------+----------------------------------------------------------------------------------------------------------+
# (row = reference; col = test)

# %% [markdown]
# This only increased the incorrect NP instances classified as NN. After This exploration I got curious and the solutions pointed to a homework assignement. It uses functions to get the most misclassified POS tags from the entire data set.

# %%
def confusion_ct(mat, tag1, tag2):
    return mat._confusion[mat._indices[tag1]][mat._indices[tag2]] 
    
def top_cm_errors(mat):
    conf = {}
    num_tags = len(mat._confusion)
    
    for tag1 in mat._indices:
        for tag2 in mat._indices:
            conf[(tag1, tag2)] = confusion_ct(mat, tag1, tag2)
            
    s_il = [((tag1, tag2), ct) for ((tag1, tag2), ct) in 
            sorted(conf.items(), key = lambda x:x[1], reverse = True)
            if tag1 != tag2]
    
    return s_il

# %%
test_tags = [tag for sent in brown.sents()[size:]
             for (word, tag) in t2.tag(sent)]
gold_tags = [tag for sent in brown.tagged_sents()[size:] for (word, tag) in sent]
cm = nltk.ConfusionMatrix(gold_tags, test_tags)

# %%
print(top_cm_errors(cm)[:50], end = '')
# Out:
# [(('JJ', 'NN'), 20420), (('NNS', 'NN'), 18652), (('NP', 'NN'), 13966), (('VB', 'NN'), 9005), (('IN', 'TO'), 8897), (('VBG', 'NN'), 7053), (('VBN', 'NN'), 6859), (('VBN', 'VBD'), 5149), (('RB', 'NN'), 5145), (('VBD', 'NN'), 4243), (('NN-TL', 'NN'), 4034), (('VBD', 'VBN'), 3969), (('NN', 'VB'), 2773), (('VBZ', 'NN'), 2463), (('NP$', 'NN'), 2111), (('CD', 'NN'), 2016), (('RP', 'IN'), 1865), (('CS', 'IN'), 1819), (('NN', 'JJ'), 1512), (('NP-TL', 'NN'), 1322), (('NN-HL', 'NN'), 1202), (('QL', 'RB'), 1158), (('QL', 'CS'), 1143), (('DT', 'CS'), 1135), (('WPS', 'CS'), 1132), (('RB', 'IN'), 1120), (('NP-TL', 'NP'), 1113), (('NNS-TL', 'NN'), 1011), (('RB', 'QL'), 979), (('VBZ', 'NNS'), 946), (('RB', 'JJ'), 915), (('PPO', 'PP$'), 897), (('QL', 'AP'), 886), (('IN', 'RP'), 824), (('RB', 'AP'), 814), (('TO', 'IN'), 792), (('NN', 'VBG'), 781), (('JJ-TL', 'NN'), 771), (('NP', 'NP-TL'), 770), (('NN$', 'NN'), 766), (('AP', 'QL'), 737), (('NPS', 'NN'), 712), (('PPO', 'PPS'), 656), (('CD-TL', 'CD'), 591), (('NNS', 'VBZ'), 568), (('IN-TL', 'IN'), 565), (('IN', 'CS'), 554), (('.-HL', '.'), 549), (('IN', 'NN'), 541), (('IN', 'RB'), 520)]

# %% [markdown]
# Clearly the most common issue is thinking that things are nouns.

# %%
#Frequency of tags from the entire brown corpus 
tags = [tags for _, tags in brown.tagged_words()]

ft = nltk.FreqDist(tags)

# %%
perf = []

# number of top_cm_errors to collapse
trials = [140, 100, 80, 60, 50, 40, 30, 20, 10, 5]

size = int(len(brown.tagged_sents()) * .9)
train_sents = brown.tagged_sents()[:size]
test_sents = brown.tagged_sents()[size:]

for trial in trials:
    
    # create a new mapping of tags to be collapsed for each trial
    new_mappings = {}

    # if the first tag (what the tag should have been) is more common 
    # than the second (how the word was mistakenly labeled), 
    # collapse the second
    for tags, errors in top_cm_errors(cm)[:trial]:
        if ft[tags[0]] > ft[tags[1]]:
            new_mappings[tags[1]] = tags[0]
            
    # training and test sets have to be re-initialized for each trial
    
    new_train_sents = [[(word[0], new_mappings.get(word[1], word[1]))] for sent in train_sents for word in sent ]
    new_test_sents = [[(word[0], new_mappings.get(word[1], word[1]))] for sent in test_sents for word in sent ]
    t0 = nltk.DefaultTagger('NN')
    t1 = nltk.UnigramTagger(new_train_sents, backoff = t0)
    t2 = nltk.BigramTagger(new_train_sents, backoff = t1)
    perf.append(t2.evaluate(new_test_sents))

# %%
import matplotlib.pyplot as plt
plt.plot(trials, perf)
plt.xlim(140, 0)
plt.show()

# %% [markdown]
# # 28.
#
# Experiment with taggers using the simplified tagset (or make one of your own by discarding all but the first character of each tag name). Such a tagger has fewer distinctions to make, but much less information on which to base its work. Discuss your findings.

# %% [markdown]
# Since creating this quesiton NLTK has moved to a Universal tagset. To simplify tagsets we can tag data then use the map_tag

# %%
import nltk
from nltk.tag import pos_tag, map_tag

# %%
text = nltk.word_tokenize("And now for something completely different")
posTagged = pos_tag(text)
simplifiedTags = [(word, map_tag('en-ptb', 'universal', tag)) for word, tag in posTagged]
print(simplifiedTags)
# Out:
# [('And', 'CONJ'), ('now', 'ADV'), ('for', 'ADP'), ('something', 'NOUN'), ('completely', 'ADV'), ('different', 'ADJ')]

# %%
posTagged
# Out:
# [('And', 'CC'),
#  ('now', 'RB'),
#  ('for', 'IN'),
#  ('something', 'NN'),
#  ('completely', 'RB'),
#  ('different', 'JJ')]

# %% [markdown]
# The simplified tagset works but it is not specific as with the original POS tags. "ADP" is adposition which can be a preposition or postposition. Conj is a conjuction, the conjunctions used to join independent clauses in compound sentences are coordinating conjunctions. They can stand alone as complete sentences. A subordinating conjunction, on the other hand, has two functions: it joins, and it shows a relationship between the clauses that it joins.
#
# While the tags are accurate using simplified tags leads to ambiguity.

# %% [markdown]
# # 29.
#
# Recall the example of a bigram tagger which encountered a word it hadn't seen during training, and tagged the rest of the sentence as None. It is possible for a bigram tagger to fail part way through a sentence even if it contains no unseen words (even if the sentence was used during training). In what circumstance can this happen? Can you write a program to find some examples of this?

# %% [markdown]
# I would say yes. If the bigrams have not encountered the exact pair then it might fail, more so if that bigram had different POS tags in traning the model might not be sure of the exact context.

# %%
train_sents = brown.tagged_sents()
t0 = nltk.BigramTagger(train_sents)

# %%
import random
def find_None(sents, tagger, i = 0, n = 3):
    """
    Prints out sentence if two consecutive words are tagged
    with None.  Will run until $n$ sentences are found.
    
    Arguments:
    
    sents:  An untagged corpus.
    tagger: A trained bigram tagger.
    i:      The number of sentences already printed.
    n:      The target number of sentences to be printed. 
            Default is 3.
    """
    r = random.randint(0, len(sents))
    test_tag = tagger.tag(sents[r])
    for j in range(len(test_tag) - 1):
        if test_tag[j][1] == None and test_tag[j + 1][1] == None:
            print(test_tag, "\n")
            i += 1
            break
            
        
    if i < n:
        find_None(sents, tagger, i)

# %%
find_None(brown.sents(), t0)
# Out:
# [('The', 'AT'), ('rating', 'NN'), ('scale', 'NN'), ('of', 'IN'), ('compulsivity', 'NN'), ('was', 'BEDZ'), ('constructed', 'VBN'), ('by', 'IN'), ('first', 'RB'), ('perusing', 'VBG'), ('the', 'AT'), ('interview', 'NN'), ('records', 'NNS'), (',', ','), ('categorizing', 'VBG'), ('all', 'ABN'), ('evidence', 'NN'), ('related', 'VBN'), ('to', 'TO'), ('compulsivity', None), (',', None), ('then', None), ('arranging', None), ('a', None), ('distribution', None), ('of', None), ('such', None), ('information', None), ('apart', None), ('from', None), ('the', None), ('case', None), ('records', None), ('.', None)]
#
# [('Another', 'DT'), ('good', 'JJ'), ('friend', 'NN'), ('of', 'IN'), ('the', 'AT'), ("Coolidges'", 'NPS$'), ('was', 'BEDZ'), ('George', 'NP'), ('B.', 'NP'), ('Harvey', 'NP'), (',', ','), ('who', 'WPS'), ('was', 'BEDZ'), ('the', 'AT'), ('Ambassador', 'NN-TL'), ('to', 'TO'), ('Great', None), ('Britain', None), ('from', None), ('1921', None), ('to', None), ('1923', None), ('.', None)]
#
# [('Of', 'IN'), ('interest', 'NN'), ('is', 'BEZ'), ('a', 'AT'), ('recent', 'JJ'), ('announcement', 'NN'), ('by', 'IN'), ('Du', 'NP'), ("Pont's", 'NP$'), ('Polychemicals', 'NNS-TL'), ('Dept.', 'NN-TL'), ('of', 'IN-TL'), ('a', 'AT-TL'), ('new', None), ('methyl', None), ('methacrylate', None), ('monomer', None), ('designated', None), ('as', None), ('Monocite', None), ('H', None), ('100', None), (',', None), ('which', None), ('was', None), ('developed', None), ('specifically', None), ('for', None), ('production', None), ('of', None), ('cast', None), ('acrylic', None), ('sheets', None), ('for', None), ('the', None), ('sign', None), ('and', None), ('lighting', None), ('industry', None), ('.', None)]

# %% [markdown]
# # 30.
#
# Preprocess the Brown News data by replacing low frequency words with UNK, but leaving the tags untouched. Now train and evaluate a bigram tagger on this data. How much does this help? What is the contribution of the unigram tagger and default tagger now?

# %%
new_freq = nltk.FreqDist(word.lower() for word in brown.words(categories = "news"))

# %%
sizes = [2, 5, 10, 25, 50, 100, 150, 200, 250] # the frequency we are trying 
perfs = []

def preprocess(s): # s for size,aka frequency 
    bns_copy = []
    for sent in brown.tagged_sents(categories = "news"):
        current = []
        for tagset in sent:
            if new_freq[tagset[0].lower()] <= s:
                current.append(('UNK', tagset[1]))
            else:
                current.append(tagset)
        bns_copy.append(current)
        
    size = int(len(brown.tagged_sents(categories = "news")) * 0.9)
    train = bns_copy[:size]
    test = bns_copy[size:]
    return train, test

# %%
for s in sizes:
    train, test = preprocess(s)
    t0 = nltk.BigramTagger(train)
    perfs.append(t0.evaluate(test))

# %%
import matplotlib.pyplot as plt
plt.plot(sizes, perfs, '-bo')
plt.title("Bigram Tagger Performance with $n$ Words Tagged 'UNK'")
plt.xlabel("Frequency Threshold for 'UNK'")
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# After processing low frequency words tO UNK, modeling performance increases when trained on this data. For our specific data, choosing the frequency to be 100 causes the best performance boost.
#
# Prepocessing our data so that low frequency words are replaced with UNK can improve the tagging of bigram taggers.
#
# But what percent of our data is "low frequency".

# %%
train, test = preprocess(100)

# %%
flat_list = [item for sublist in train for item in sublist]

# %%
cdf = nltk.ConditionalFreqDist(flat_list)

# %%
sum(cdf["UNK"].values())/ len(flat_list)
# Out:
# 0.5184763756476398

# %% [markdown]
# Here we see that just over 50% of keys are "UNK". There are many different POS tags that are associated with this but the model can infer which one to use from the token before the UNK.
#
# The solutions show something else but I believe there is human error in the person's solutions. Note: The solutions manual I've been referencing was done by another student of NLTK. He states that 99% of all tags are UNK but I believe that is because of how we acquired his frequencies. He did not use the nltk.FreqDist.
#
# Onto backoff tagers with this level of UNK preprocessing.

# %%
sizes = [2, 5, 10, 25, 50, 100, 250, 500]
perfs = []

for s in sizes:
    
    bns_copy = []

    for sent in brown.tagged_sents(categories = "news"):
        current = []
        for tagset in sent:
            if new_freq[tagset[0].lower()] <= s:
                current.append(('UNK', tagset[1]))
            else:
                current.append(tagset)
        bns_copy.append(current)
        
    size = int(len(brown.tagged_sents(categories = "news")) * 0.9)
    train = bns_copy[:size]
    test = brown.tagged_sents(categories = "news")[size:]

    t0 = nltk.DefaultTagger('NN')
    t1 = nltk.UnigramTagger(train, backoff = t0)
    t2 = nltk.BigramTagger(train, backoff = t1)  
    
    perfs.append(t2.evaluate(test))

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sizes, perfs, '-bo', label = "Performace with backoff taggers")
plt.title("Bigram Tagger Performance with $n$ Words Tagged 'UNK'")
plt.xlabel("Frequency Threshold for 'UNK'")
plt.ylabel('Accuracy')
plt.legend(loc = 'best')
plt.show()

# %% [markdown]
# As we can see the higher the frequency threshold we
