# %% [markdown]
# $ Equation$ $1$
#
# $\rho= \frac{Current Value - Inital Value}{Inital Value} * 100 $

# %% [markdown]
# $Equation$ $2$
#
# $\mu_{\rho} = \sum_{i =0}^{n} w_{i} \mu_{i} $
#
# Where $ \mu_{i} = E(\rho_i) $

# %%
import matplotlib.pyplot as plt 
  
import numpy as np

x_space = np.linspace( start = 11 , stop=  14 , num = 50 )
y = [] 
for x in x_space:
    y_i = 225.610001 + (-58.96300781607924)*(x-11) + (111.33450272411883)*(x-11)**2 + (-37.11150090803961)*(x-11)**3
    y.append(y_i)
    
plt.plot(x_space, y) 
plt.xlabel('Month(X = 12 is Septemeber, X = 13 is October )') 
plt.ylabel('Closing Price(In USD)')
plt.title('Figure 2: Cubic Tesla Model') 

plt.show()

# %% [markdown]
# $Equation$ $3$
#
# $\sigma_{p}^{2} = \mathbf{w}^{T} V \mathbf{w}$  Where $w$ is portfolio weights
# and $V$ the covariance matrix
